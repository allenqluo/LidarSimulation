# %%
# Define a function to convert a string representation of a list to a list
def parse_list_string(list_string):
    return [float(item.strip()) if '.' in item and item != '-' else int(item.strip()) if item != '-' else None for item in list_string.split('-')]

# Dictionary to store indices of points within each circle
redwood_tree_data = {}

# Define the file path from where you want to read the data
tree_file_path = "redwood_output/tree_data.txt"

with open(tree_file_path, 'r') as file:
    tree_index = None
    tree_values = {}
    for line in file:
        line = line.strip()
        if line.endswith(':'):
            # Start of a new tree index
            if tree_index is not None:
                redwood_tree_data[tree_index] = tree_values
                tree_values = {}
            tree_index = line[:-1]
        elif line:
            # Parse field and value
            field, value = line.split(':')
            field = field.strip()
            value = value.strip()
            if value.startswith('- '):
                # If the value is a list
                value = parse_list_string(value[2:])
            elif '.' in value:
                # If the value is a float
                value = float(value)
            else:
                # If the value is an integer or string
                try:
                    value = int(value)
                except ValueError:
                    pass
            tree_values[field] = value

    # Add the last tree data
    if tree_index is not None:
        redwood_tree_data[tree_index] = tree_values

# Print the read data to verify
print(redwood_tree_data)

# Dictionary to store indices of points within each circle
guiana_tree_data = {}

# Define the file path from where you want to read the data
tree_file_path = "guiana_output/tree_data.txt"

with open(tree_file_path, 'r') as file:
    tree_index = None
    tree_values = {}
    for line in file:
        line = line.strip()
        if line.endswith(':'):
            # Start of a new tree index
            if tree_index is not None:
                guiana_tree_data[tree_index] = tree_values
                tree_values = {}
            tree_index = line[:-1]
        elif line:
            # Parse field and value
            field, value = line.split(':')
            field = field.strip()
            value = value.strip()
            if value.startswith('- '):
                # If the value is a list
                value = parse_list_string(value[2:])
            elif '.' in value:
                # If the value is a float
                value = float(value)
            else:
                # If the value is an integer or string
                try:
                    value = int(value)
                except ValueError:
                    pass
            tree_values[field] = value

    # Add the last tree data
    if tree_index is not None:
        guiana_tree_data[tree_index] = tree_values

# Print the read data to verify
print(guiana_tree_data)
# Out:
# {'Tree [1]': {'crown_base': 9.41629, 'crown_d1': 6.85315, 'crown_d2': 3.84102, 'crown_d3': 13.6378, 'crown_center_height': 16.23519, 'tree_height': 23.08834, 'crown_volume': 423.51811, 'single_leaf_areas': [3e-05], 'total_leaf_areas': 317.63858, 'total_tree_branch_area': 525.11363, 'total_tree_stem_areas': '-', 'total_tree_ground_areas': 147.54699, 'total_tree_canopy_veg_areas': 392.10947}, 'Tree [2]': {'crown_base': 12.2034, 'crown_d1': 10.1127, 'crown_d2': 5.93701, 'crown_d3': 20.1243, 'crown_center_height': 22.26555, 'tree_height': 32.37825, 'crown_volume': 1493.10825, 'single_leaf_areas': [3e-05], 'total_leaf_areas': '-', 'total_tree_branch_area': 1934.21941, 'total_tree_stem_areas': '-', 'total_tree_ground_areas': 321.28032, 'total_tree_canopy_veg_areas': '-'}, 'Tree [3]': {'crown_base': 9.8635, 'crown_d1': 7.24383, 'crown_d2': 3.83453, 'crown_d3': 14.4152, 'crown_center_height': 17.0711, 'tree_height': 24.31493, 'crown_volume': 446.15025, 'single_leaf_areas': [3e-05], 'total_leaf_areas': 334.61269, 'total_tree_branch_area': 579.19392, 'total_tree_stem_areas': '-', 'total_tree_ground_areas': 164.84902, 'total_tree_canopy_veg_areas': 913.80661}, 'Tree [4]': {'crown_base': 10.4496, 'crown_d1': 9.06163, 'crown_d2': 4.85262, 'crown_d3': 18.0326, 'crown_center_height': 19.4659, 'tree_height': 28.52753, 'crown_volume': 893.81472, 'single_leaf_areas': [3e-05], 'total_leaf_areas':
 'total_tree_stem_areas': '-', 'total_tree_ground_areas': 53.62606, 'total_tree_canopy_veg_areas': 81129.29459}, 'Tree [10]': {'crown_base': 13.6549, 'crown_d1': 4.68895, 'crown_d2': 2.37698, 'crown_d3': 9.33102, 'crown_center_height': 18.32041, 'tree_height': 23.00936, 'crown_volume': 110.97247, 'single_leaf_areas': [0.01161], 'total_leaf_areas': '-', 'total_tree_branch_area': 159.54367, 'total_tree_stem_areas': '-', 'total_tree_ground_areas': 69.07185, 'total_tree_canopy_veg_areas': '-'}, 'Tree [11]': {'crown_base': 13.8307, 'crown_d1': 4.30215, 'crown_d2': 2.38285, 'crown_d3': 8.56128, 'crown_center_height': 18.11134, 't ...

# %%
# Define a function to parse list strings
def parse_list_string(list_string):
    return [float(item.strip()) if '.' in item and item != '-' else int(item.strip()) if item != '-' else None for item in list_string.split('-')]

# Define the prefix for circle file paths
circle_path_prefix = "redwood_output/"

# Define the dictionary to store circle data
redwood_circle_indices = {}

# Loop through each circle file
for i in range(3, 0, -1):
    for j in range(1, 4):
        circle_name = f"Circle [{i}, {j}]"
        file_path = f"{circle_path_prefix}circle_data_{circle_name}.txt"

        # Read circle data from file
        with open(file_path, 'r') as file:
            circle_data = {}
            circle_data[circle_name] = {}
            current_field = None
            for line in file:
                line = line.strip()
                if line.endswith(':'):
                    # Start of a new field
                    current_field = line[:-1]
                    circle_data[circle_name][current_field] = []
                elif line.startswith('- '):
                    # List item
                    circle_data[circle_name][current_field].append(parse_list_string(line[2:]))
                else:
                    # Single value
                    field, value = line.split(':')
                    circle_data[circle_name][field.strip()] = parse_list_string(value.strip())[0]

            # Merge circle data into main dictionary
            redwood_circle_indices.update(circle_data)

# Print the merged dictionary
print(redwood_circle_indices)

# Define the prefix for circle file paths
circle_path_prefix = "guiana_output/"

# Define the dictionary to store circle data
guiana_circle_indices = {}

# Loop through each circle file
for i in range(3, 0, -1):
    for j in range(1, 4):
        circle_name = f"Circle [{i}, {j}]"
        file_path = f"{circle_path_prefix}circle_data_{circle_name}.txt"

        # Read circle data from file
        with open(file_path, 'r') as file:
            circle_data = {}
            circle_data[circle_name] = {}
            current_field = None
            for line in file:
                line = line.strip()
                if line.endswith(':'):
                    # Start of a new field
                    current_field = line[:-1]
                    circle_data[circle_name][current_field] = []
                elif line.startswith('- '):
                    # List item
                    circle_data[circle_name][current_field].append(parse_list_string(line[2:]))
                else:
                    # Single value
                    field, value = line.split(':')
                    circle_data[circle_name][field.strip()] = parse_list_string(value.strip())[0]

            # Merge circle data into main dictionary
            guiana_circle_indices.update(circle_data)

# Print the merged dictionary
print(guiana_circle_indices)
# Out:
# {'Circle [3, 1]': {'Circle [3, 1]': [], 'indices': [[1], [3], [4], [5], [6], [10], [11], [12], [20], [21]], 'crown_vol_in_circle': [[197.05134868438574], [446.1502479699771], [649.2507141670159], [157.54484615875558], [367.1996157047156], [10.921211032523688], [333.056534006133], [109.56265422729902], [840.6609879749167], [1382.3297439620437]], 'radius': 12.5, 'crown_percentage': [[0.4652725465190833], [1.0], [0.7263817659901105], [0.6716121768741096], [1.0], [0.04334232545806171], [0.2997153435738256], [1.0], [0.947213027675467], [0.47555574778969306]], 'tree_density':
std_crown_d1': 0.9651339851230534, 'mean_crown_d2': 1.848937222222222, 'std_crown_d2': 0.8392686724280466, 'mean_crown_center_height': 15.044281851851851, 'std_crown_center_height': 4.007747979060003, 'mean_tree_height': 18.695330740740737, 'std_tree_height': 4.967613144560158, 'mean_crown_volume': 77.95817681530649, 'std_crown_volume': 100.10947567575056, 'total_crown_volume': 2104.870774013275, 'total_vegetation_area_per_pixel': 1424534.8875126936, 'LAI_per_pixel': 2898.0709040853467, 'h1': 7.028785893731845, 'h2': 23.059777809971855, 'Fa': 1015.8749999999999}, 'Circle [3, 3]': {'Circle [3, 3]': [], 'indices': [[47], [50], [64], [77], [93], [105], [112], [120], [121], [124], [129], [142], [152], [156], [166], [167], [168], [169], [182], [184], [195], [216], [229], [231]], 'crown_vol_in_circle': [[106.25840876179743], [1.0613942948051385], [20.80616014185378], [2.6037117591826755], [1.160121947590456], [62.81837110972952], [19.348005848489976], [29.04016802891639], [2.6998952576964776], [6.375599143217776], [50.53260961030311], [1.2659500417604839], [11.45526753479565], [239.4937233255899], [123.76779380581549], [91.34598699333444], [194.0272558894338], [11.759970891265233], [1.8642335391258047], [15.973906954896679], [0.7722960793388058], [110.47102463764381], [33.10820768090995], [3.3187441645561515]], 'radius': 12.5, 'crown_percentage': [[1.0], [0.020755075950394834], [1.0], [0.12459501262186133], [0.142695690 ...

# %%
import os
import matplotlib.pyplot as plt

# Define the directory to save the figures
redwood_output_folder = "redwood_output/graphs_and_plots"
guiana_output_folder = "guiana_output/graphs_and_plots"

# Create the directory if it doesn't exist
os.makedirs(redwood_output_folder, exist_ok=True)
os.makedirs(guiana_output_folder, exist_ok=True)

# Extract circle names and tree densities
redwood_circle_names = list(redwood_circle_indices.keys())
tree_densities = [redwood_circle_indices[circle_name]['tree_density'] for circle_name in redwood_circle_names]

# Plotting the bar graph
plt.figure(figsize=(20, 12))
plt.bar(redwood_circle_names, tree_densities, color='skyblue')
plt.title('Tree Densities of All Circles in California Redwood 005')
plt.xlabel('Circle Names')
plt.ylabel('Tree Density')
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for better readability
plt.tight_layout()

# Save the figure as a PNG image to the output folder
output_file_path = os.path.join(redwood_output_folder, "redwood_tree_densities.png")
plt.savefig(output_file_path)

plt.show()

# Extract circle names and tree densities
guiana_circle_names = list(redwood_circle_indices.keys())
tree_densities = [guiana_circle_indices[circle_name]['tree_density'] for circle_name in guiana_circle_names]

# Plotting the bar graph
plt.figure(figsize=(20, 12))
plt.bar(guiana_circle_names, tree_densities, color='skyblue')
plt.title('Tree Densities of All Circles in French Guiana 005')
plt.xlabel('Circle Names')
plt.ylabel('Tree Density')
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for better readability
plt.tight_layout()

plt.rcParams['axes.titlesize'] = 24
plt.rcParams['axes.labelsize'] = 30
plt.rcParams['xtick.labelsize'] = 20
plt.rcParams['ytick.labelsize'] = 20

# Save the figure as a PNG image to the output folder
output_file_path = os.path.join(guiana_output_folder, "guiana_tree_densities.png")
plt.savefig(output_file_path)

plt.show()

# %%
import matplotlib.pyplot as plt

# Define the directory to save the figures
redwood_output_folder = "redwood_output/graphs_and_plots"
guiana_output_folder = "guiana_output/graphs_and_plots"

# Create the directory if it doesn't exist
os.makedirs(redwood_output_folder, exist_ok=True)
os.makedirs(guiana_output_folder, exist_ok=True)

# Initialize lists for tree heights and crown diameters
tree_heights = []
crown_d1_values = []
crown_d2_values = []

plt.rcParams['axes.titlesize'] = 24
plt.rcParams['axes.labelsize'] = 30
plt.rcParams['xtick.labelsize'] = 20
plt.rcParams['ytick.labelsize'] = 20

# Extract tree_height, crown_d1, and crown_d2 values from redwood_tree_data
for tree_values in redwood_tree_data.values():
    # If tree_height is a list, extend the list after filtering out '-' values
    if isinstance(tree_values['tree_height'], list):
        tree_heights.extend([value for value in tree_values['tree_height'] if isinstance(value, float)])
    else:
        if isinstance(tree_values['tree_height'], float):
            tree_heights.append(tree_values['tree_height'])
    
    # If crown_d1 is a list, extend the list after filtering out '-' values
    if isinstance(tree_values['crown_d1'], list):
        crown_d1_values.extend([value for value in tree_values['crown_d1'] if isinstance(value, float)])
    else:
        if isinstance(tree_values['crown_d1'], float):
            crown_d1_values.append(tree_values['crown_d1'])

    # If crown_d2 is a list, extend the list after filtering out '-' values
    if isinstance(tree_values['crown_d2'], list):
        crown_d2_values.extend([value for value in tree_values['crown_d2'] if isinstance(value, float)])
    else:
        if isinstance(tree_values['crown_d2'], float):
            crown_d2_values.append(tree_values['crown_d2'])

# Create subplots
fig, axs = plt.subplots(1, 3, figsize=(24, 12))

# Plot crown_d2 vs tree_height
axs[0].scatter(tree_heights, crown_d2_values, color='blue', alpha=0.5)
axs[0].set_title('Crown Radius vs Tree Height')
axs[0].set_xlabel('Tree Height')
axs[0].set_ylabel('Crown Radius')
axs[0].grid(True)

# Plot crown_d1 vs tree_height
axs[1].scatter(tree_heights, crown_d1_values, color='green', alpha=0.5)
axs[1].set_title('Crown Depth vs Tree Height')
axs[1].set_xlabel('Tree Height')
axs[1].set_ylabel('Crown Depth')
axs[1].grid(True)

# Calculate crown_d2/h values
crown_d2_over_h_values = [d2 / h for d2, h in zip(crown_d2_values, tree_heights)]

# Plot crown_d2/h vs tree_height
axs[2].scatter(tree_heights, crown_d2_over_h_values, color='red', alpha=0.5)
axs[2].set_title('Crown Radius/Tree Height\n vs Tree Height')
axs[2].set_xlabel('Tree Height')
axs[2].set_ylabel('Crown Radius / Tree Height')
axs[2].grid(True)

# Set the suptitle and adjust layout
plt.suptitle('California Redwood Tree Metrics', x=0.5, y=0.90, fontsize=36)  # Adjust the y-coordinate here

# Adjust the bottom margin to leave space for the title
plt.subplots_adjust(top=0.80, bottom=0.08, left=0.03, right=0.97, hspace=0.25, wspace=0.2)

# Save the figure as a PNG image to the output folder
output_file_path = os.path.join(redwood_output_folder, "redwood_tree_metrics.png")
plt.savefig(output_file_path)

plt.show()

tree_heights = []
crown_d1_values = []
crown_d2_values = []

# Extract tree_height, crown_d1, and crown_d2 values from redwood_tree_data
for tree_values in guiana_tree_data.values():
    # If tree_height is a list, extend the list after filtering out '-' values
    if isinstance(tree_values['tree_height'], list):
        tree_heights.extend([value for value in tree_values['tree_height'] if isinstance(value, float)])
    else:
        if isinstance(tree_values['tree_height'], float):
            tree_heights.append(tree_values['tree_height'])
    
    # If crown_d1 is a list, extend the list after filtering out '-' values
    if isinstance(tree_values['crown_d1'], list):
        crown_d1_values.extend([value for value in tree_values['crown_d1'] if isinstance(value, float)])
    else:
        if isinstance(tree_values['crown_d1'], float):
            crown_d1_values.append(tree_values['crown_d1'])

    # If crown_d2 is a list, extend the list after filtering out '-' values
    if isinstance(tree_values['crown_d2'], list):
        crown_d2_values.extend([value for value in tree_values['crown_d2'] if isinstance(value, float)])
    else:
        if isinstance(tree_values['crown_d2'], float):
            crown_d2_values.append(tree_values['crown_d2'])

# Create subplots
fig, axs = plt.subplots(1, 3, figsize=(24, 12))

# Plot crown_d2 vs tree_height
axs[0].scatter(tree_heights, crown_d2_values, color='blue', alpha=0.5)
axs[0].set_title('Crown Radius vs Tree Height')
axs[0].set_xlabel('Tree Height')
axs[0].set_ylabel('Crown Radius')
axs[0].grid(True)

# Plot crown_d1 vs tree_height
axs[1].scatter(tree_heights, crown_d1_values, color='green', alpha=0.5)
axs[1].set_title('Crown Depth vs Tree Height')
axs[1].set_xlabel('Tree Height')
axs[1].set_ylabel('Crown Depth')
axs[1].grid(True)

# Calculate crown_d2/h values
crown_d2_over_h_values = [d2 / h for d2, h in zip(crown_d2_values, tree_heights)]

# Plot crown_d2/h vs tree_height
axs[2].scatter(tree_heights, crown_d2_over_h_values, color='red', alpha=0.5)
axs[2].set_title('Crown Radius/Tree Height\n vs Tree Height')
axs[2].set_xlabel('Tree Height')
axs[2].set_ylabel('Crown Radius / Tree Height')
axs[2].grid(True)

# Set the suptitle and adjust layout
plt.suptitle('French Guiana Tree Metrics', x=0.5, y=0.90, fontsize=36)  # Adjust the y-coordinate here

# Adjust the bottom margin to leave space for the title
plt.subplots_adjust(top=0.80, bottom=0.08, left=0.03, right=0.97, hspace=0.25, wspace=0.2)

# Save the figure as a PNG image to the output folder
output_file_path = os.path.join(guiana_output_folder, "guiana_tree_metrics.png")
plt.savefig(output_file_path)

plt.show()

# %%
import matplotlib.pyplot as plt
import os

# Define the directory to save the figures
redwood_output_folder = "redwood_output/graphs_and_plots"

# Create the directory if it doesn't exist
os.makedirs(redwood_output_folder, exist_ok=True)

# Define the number of rows and columns for subplot arrangement
num_rows = 3
num_cols = 3

plt.rcParams['axes.titlesize'] = 20
plt.rcParams['axes.labelsize'] = 15
plt.rcParams['xtick.labelsize'] = 20
plt.rcParams['ytick.labelsize'] = 15

###  Redwood Crown Radius Count
# Create subplots for each circle
fig, axs = plt.subplots(num_rows, num_cols, figsize=(20, 20))

# Flatten the axes array to iterate over it with a single loop
axs_flat = axs.flatten()

# Iterate over each circle's data and plot the histogram
for i, (circle_name, data) in enumerate(redwood_circle_indices.items()):
    # Extract tree indices for the current circle
    tree_indices = data['indices']
    
    # Collect all crown_d2 values for the trees in the current circle
    all_crown_d2_values = []
    for tree_index in tree_indices:
        tree_data_key = f"Tree {tree_index}"
        crown_d2_value = redwood_tree_data[tree_data_key]['crown_d2']
        all_crown_d2_values.append(crown_d2_value)
    
    # Plot histogram for all crown_d2 values in the current circle
    x_min = min(all_crown_d2_values)
    x_max = max(all_crown_d2_values)
    x_range = x_max - x_min
    bar_width = x_range / 18  # Adjust divisor as needed
    axs_flat[i].hist(all_crown_d2_values, bins=10, color='blue', alpha=0.7, width=bar_width)  # Adjust width here
    axs_flat[i].set_title(circle_name)
    axs_flat[i].set_xlabel('Crown Radius')
    axs_flat[i].set_ylabel('Count')

# Set the suptitle and adjust layout
plt.suptitle('California Redwood Crown Radius Count', x=0.5, y=0.95, fontsize=36)  # Adjust the y-coordinate here

# Adjust the bottom margin to leave space for the title
plt.subplots_adjust(top=0.9, bottom=0.1, left=0.03, right=0.97, hspace=0.25, wspace=0.2)

# Save the figure as a PNG image to the output folder
output_file_path = os.path.join(redwood_output_folder, "redwood_crown_radius_count.png")
plt.savefig(output_file_path)

plt.show()

###  Redwood Tree Height Count
# Create subplots for each circle
fig, axs = plt.subplots(num_rows, num_cols, figsize=(20, 20))

# Flatten the axes array to iterate over it with a single loop
axs_flat = axs.flatten()

# Iterate over each circle's data and plot the histogram
for i, (circle_name, data) in enumerate(redwood_circle_indices.items()):
    # Extract tree indices for the current circle
    tree_indices = data['indices']
    
    # Collect all crown_d2 values for the trees in the current circle
    all_tree_height_values = []
    for tree_index in tree_indices:
        tree_data_key = f"Tree {tree_index}"
        tree_height_value = redwood_tree_data[tree_data_key]['tree_height']
        all_tree_height_values.append(tree_height_value)
    
    # Plot histogram for all crown_d2 values in the current circle
    x_min = min(all_tree_height_values)
    x_max = max(all_tree_height_values)
    x_range = x_max - x_min
    bar_width = x_range / 18  # Adjust divisor as needed
    axs_flat[i].hist(all_tree_height_values, bins=10, color='blue', alpha=0.7, width=bar_width)  # Adjust width here
    axs_flat[i].set_title(circle_name)
    axs_flat[i].set_xlabel('Tree Height')
    axs_flat[i].set_ylabel('Count')

# Set the suptitle and adjust layout
plt.suptitle('California Redwood Tree Height Count', x=0.5, y=0.95, fontsize=36)  # Adjust the y-coordinate here

# Adjust the bottom margin to leave space for the title
plt.subplots_adjust(top=0.9, bottom=0.1, left=0.03, right=0.97, hspace=0.25, wspace=0.2)

# Save the figure as a PNG image to the output folder
output_file_path = os.path.join(redwood_output_folder, "redwood_tree_height_count.png")
plt.savefig(output_file_path)

plt.show()


###  Redwood Crown Width/Tree Height Count
# Create subplots for each circle
fig, axs = plt.subplots(num_rows, num_cols, figsize=(20, 20))

# Flatten the axes array to iterate over it with a single loop
axs_flat = axs.flatten()

# Iterate over each circle's data and plot the histogram
for i, (circle_name, data) in enumerate(redwood_circle_indices.items()):
    # Extract tree indices for the current circle
    tree_indices = data['indices']
    
    # Collect all crown_d2 values for the trees in the current circle
    all_ratio_values = []
    for tree_index in tree_indices:
        tree_data_key = f"Tree {tree_index}"
        crown_d2 = redwood_tree_data[tree_data_key]['crown_d2']
        tree_height_value = redwood_tree_data[tree_data_key]['tree_height']
        ratio_value = 2*crown_d2 / tree_height_value
        all_ratio_values.append(ratio_value)
    
    # Plot histogram for all crown_d2 values in the current circle
    x_min = min(all_ratio_values)
    x_max = max(all_ratio_values)
    x_range = x_max - x_min
    bar_width = x_range / 18  # Adjust divisor as needed
    axs_flat[i].hist(all_ratio_values, bins=10, color='blue', alpha=0.7, width=bar_width)  # Adjust width here
    axs_flat[i].set_title(circle_name)
    axs_flat[i].set_xlabel('Crown Width to Tree Height Ratio')
    axs_flat[i].set_ylabel('Count')

# Set the suptitle and adjust layout
plt.suptitle('California Redwood Crown Width to Tree Height Ratio Count', x=0.5, y=0.95, fontsize=36)  # Adjust the y-coordinate here

# Adjust the bottom margin to leave space for the title
plt.subplots_adjust(top=0.9, bottom=0.1, left=0.03, right=0.97, hspace=0.25, wspace=0.2)

# Save the figure as a PNG image to the output folder
output_file_path = os.path.join(redwood_output_folder, "redwood_cr_width_tree_h_ratio_count.png")
plt.savefig(output_file_path)

plt.show()


### Redwood Crown Depth to Tree Height Ratio

# Initialize list to store crown_d1/tree_height ratios
crown_d1_tree_height_ratios = []

# Iterate over each tree's data
for tree_data in redwood_tree_data.values():
    crown_d1 = tree_data.get('crown_d1')
    tree_height = tree_data.get('tree_height')

    crown_d1_tree_height_ratio = crown_d1 / tree_height
    crown_d1_tree_height_ratios.append(crown_d1_tree_height_ratio)

# Plot histogram
plt.figure(figsize=(20, 20))
x_min = min(crown_d1_tree_height_ratios)
x_max = max(crown_d1_tree_height_ratios)
x_range = x_max - x_min
bar_width = x_range / 28  # Adjust divisor as needed
plt.hist(crown_d1_tree_height_ratios, bins=20, color='blue', alpha=0.7, width=bar_width)

plt.title('California Redwood \nCrown Depth to Tree Height Ratio Count')
plt.xlabel('Crown Depth / Tree Height')
plt.ylabel('Count')

# Save the figure as a PNG image to the output folder
output_file_path = os.path.join(redwood_output_folder, "redwood_cr_depth_tree_h_ratio_count.png")
plt.savefig(output_file_path)

plt.show()


### Redwood Crown Depth to Crown Width Ratio

# Initialize list to store crown_d1/tree_height ratios
crown_d1_crown_width_ratios = []

# Iterate over each tree's data
for tree_data in redwood_tree_data.values():
    crown_d1 = tree_data.get('crown_d1')
    crown_d2 = tree_data.get('crown_d2')

    crown_d1_crown_width_ratio = crown_d1 / (2 * crown_d2)
    crown_d1_crown_width_ratios.append(crown_d1_crown_width_ratio)

# Plot histogram
plt.figure(figsize=(18, 12))
x_min = min(crown_d1_crown_width_ratios)
x_max = max(crown_d1_crown_width_ratios)
x_range = x_max - x_min
bar_width = x_range / 28  # Adjust divisor as needed
plt.hist(crown_d1_crown_width_ratios, bins=20, color='blue', alpha=0.7, width=bar_width)

plt.title('California Redwood \nCrown Depth to Crown Width Ratio Count')
plt.xlabel('Crown Depth / Crown Width')
plt.ylabel('Count')

# Save the figure as a PNG image to the output folder
output_file_path = os.path.join(redwood_output_folder, "redwood_cr_depth_cr_width_ratio_metrics.png")
plt.savefig(output_file_path)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Initialize lists to store circle names, mean d1 values, and std d1 values
circle_names = []
mean_d1_values = []
std_d1_values = []
mean_d2_values = []
std_d2_values =[]
mean_crown_center_height =[]
std_crown_center_height = []
mean_tree_height = []
std_tree_height = []
LAI_per_pixel = []
Fa = []

# Iterate over each circle's data
for circle_name, data in redwood_circle_indices.items():
    # Append circle name to the list
    circle_names.append(circle_name)
    
    # Append mean and std d1 values to the lists
    mean_d1_values.append(data['mean_crown_d1'])
    std_d1_values.append(data['std_crown_d1'])
    mean_d2_values.append(data['mean_crown_d2'])
    std_d2_values.append(data['std_crown_d2'])
    mean_crown_center_height.append(data['mean_crown_center_height'])
    std_crown_center_height.append(data['std_crown_center_height'])

    mean_tree_height.append(data['mean_tree_height'])
    std_tree_height.append(data['std_tree_height'])
    LAI_per_pixel.append(data['LAI_per_pixel'])
    Fa.append(data['Fa'])

# Create subplots
fig, axs = plt.subplots(2, 3, figsize=(35, 24))

# Set global plot parameters
plt.rcParams['axes.titlesize'] = 24
plt.rcParams['axes.labelsize'] = 22
plt.rcParams['xtick.labelsize'] = 20
plt.rcParams['ytick.labelsize'] = 20

# Plot mean and std of d1 in the first subplot
axs[0, 0].bar(circle_names, mean_d1_values, yerr=std_d1_values, capsize=5)
axs[0, 0].set_title('Mean and Std of Vertical Crown Radius')
axs[0, 0].set_ylabel('d1 Values')

# Plot mean and std of d2 in the second subplot
axs[0, 1].bar(circle_names, mean_d2_values, yerr=std_d2_values, capsize=5)
axs[0, 1].set_title('Mean and Std of Horizontal Crown Radius')
axs[0, 1].set_ylabel('d2 Values')

# Plot mean and std of crown center height in the third subplot
axs[0, 2].bar(circle_names, mean_crown_center_height, yerr=std_crown_center_height, capsize=5)
axs[0, 2].set_title('Mean and Std of Crown Center Height')
axs[0, 2].set_ylabel('Crown Center Height Values')

# Plot mean and std of tree height in the fourth subplot
axs[1, 0].bar(circle_names, mean_tree_height, yerr=std_tree_height, capsize=5)
axs[1, 0].set_title('Mean and Std of Tree Height')
axs[1, 0].set_ylabel('Tree Height Values')

# Plot bar graph of LAI per pixel in the fifth subplot
axs[1, 1].bar(circle_names, LAI_per_pixel)
axs[1, 1].set_title('LAI per Unit Area')
axs[1, 1].set_ylabel('LAI per Pixel')

# Plot bar graph of Fa in the sixth subplot
axs[1, 2].bar(circle_names, Fa)
axs[1, 2].set_title('Fa')
axs[1, 2].set_ylabel('Fa Values')

# Rotate x-axis labels for better readability
for ax in axs.flat:
    ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha='right')

# Set the suptitle and adjust layout
plt.suptitle('California Redwood \nMean and Std Values', x=0.5, y=0.95, fontsize=36)  # Adjust the y-coordinate here

# Adjust the bottom margin to leave space for the title
plt.subplots_adjust(top=0.88, bottom=0.08, left=0.10, right=0.95, hspace=0.25, wspace=0.35)

# Save the figure as a PNG image to the output folder
output_file_path = os.path.join(redwood_output_folder, "redwood_mean_std_plots.png")
plt.savefig(output_file_path)

# Show the plot
plt.show()
# Out:
# C:\Users\allen\AppData\Local\Temp\ipykernel_12452\204026080.py:76: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha='right')
# C:\Users\allen\AppData\Local\Temp\ipykernel_12452\204026080.py:76: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha='right')
# C:\Users\allen\AppData\Local\Temp\ipykernel_12452\204026080.py:76: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha='right')
# C:\Users\allen\AppData\Local\Temp\ipykernel_12452\204026080.py:76: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha='right')
# C:\Users\allen\AppData\Local\Temp\ipykernel_12452\204026080.py:76: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha='right')
# C:\Users\allen\AppData\Local\Temp\ipykernel_12452\204026080.py:76: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha='right')

# %%
import matplotlib.pyplot as plt
import os

# Define the directory to save the figures
guiana_output_folder = "guiana_output/graphs_and_plots"

# Create the directory if it doesn't exist
os.makedirs(guiana_output_folder, exist_ok=True)

# Define the number of rows and columns for subplot arrangement
num_rows = 3
num_cols = 3

plt.rcParams['axes.titlesize'] = 20
plt.rcParams['axes.labelsize'] = 15
plt.rcParams['xtick.labelsize'] = 20
plt.rcParams['ytick.labelsize'] = 15

###  Redwood Crown Radius Count
# Create subplots for each circle
fig, axs = plt.subplots(num_rows, num_cols, figsize=(20, 20))

# Flatten the axes array to iterate over it with a single loop
axs_flat = axs.flatten()

# Iterate over each circle's data and plot the histogram
for i, (circle_name, data) in enumerate(guiana_circle_indices.items()):
    # Extract tree indices for the current circle
    tree_indices = data['indices']
    
    # Collect all crown_d2 values for the trees in the current circle
    all_crown_d2_values = []
    for tree_index in tree_indices:
        tree_data_key = f"Tree {tree_index}"
        crown_d2_value = guiana_tree_data[tree_data_key]['crown_d2']
        all_crown_d2_values.append(crown_d2_value)
    
    # Plot histogram for all crown_d2 values in the current circle
    x_min = min(all_crown_d2_values)
    x_max = max(all_crown_d2_values)
    x_range = x_max - x_min
    bar_width = x_range / 18  # Adjust divisor as needed
    axs_flat[i].hist(all_crown_d2_values, bins=10, color='blue', alpha=0.7, width=bar_width)  # Adjust width here
    axs_flat[i].set_title(circle_name)
    axs_flat[i].set_xlabel('Crown Radius')
    axs_flat[i].set_ylabel('Count')

# Set the suptitle and adjust layout
plt.suptitle('French Guiana Crown Radius Count', x=0.5, y=0.95, fontsize=36)  # Adjust the y-coordinate here

# Adjust the bottom margin to leave space for the title
plt.subplots_adjust(top=0.9, bottom=0.1, left=0.03, right=0.97, hspace=0.25, wspace=0.2)

# Save the figure as a PNG image to the output folder
output_file_path = os.path.join(guiana_output_folder, "guiana_crown_radius_count.png")
plt.savefig(output_file_path)

plt.show()

###  Redwood Tree Height Count
# Create subplots for each circle
fig, axs = plt.subplots(num_rows, num_cols, figsize=(20, 20))

# Flatten the axes array to iterate over it with a single loop
axs_flat = axs.flatten()

# Iterate over each circle's data and plot the histogram
for i, (circle_name, data) in enumerate(guiana_circle_indices.items()):
    # Extract tree indices for the current circle
    tree_indices = data['indices']
    
    # Collect all crown_d2 values for the trees in the current circle
    all_tree_height_values = []
    for tree_index in tree_indices:
        tree_data_key = f"Tree {tree_index}"
        tree_height_value = guiana_tree_data[tree_data_key]['tree_height']
        all_tree_height_values.append(tree_height_value)
    
    # Plot histogram for all crown_d2 values in the current circle
    x_min = min(all_tree_height_values)
    x_max = max(all_tree_height_values)
    x_range = x_max - x_min
    bar_width = x_range / 18  # Adjust divisor as needed
    axs_flat[i].hist(all_tree_height_values, bins=10, color='blue', alpha=0.7, width=bar_width)  # Adjust width here
    axs_flat[i].set_title(circle_name)
    axs_flat[i].set_xlabel('Tree Height')
    axs_flat[i].set_ylabel('Count')

# Set the suptitle and adjust layout
plt.suptitle('French Guiana Tree Height Count', x=0.5, y=0.95, fontsize=36)  # Adjust the y-coordinate here

# Adjust the bottom margin to leave space for the title
plt.subplots_adjust(top=0.9, bottom=0.1, left=0.03, right=0.97, hspace=0.25, wspace=0.2)

# Save the figure as a PNG image to the output folder
output_file_path = os.path.join(guiana_output_folder, "guiana_tree_height_count.png")
plt.savefig(output_file_path)

plt.show()

###  Redwood Crown Width/Tree Height Count
# Create subplots for each circle
fig, axs = plt.subplots(num_rows, num_cols, figsize=(20, 20))

# Flatten the axes array to iterate over it with a single loop
axs_flat = axs.flatten()

# Iterate over each circle's data and plot the histogram
for i, (circle_name, data) in enumerate(guiana_circle_indices.items()):
    # Extract tree indices for the current circle
    tree_indices = data['indices']
    
    # Collect all crown_d2 values for the trees in the current circle
    all_ratio_values = []
    for tree_index in tree_indices:
        tree_data_key = f"Tree {tree_index}"
        crown_d2 = guiana_tree_data[tree_data_key]['crown_d2']
        tree_height_value = guiana_tree_data[tree_data_key]['tree_height']
        ratio_value = 2*crown_d2 / tree_height_value
        all_ratio_values.append(ratio_value)
    
    # Plot histogram for all crown_d2 values in the current circle
    x_min = min(all_ratio_values)
    x_max = max(all_ratio_values)
    x_range = x_max - x_min
    bar_width = x_range / 18  # Adjust divisor as needed
    axs_flat[i].hist(all_ratio_values, bins=10, color='blue', alpha=0.7, width=bar_width)  # Adjust width here
    axs_flat[i].set_title(circle_name)
    axs_flat[i].set_xlabel('Crown Width to Tree Height Ratio')
    axs_flat[i].set_ylabel('Count')


# Set the suptitle and adjust layout
plt.suptitle('French Guiana Crown Width to Tree Height Ratio Count', x=0.5, y=0.95, fontsize=36)  # Adjust the y-coordinate here

# Adjust the bottom margin to leave space for the title
plt.subplots_adjust(top=0.9, bottom=0.1, left=0.03, right=0.97, hspace=0.25, wspace=0.2)

# Save the figure as a PNG image to the output folder
output_file_path = os.path.join(guiana_output_folder, "guiana_cr_width_tree_h_ratio_count.png")
plt.savefig(output_file_path)

plt.show()


### Redwood Crown Depth to Tree Height Ratio

# Initialize list to store crown_d1/tree_height ratios
crown_d1_tree_height_ratios = []

# Iterate over each tree's data
for tree_data in guiana_tree_data.values():
    crown_d1 = tree_data.get('crown_d1')
    tree_height = tree_data.get('tree_height')

    crown_d1_tree_height_ratio = crown_d1 / tree_height
    crown_d1_tree_height_ratios.append(crown_d1_tree_height_ratio)

# Plot histogram
plt.figure(figsize=(18, 12))
x_min = min(crown_d1_tree_height_ratios)
x_max = max(crown_d1_tree_height_ratios)
x_range = x_max - x_min
bar_width = x_range / 28  # Adjust divisor as needed
plt.hist(crown_d1_tree_height_ratios, bins=20, color='blue', alpha=0.7, width=bar_width)

plt.title('French Guiana \nCrown Depth to Tree Height Ratio Count')
plt.xlabel('Crown Depth / Tree Height')
plt.ylabel('Count')

# Save the figure as a PNG image to the output folder
output_file_path = os.path.join(guiana_output_folder, "guiana_cr_depth_tree_h_ratio_count.png")
plt.savefig(output_file_path)

plt.show()

### Redwood Crown Depth to Crown Width Ratio

# Initialize list to store crown_d1/tree_height ratios
crown_d1_crown_width_ratios = []

# Iterate over each tree's data
for tree_data in guiana_tree_data.values():
    crown_d1 = tree_data.get('crown_d1')
    crown_d2 = tree_data.get('crown_d2')

    crown_d1_crown_width_ratio = crown_d1 / (2 * crown_d2)
    crown_d1_crown_width_ratios.append(crown_d1_crown_width_ratio)

# Plot histogram
plt.figure(figsize=(18, 12))
x_min = min(crown_d1_crown_width_ratios)
x_max = max(crown_d1_crown_width_ratios)
x_range = x_max - x_min
bar_width = x_range / 28  # Adjust divisor as needed
plt.hist(crown_d1_crown_width_ratios, bins=20, color='blue', alpha=0.7, width=bar_width)

plt.title('French Guiana \nCrown Depth to Crown Width Ratio Count')
plt.xlabel('Crown Depth / Crown Width')
plt.ylabel('Count')

# Save the figure as a PNG image to the output folder
output_file_path = os.path.join(guiana_output_folder, "guiana_cr_depth_cr_width_ratio_metrics.png")
plt.savefig(output_file_path)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Initialize lists to store circle names, mean d1 values, and std d1 values
circle_names = []
mean_d1_values = []
std_d1_values = []
mean_d2_values = []
std_d2_values =[]
mean_crown_center_height =[]
std_crown_center_height = []
mean_tree_height = []
std_tree_height = []
LAI_per_pixel = []
Fa = []

# Iterate over each circle's data
for circle_name, data in guiana_circle_indices.items():
    # Append circle name to the list
    circle_names.append(circle_name)
    
    # Append mean and std d1 values to the lists
    mean_d1_values.append(data['mean_crown_d1'])
    std_d1_values.append(data['std_crown_d1'])
    mean_d2_values.append(data['mean_crown_d2'])
    std_d2_values.append(data['std_crown_d2'])
    mean_crown_center_height.append(data['mean_crown_center_height'])
    std_crown_center_height.append(data['std_crown_center_height'])

    mean_tree_height.append(data['mean_tree_height'])
    std_tree_height.append(data['std_tree_height'])
    LAI_per_pixel.append(data['LAI_per_pixel'])
    Fa.append(data['Fa'])

# Create subplots
fig, axs = plt.subplots(2, 3, figsize=(35, 24))

# Set global plot parameters
plt.rcParams['axes.titlesize'] = 24
plt.rcParams['axes.labelsize'] = 22
plt.rcParams['xtick.labelsize'] = 20
plt.rcParams['ytick.labelsize'] = 20

# Plot mean and std of d1 in the first subplot
axs[0, 0].bar(circle_names, mean_d1_values, yerr=std_d1_values, capsize=5)
axs[0, 0].set_title('Mean and Std of Vertical Crown Radius')
axs[0, 0].set_ylabel('d1 Values')

# Plot mean and std of d2 in the second subplot
axs[0, 1].bar(circle_names, mean_d2_values, yerr=std_d2_values, capsize=5)
axs[0, 1].set_title('Mean and Std of Horizontal Crown Radius')
axs[0, 1].set_ylabel('d2 Values')

# Plot mean and std of crown center height in the third subplot
axs[0, 2].bar(circle_names, mean_crown_center_height, yerr=std_crown_center_height, capsize=5)
axs[0, 2].set_title('Mean and Std of Crown Center Height')
axs[0, 2].set_ylabel('Crown Center Height Values')

# Plot mean and std of tree height in the fourth subplot
axs[1, 0].bar(circle_names, mean_tree_height, yerr=std_tree_height, capsize=5)
axs[1, 0].set_title('Mean and Std of Tree Height')
axs[1, 0].set_ylabel('Tree Height Values')

# Plot bar graph of LAI per pixel in the fifth subplot
axs[1, 1].bar(circle_names, LAI_per_pixel)
axs[1, 1].set_title('LAI per Unit Area')
axs[1, 1].set_ylabel('LAI per Pixel')

# Plot bar graph of Fa in the sixth subplot
axs[1, 2].bar(circle_names, Fa)
axs[1, 2].set_title('Fa')
axs[1, 2].set_ylabel('Fa Values')


# Rotate x-axis labels for better readability
for ax in axs.flat:
    ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha='right')

# Set the suptitle and adjust layout
plt.suptitle('French Guiana \nMean and Std Values', x=0.5, y=0.95, fontsize=36)  # Adjust the y-coordinate here

# Adjust the bottom margin to leave space for the title
plt.subplots_adjust(top=0.88, bottom=0.08, left=0.10, right=0.95, hspace=0.25, wspace=0.35)

# Save the figure as a PNG image to the output folder
output_file_path = os.path.join(guiana_output_folder, "guiana_mean_std_plots.png")
plt.savefig(output_file_path)

# Show the plot
plt.show()
# Out:
# C:\Users\allen\AppData\Local\Temp\ipykernel_12452\1394226523.py:77: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha='right')
# C:\Users\allen\AppData\Local\Temp\ipykernel_12452\1394226523.py:77: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha='right')
# C:\Users\allen\AppData\Local\Temp\ipykernel_12452\1394226523.py:77: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha='right')
# C:\Users\allen\AppData\Local\Temp\ipykernel_12452\1394226523.py:77: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha='right')
# C:\Users\allen\AppData\Local\Temp\ipykernel_12452\1394226523.py:77: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha='right')
# C:\Users\allen\AppData\Local\Temp\ipykernel_12452\1394226523.py:77: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha='right')
