# %%
from scipy import io as scipy_io
import os
import math
import numpy as np
import matplotlib.pyplot as plt
from IPython.utils import io as ipy_io
import sys
import re
import lidar_sim_class_declarations
import pickle


data_path = 'C:/Users/allen/OneDrive/Desktop/Work/Scripts/Lidar Simulation/lidarmodeling_202404'
output_path = 'C:/Users/allen/OneDrive/Desktop/Work/Scripts/Lidar Simulation/output_008/'
gort_output = 'C:/Users/allen/OneDrive/Desktop/Work/Scripts/Lidar Simulation/OrigGORTInput/'

data_version = '008'

redwood_file = 'rw_alltreeinfo.mat'
guiana_file = 'fg_alltreeinfo.mat'

redwood_filepath = os.path.normpath(os.path.join(data_path, 'RW' + data_version, redwood_file))
guiana_filepath = os.path.normpath(os.path.join(data_path, 'FG' + data_version, guiana_file))

redwood_mat_data = scipy_io.loadmat(redwood_filepath)
guiana_mat_data = scipy_io.loadmat(guiana_filepath)

radius = 33.3 / 2

# Leaf Density ratio
redwood_leaf_density_ratio = 2500  # Leaves per m3
guiana_leaf_density_ratio = 291.5  # Leaves per m3  Original 8750 number divided by 30 for more realistic density per m3

# %%
def circle_intersection_percentage(x1, y1, r1, x2, y2, r2):
    # Calculate the area of the first circle
    area1 = math.pi * r1**2
    
    # Calculate the distance between the centers of the circles
    d = math.sqrt((x2 - x1)**2 + (y2 - y1)**2)
    
    # Check if the circles are separate or one is completely inside the other
    if d >= r1 + r2:
        # Circles are separate, no intersection
        return 0
    elif d <= abs(r1 - r2) and r1 >= r2:
        # Circle 2 is completely inside circle 1, intersection area is area of circle 2
        return math.pi * r2**2 / area1 * 100
    elif d <= abs(r1 - r2) and r1 < r2:
        # Circle 1 is completely inside circle 2, intersection area is area of circle 1
        return 100
    else:
        # Calculate the intersection area using the formula for the area of a circular segment
        A = r1**2 * math.acos((d**2 + r1**2 - r2**2) / (2 * d * r1)) + r2**2 * math.acos((d**2 + r2**2 - r1**2) / (2 * d * r2)) - 0.5 * math.sqrt((-d + r1 + r2) * (d + r1 - r2) * (d - r1 + r2) * (d + r1 + r2))
        return A / area1 * 100
    
def load_matlab(region):
    if region == 'redwood':
        tree_elements = redwood_mat_data['tree'][0]
        x_values = redwood_mat_data['tree_x'][0]
        y_values = redwood_mat_data['tree_y'][0]
    elif region == 'guiana':
        tree_elements = guiana_mat_data['tree'][0]
        x_values = guiana_mat_data['tree_x'][0]
        y_values = guiana_mat_data['tree_y'][0]
    else:
        raise ValueError("Invalid region. Please specify either 'redwood' or 'guiana'.")

    return tree_elements, x_values, y_values

# This function creates and returns a list of Circle objects and assigns their name, and x_coord, y_coord
def create_circle_data(radius):

    circles_grid = []

    # Check each circle in the 3x3 grid
    for i in range(3, 0, -1):
        for j in range(1, 4):
            # Calculate the center of the current circle
            center_x = (j - 2) * 2 * radius
            center_y = (i - 2) * 2 * radius

            # Create the circle object with a unique name
            circle_name = f"Circle({i}, {j})"
            circle = lidar_sim_class_declarations.Circle(circle_name)

            # Assign the calculated coordinates to the circle
            circle.x_coord = center_x
            circle.y_coord = center_y
            circle.row = i
            circle.column = j

            # Append the circle to the grid list
            circles_grid.append(circle)

    return circles_grid

def calc_basic_tree_info(tree_index, tree_element, tree, x_values, y_values, site):

    # Extract crown base height, d1, d2, d3 value from tree data
    base = tree_element[0][0][0][0][0][0]
    d1 = tree_element[0][0][0][1][0][0]
    d2 = tree_element[0][0][0][2][0][0]
    d3 = tree_element[0][0][0][3][0][0]

    deciduous_volume = (4/3) * math.pi * d2**2 * d1
    pine_001_volume = ((2 * d2)**2 * d3) + deciduous_volume/2
    pine_002_volume = ((2 * d2)**2 * d3) + (1/3 * (2 * d2)**2 * d1)

    if (site == "redwood"):
        # Calculate the volume of the tree crown:  (rectangular prism vol) + (pyramid vol)  
        crown_volume = pine_002_volume
        # Calculate the Crown Center Height for each tree in the circle
        crown_center_height = (d1 + d3)/2
        # Calculate the Crown Base height
        crown_base_height = base
    elif (site == "guiana"):
        # Calculate the volume of the tree spheroid
        crown_volume = deciduous_volume
        # Calculate the Crown Center Height for each tree in the circle
        crown_center_height = base + (d3 / 2)
        # Calculate the Crown Base height
        crown_base_height = crown_center_height - d1

    # Calculate the Tree Height for each tree in the circle
    tree_height = base + d1 + (d3 / 2)
    # Calculate total ground area, just the area of circle with crown_radius d1
    total_tree_ground_areas = math.pi * d2**2

    # Extract leaf number, leaf width, tree leaf, calculate leaf area, then total leaf area
    single_leaf_length = tree_element[5][0][0][1][0][0]
    single_leaf_width = tree_element[5][0][0][2][0][0]
    single_leaf_area = single_leaf_length * single_leaf_width

    # Add basic info to each tree
    tree.tree_index = tree_index
    tree.crown_base = base
    tree.crown_d1 = d1
    tree.crown_d2 = d2
    tree.crown_d3 = d3

    tree.crown_volume = crown_volume
    tree.crown_center_height = crown_center_height
    tree.crown_base_height = crown_base_height
    tree.tree_height = tree_height
    tree.total_tree_ground_area = total_tree_ground_areas

    if (site == "redwood"):
        single_leaf_area *= 2  # redwoods:  assuming d2 or d3 are radius, so 2 * radius * length = area of rectangle cross section of leaf
    # if guiana:  assuming d1 is length, d2 is width, and d3 is thickness of leaf, width x length = area of leaf

    total_leaf_area = single_leaf_area * redwood_leaf_density_ratio * crown_volume
    tree.single_leaf_area = single_leaf_area
    tree.total_leaf_area = total_leaf_area

    total_branch_area = calc_basic_branch_info(tree_element)

    if (site == "redwood"):
        tree.leaf_density = redwood_leaf_density_ratio
        branch_scale = 0.01 # branch area divided by 100 for realism:  2000 primary branches and 4000 secondary branches per tree is ridiculous
        total_branch_area *= branch_scale
        tree.branch_scale = branch_scale
    elif (site =="guiana"):
        tree.leaf_density = guiana_leaf_density_ratio

    tree.total_tree_branch_area = total_branch_area

    tree_total_canopy_veg_areas = total_leaf_area + total_branch_area
    tree.total_tree_canopy_veg_area = tree_total_canopy_veg_areas

    # Assign x and y coordinates
    tree.x_coord = x_values[tree_index - 1]  # Adjusting for 1-based indexing
    tree.y_coord = y_values[tree_index - 1]

# This function gets the branch info from tree_element list and calculates and returns the total branch area
def calc_basic_branch_info(tree_element):

    # Initial values for total primary, secondary, and tertiary branch areas
    total_prim_branch_area = 0
    total_sec_branch_area = 0
    total_tert_branch_area = 0

    # For each tree, iterate through each primary branch array to get the total primary branch area
    for prim_branch_index in range(len(tree_element[2][0][0][0][0])):
        prim_branch_length = tree_element[2][0][0][0][0][prim_branch_index]
        prim_branch_radius = tree_element[2][0][0][1][0][prim_branch_index]
        prim_branch_area = 2 * prim_branch_radius * prim_branch_length
        total_prim_branch_area = total_prim_branch_area + prim_branch_area

    # for each tree, iterate through each secondary branch array to get the total secondary branch area
    for sec_branch_index in range(len(tree_element[3][0][0][0][0])):
        sec_branch_length = tree_element[3][0][0][0][0][sec_branch_index]
        sec_branch_radius = tree_element[3][0][0][1][0][sec_branch_index]
        sec_branch_area = 2 * sec_branch_radius * sec_branch_length
        total_sec_branch_area = total_sec_branch_area + sec_branch_area    
    
    # for each tree, iterate through each tertiary branch array to get the total tertiary branch area
    for tert_branch_index in range(len(tree_element[4][0][0][0][0])):
        tert_branch_length = tree_element[4][0][0][0][0][tert_branch_index]
        tert_branch_radius = tree_element[4][0][0][1][0][tert_branch_index]
        tert_branch_area = 2 * tert_branch_radius * tert_branch_length
        total_tert_branch_area = total_tert_branch_area + tert_branch_area

    total_branch_area = (total_prim_branch_area + total_sec_branch_area + total_tert_branch_area) # adjusted for realism

    return(total_branch_area)

# This function attempts to find a single tree object in the list of circle objects
def find_tree_in_circle(tree, circle_objects):

    # Flag to indicate whether the point falls within a circle
    circle_within_grid = False

    # Iterates through list of circle objects
    for circle in circle_objects:

        # Calculate the distance of the tree x,y coord from the center x,y coord of the Circle
        dist = math.sqrt((circle.x_coord - tree.x_coord)**2 + (circle.y_coord - tree.y_coord)**2)

        # Check if the distance is less than or equal to the radius
        if dist <= radius + tree.crown_d2:
            print(f'Tree {tree.tree_index} at {tree.x_coord}, {tree.y_coord} found in: Circle({circle.row}, {circle.column})')

            # Calculate the volume of the intersection between the tree and the circle
            intersection_percentage = circle_intersection_percentage(tree.x_coord, tree.y_coord, tree.crown_d2, circle.x_coord, circle.y_coord, radius) / 100
            intersection_volume = tree.crown_volume * intersection_percentage
            print(f'\tTree {tree.tree_index} crown volume is: {tree.crown_volume}')
            print(f'\tTree {tree.tree_index} intersection percentage with Circle ({circle.row}, {circle.column}) is: {intersection_percentage}')
            print(f'\tApprox. Tree {tree.tree_index} intersection volume with Circle ({circle.row}, {circle.column} is: {intersection_volume}\n')


            # Add tree index, crown percentage and intersection volume to circle object
            circle.tree_indices = np.append(circle.tree_indices, tree.tree_index)
            circle.crown_percentages = np.append(circle.crown_percentages, intersection_percentage)
            circle.crown_vol_in_circle = np.append(circle.crown_vol_in_circle, intersection_volume)

            circle_within_grid = True  # Set flag to True

    # If the tree is not found within any circle, print the message
    if not circle_within_grid:
        print(f'Tree {tree.tree_index} at {tree.x_coord}, {tree.y_coord} with radius {tree.crown_d2} not found within any grid circle!\n')

def plot_trees(tree_objects, circle_objects, region):
    # Set the figure size
    plt.figure(figsize=(20, 20))

    plt.rcParams['axes.titlesize'] = 36
    plt.rcParams['axes.labelsize'] = 15
    plt.rcParams['xtick.labelsize'] = 20
    plt.rcParams['ytick.labelsize'] = 15

    # Create a scatter plot for each tree
    for index, tree in enumerate(tree_objects, start=1):
        x, y = tree.x_coord, tree.y_coord
        d2 = tree.crown_d2  # Assuming tree has an attribute d2 for crown diameter
        plt.scatter(x, y, color='black', marker='o')  # Black dot for tree
        
        # Draw green circle around the tree with radius equal to d2
        circle = plt.Circle((x, y), d2, color='green', fill=False, linestyle='--', linewidth=1.5)
        plt.gca().add_artist(circle)

        # Add text label for the tree index slightly below the point
        plt.text(x, y - 1.5, str(index), ha='center', va='center', fontsize=12)  # Adjust fontsize and offset as needed

    # Plot the circles and label them
    for circle in circle_objects:
        center_x, center_y = circle.x_coord, circle.y_coord
        circle_artist = plt.Circle((center_x, center_y), radius, color='red', fill=False)
        plt.gca().add_artist(circle_artist)
        plt.text(center_x, center_y, f'({circle.row}, {circle.column})', ha='center', va='center', fontsize=12, color='red')  # Adjust fontsize as needed

    # Add labels, title, etc. if required
    plt.xlabel('X')
    plt.ylabel('Y')
    if region == 'redwood':
        plt.title('Scatter Plot of Trees with Circle Plots \n(with 33.3m diameter) in California Redwoods')
    elif region == 'guiana':
        plt.title('Scatter Plot of Trees with Circle Plots \n(with 33.3m diameter) in French Guiana')

    # Set equal aspect ratio
    plt.gca().set_aspect('equal', adjustable='box')

    # Save the plot
    plt.savefig(output_path + region + '_trees_plots.png')

    # Show the plot
    plt.show()

def save_objects_to_file(objects_list, filename, subfolder=""):
    # Create the subfolder if it doesn't exist
    if subfolder:
        os.makedirs(subfolder, exist_ok=True)
        filename = os.path.join(subfolder, filename)
        
    # Save the objects to file
    with open(filename, 'wb') as f:
        pickle.dump(objects_list, f)

def load_objects_from_file(filename, subfolder=""):
    # Adjust the filename to include the subfolder
    if subfolder:
        filename = os.path.join(subfolder, filename)
        
    # Load the objects from file
    with open(filename, 'rb') as f:
        objects_list = pickle.load(f)
    
    return objects_list

# %%
### This block assigns California Redwoods tree and circle data and plots and outputs the overhead visual representation of the site

# Redirecting stdout to a text file
output_file = output_path + 'redwood_tree_search_output_class.txt'

# Create the output directory if it doesn't exist
if not os.path.exists(output_path):
    os.makedirs(output_path)

# Specify region to California Redwoods
region = 'redwood'

# Initialize list of Tree objects
redwood_tree_objects = []

# Initilizes list of Circle objects for Redwood site.  Circles are assigned names and x_coord and y_coord
redwood_circle_objects = create_circle_data(radius)

# Use %%capture to capture output
with ipy_io.capture_output() as captured_output:

    # Load matlab data into lists
    redwood_tree_elements, redwood_x_values, redwood_y_values = load_matlab(region)
    # Get total tree count
    total_trees = len(redwood_x_values)

    # Loop interates through all trees
    for tree_index, (x, y, tree_element) in enumerate(zip(redwood_x_values, redwood_y_values, redwood_tree_elements), start=1):

        # Declare Tree object
        tree = lidar_sim_class_declarations.Tree(tree_index)
        print(f"Processing tree {tree_index} of {total_trees}")

        # Calls functions to assign basic tree info, then find tree in any of the cirlces
        calc_basic_tree_info(tree_index, tree_element, tree, redwood_x_values, redwood_y_values, "redwood")
        find_tree_in_circle(tree, redwood_circle_objects)

        # Append the Tree object to the list
        redwood_tree_objects.append(tree)

# Writes captured output to file
with open(output_file, "w") as file:
    file.write(captured_output.stdout)

print("California Redwood Trees:")

for tree in redwood_tree_objects:
    print()
    tree.print_attributes()
print()

plot_trees(redwood_tree_objects, redwood_circle_objects, region)
# Out:
# California Redwood Trees:
#
# tree_index: 1
# x_coord: -58.22
# y_coord: 39.89
# crown_base: 6.53279
# crown_d1: 4.75503
# crown_d2: 2.70483
# crown_d3: 9.46251
# crown_base_height: 6.509015
# crown_center_height: 11.264045
# tree_height: 16.019075
# crown_volume: 145.72089163029327
# single_leaf_area: 6e-05
# total_leaf_area: 21.858133744543988
# total_tree_branch_area: 5.091073367371114
# total_tree_stem_area: 0
# total_tree_ground_area: 22.984222754161376
# total_tree_canopy_veg_area: 26.9492071119151
# leaf_density: 2500
# branch_scale: 0.01
#
# tree_index: 2
# x_coord: -58.43
# y_coord: 32.12
# crown_base: 7.02676
# crown_d1: 5.83397
# crown_d2: 3.09267
# crown_d3: 11.6096
# crown_base_height: 6.99759
# crown_center_height: 12.83156
# tree_height: 18.66553
# crown_volume: 233.732962642793
# single_leaf_area: 6e-05
# total_leaf_area: 35.05994439641895
# total_tree_branch_area: 8.083898341710007
# total_tree_stem_area: 0
# total_tree_ground_area: 30.048101375580398
# total_tree_canopy_veg_area: 43.14384273812895
# leaf_density: 2500
# branch_scale: 0.01
#
# tree_index: 3
# x_coord: -62.59
# y_coord: 25.39
# crown_base: 8.83017
# crown_d1: 6.46724
# crown_d2: 3.60917
# crown_d3: 12.8698
# crown_base_height: 8.797830000000001
# crown_center_height: 15.265070000000001
# tree_height: 21.732310000000002
# crown_volume: 352.87611615144175
# single_leaf_area: 6e-05
# total_leaf_area: 52.93141742271626
# total_tree_branch_area: 11.487972651560128
# total_tree_stem_area: 0
# total_tree_ground_area: 40.922725476954824
# total_tree_canopy_veg_area: 64.41939007427638
# leaf_density: 2500
# branch_scale: 0.01
#
# tree_index: 4
# x_coord: -66.96
# y_coord: 7.555
# crown_base: 10.6832
# crown_d1: 9.22597
# crown_d2: 4.76444
# crown_d3: 18.3597
# crown_base_height: 10.637080000000001
# crown_center_height: 19.86305
# tree_height: 29.089019999999998
# crown_volume: 877.2520093156226
# single_leaf_area: 6e-05
# total_leaf_area: 131.58780139734338
# total_tree_branch_area: 30.563438192944393
# total_tree_stem_area: 0
# total_tree_ground_area: 71.31380299163307
# total_tree_canopy_veg_area: 162.1512395902878
# leaf_density: 2500
# branch_scale: 0.01
#
# tree_index: 5
# x_coord: -35.2
# y_coord: 60.06
# crown_base: 6.96041
# crown_d1: 5.871
# crown_d2: 3.14531
# crown_d3: 11.6833
# crown_base_height: 6.93106
# crown_center_height: 12.80206
# tree_height: 18.67306
# crown_volume: 243.29187257714017
# single_leaf_area: 6e-05
# total_leaf_area: 36.493780886571024
# total_tree_branch_area: 8.320031082642599
# total_tree_stem_area: 0
# total_tree_ground_area: 31.07969756989527
# total_tree_canopy_veg_area: 44.813811969213624
# leaf_density: 2500
# branch_scale: 0.01
#
# tree_index: 6
# x_coord: -49.26
# y_coord: 45.81
# crown_base: 5.70719
# crown_d1: 4.64243
# crown_d2: 2.53781
# crown_d3: 9.23844
# crown_base_height: 5.683979999999999
# crown_center_height: 10.32641
# tree_height: 14.96884
# crown_volume: 125.24263090406058
# single_leaf_area: 6e-05
# total_leaf_area: 18.786394635609085
# total_tree_branch_area: 4.573583221356244
# total_tree_stem_area: 0
# total_tree_ground_area: 20.233363384702717
# total_tree_canopy_veg_area: 23.35997785696533
# leaf_density: 2500
# branch_scale: 0.01
#
# tree_index: 7
# x_coord: -50.29
# y_coord: 35.88
# crown_base: 9.69828
# crown_d1: 8.14329
# crown_d2: 4.29379
# crown_d3: 16.2051
# crown_base_height: 9.657540000000001
# crown_center_height: 17.80083
# tree_height: 25.94412
# crown_volume: 628.8833706166984
# single_leaf_area: 6e-05
# total_leaf_area: 94.33250559250475
# total_tree_branch_area: 21.133749877020964
# total_tree_stem_area: 0
# total_tree_ground_area: 57.920389420310926
# total_tree_canopy_veg_area: 115.4662554695257
# leaf_density: 2500
# branch_scale: 0.01
#
# tree_index: 8
# x_coord: -51.46
# y_coord: 13.73
# crown_base: 8.24998
# crown_d1: 6.87828
# crown_d2: 3.5683
# crown_d3: 13.6878
# crown_base_height: 8.2156
# crown_center_height: 15.09388
# tree_height: 21.972160000000002
# crown_volume: 366.85224426036694
# single_leaf_area: 6e-05
# total_leaf_area: 55.02783663905504
# total_tree_branch_area: 12.54485278570225
# total_tree_stem_area: 0
# total_tree_ground_area: 40.00116063831005
# total_tree_canopy_veg_area: 67.57268942475729
# leaf_density: 2500
# branch_scale: 0.01
#
# tree_index: 9
# x_coord: -61.64
# y_coord: 15.29
# crown_base: 9.57792
# crown_d1: 7.03964
# crown_d2: 3.66206
# crown_d3: 14.0089
# crown_base_height: 9.54273
# crown_center_height: 16.58237
# tree_height: 23.622010000000003
# crown_volume: 395.4485348800193
# single_leaf_area: 6e-05
# total_leaf_area: 59.31728023200289
# total_tree_branch_area: 13.557855254255507
# total_tree_stem_area: 0
# total_tree_ground_area: 42.130904586032024
# total_tree_canopy_veg_area: 72.87513548625839
# leaf_density: 2500
# branch_scale: 0.01
#
# tree_index: 10
# x_coord: -51.77
# y_coord: 5.978
# crown_base: 11.3746
# crown_d1: 10.6741
# crown_d2: 6.1011
# crown_d3: 21.2415
# crown_base_height: 11.32125
# crown_center_height: 21.99535
# tree_height: 32.66945
# crown_volume: 1664.3174364922547
# single_leaf_area: 6e-05
# total_leaf_area: 249.6476154738382
# total_tree_branch_area: 54.489987217449034
# total_tree_stem_area: 0
# total_tree_ground_area: 116.94082661481448
# total_tree_canopy_veg_area: 304.1376026912872
# leaf_density: 2500
# branch_scale: 0.01
#
# tree_index: 11
# x_coord: -59.63
# y_coord: 2.718
# crown_base: 7.55293
# crown_d1: 6.03233
# crown_d2: 3.00646
# crown_d3: 12.0043
# crown_base_height: 7.52275
# crown_center_height: 13.55508
# tree_height: 19.58741
# crown_volume: 228.39393189356835
# single_leaf_area: 6e-05
# total_leaf_area: 34.259089784035254
# total_tree_branch_area: 8.253005162386735
# total_tree_stem_area: 0
# total_tree_ground_area: 28.396233117249267
# total_tree_canopy_veg_area: 42.51209494642199
# leaf_density: 2500
# branch_scale: 0.01
#
# tree_index: 12
# x_coord: -68.14
# y_coord: -9.824
# crown_base: 9.58971
# crown_d1: 7.31865
# crown_d2: 3.80731
# crown_d3: 14.5641
# crown_base_height: 9.553110000000002
# crown_center_height: 16.871760000000002
# tree_height: 24.19041
# crown_volume: 444.38159837007964
# single_leaf_area: 6e-05
# total_leaf_area: 66.65723975551194
# total_tree_branch_area: 15.226321596044372
# total_tree_stem_area: 0
# total_tree_ground_area: 45.53930011375865
# total_tree_canopy_veg_area: 81.88356135155631
# leaf_density: 2500
# branch_scale: 0.01
#
# tree_index: 13
# x_coord: -26.26
# y_coord: 61.99
# crown_base: 13.4838
# crown_d1: 11.5723
# crown_d2: 7.06886
# crown_d3: 23.0288
# crown_base_height: 13.4259
# crown_center_height: 24.9982
# tree_height: 36.5705
# crown_volume: 2422.1835704191735
# single_leaf_area: 6e-05
# total_leaf_area: 363.327535562876
# total_tree_branch_area: 79.4952263899261
# total_tree_stem_area: 0
# total_tree_ground_area: 156.98155749629547
# total_tree_canopy_veg_area: 442.8227619528021
# leaf_density: 2500
# branch_scale: 0.01
#
# tree_index: 14
# x_coord: -26.89
# y_coord: 53.0
# crown_base: 9.9569
# crown_d1: 8.05949
# crown_d2: 4.1094
# crown_d3: 16.0384
# crown_base_height: 9.916609999999999
# crown_center_height: 17.9761
# tree_height: 26.03559
# crown_volume: 570.1025758575894
# single_leaf_area: 6e-05
# total_leaf_area: 85.51538637863841
# total_tree_branch_area: 19.831864960319646
# total_tree_stem_area: 0
# total_tree_ground_area: 53.05260405971
# total_tree_canopy_veg_area: 105.34725133895806
# leaf_density: 2500
# branch_scale: 0.01
#
# tree_index: 15
# x_coord: -39.56
# y_coord: 50.55
# crown_base: 7.05662
# crown_d1: 6.06171
# crown_d2: 3.01703
# crown_d3: 12.0628
# crown_base_height: 7.0263100000000005
# crown_center_height: 13.08802
# tree_height: 19.149729999999998
# crown_volume: 231.12292326994017
# single_leaf_area: 6e-05
# total_leaf_area: 34.66843849049103
# total_tree_branch_area: 8.356307414008025
# total_tree_stem_area: 0
# total_tree_ground_area: 28.596252947180773
# total_tree_canopy_veg_area: 43.024745904499056
# leaf_density: 2500
# branch_scale: 0.01
#
# tree_index: 16
# x_coord: -41.96
# y_coord: 42.78
# crown_base: 8.63072
# crown_d1: 7.56117
# crown_d2: 3.96548
# crown_d3: 15.0467
# crown_base_height: 8.5929
# crown_center_height: 16.15407
# tree_height: 23.71524
# crown_volume: 498.04563654752224
# single_leaf_area: 6e-05
# total_leaf_area: 74.70684548212833
# total_tree_branch_area: 16.67284644017131
# total_tree_stem_area: 0
# total_tree_ground_area: 49.40164384753176
# total_tree_canopy_veg_area: 91.37969192229964
# leaf_density: 2500
# branch_scale: 0.01
#
# tree_index: 17
# x_coord: -42.17
# y_coord: 32.35
# crown_base: 8.74214
# crown_d1: 7.61851
# crown_d2: 3.97536
# crown_d3: 15.1608
# crown_base_height: 8.70403
# crown_center_height: 16.32254
# tree_height: 23.94105
# crown_volume: 504.3262554621003
# single_leaf_area: 6e-05
# total_leaf_area: 75.64893831931504
# total_tree_branch_area: 16.989903796749996
# total_tree_stem_area: 0
# total_tree_ground_area: 49.6481190674522
# total_tree_canopy_veg_area: 92.63884211606504
# leaf_density: 2500
# branch_scale: 0.01
#
# tree_index: 18
# x_coord: -52.92
# y_coord: 25.55
# crown_base: 6.48818
# crown_d1: 4.96936
# crown_d2: 2.67946
# crown_d3: 9.88902
# crown_base_height: 6.463330000000001
# crown_center_height: 11.432690000000001
# tree_height: 16.40205
# crown_volume: 149.4457694469526
# single_leaf_area: 6e-05
# total_leaf_area: 22.41686541704289
# total_tree_branch_area: 5.355284315061361
# total_tree_stem_area: 0
# total_tree_ground_area: 22.5550829654552
# total_tree_canopy_veg_area: 27.77214973210425
# leaf_density: 2500
# branch_scale: 0.01
#
# tree_index: 19
# x_coord: -43.3
# y_coord: 21.32
# crown_base: 7.52831
# crown_d1: 6.07214
# crown_d2: 3.12049
# crown_d3: 12.0836
# crown_base_height: 7.49797
# crown_center_height: 13.57011
# tree_height: 19.64225
# crown_volume: 247.67146656176027
# single_leaf_area: 6e-05
# total_leaf_area: 37.150719984264036
# total_tree_branch_area: 8.710597649715107
# total_tree_stem_area: 0
# total_tree_ground_area: 30.5911260150985
# total_tree_canopy_veg_area: 45.86131763397914
# leaf_density: 2500
# branch_scale: 0.01
#
# tree_index: 20
# x_coord: -43.62
# y_coord: 12.71
# crown_base: 16.2975
# crown_d1: 12.7221
# crown_d2: 9.39988
# crown_d3: 25.3171
# crown_base_height: 16.23395
# crown_center_height: 28.956049999999998
# tree_height: 41.678149999999995
# crown_volume: 4708.602544949128
# single_leaf_area: 6e-05
# total_leaf_area: 706.2903817423692
# total_tree_branch_area: 158.85783914922243
# total_tree_stem_area: 0
# total_tree_ground_area: 277.58403948340657
# total_tree_canopy_veg_area: 865.1482208915916
# leaf_density: 2500
# branch_scale: 0.01
#
# tree_index: 21
# x_coord: -52.65
# y_coord: -2.669
# crown_base: 9.04842
# crown_d1: 7.33345
# crown_d2: 3.83872
# crown_d3: 14.5936
# crown_base_height: 9.011770000000002
# crown_center_height: 16.34522
# tree_height: 23.67867
# crown_volume: 452.65759889446764
# single_leaf_area: 6e-05
# total_leaf_area: 67.89863983417014
# total_tree_branch_area: 15.314839401617485
# total_tree_stem_area: 0
# total_tree_ground_area: 46.29379066753721
# total_tree_canopy_veg_area: 83.21347923578763
# leaf_density: 2500
# branch_scale: 0.01
#
# tree_index: 22
# x_coord: -60.31
# y_coord: -6.3
# crown_base: 7.20579
# crown_d1: 5.29175
# crown_d2: 2.82011
# crown_d3: 10.5306
# crown_base_height: 7.17934
# crown_center_height: 12.47109
# tree_height: 17.76284
# crown_volume: 176.28689354804922
# single_leaf_area: 6e-05
# total_leaf_area: 26.443034032207382
# total_tree_branch_area: 6.240006651844126
# total_tree_stem_area: 0
# total_tree_ground_area: 24.985150500503032
# total_tree_canopy_veg_area: 32.683040684051505
# leaf_density: 2500
# branch_scale: 0.01
#
# tree_index: 23
# x_coord: -19.3
# y_coord: 67.05
# crown_base: 15.2322
# crown_d1: 12.8783
# crown_d2: 8.66529
# crown_d3: 25.6279
# crown_base_height: 15.167850000000001
# crown_center_height: 28.04615
# tree_height: 40.92445
# crown_volume: 4050.543966724451
# single_leaf_area: 6e-05
# total_leaf_area: 607.5815950086676
# total_tree_branch_area: 140.95745394163498
# total_tree_stem_area: 0
# total_tree_ground_area: 235.893555441583
# total_tree_canopy_veg_area: 748.5390489503026
# leaf_density: 2500
# branch_scale: 0.01
#
# tree_index: 24
# x_coord: -18.51
# y_coord: 57.44
# crown_base: 14.4804
# crown_d1: 13.0658
# crown_d2: 8.7423
# crown_d3: 26.0009
# crown_base_height: 14.41505
# crown_center_height: 27.48085
# tree_height: 40.54665
# crown_volume: 4182.8859819314575
# single_leaf_area: 6e-05
# total_leaf_area: 627.4328972897187
# total_tree_branch_area: 144.94663128759464
# total_tree_stem_area: 0
# total_tree_ground_area: 240.10504419542573
# total_tree_canopy_veg_area: 772.3795285773133
# leaf_density: 2500
# branch_scale: 0.01
#
# tree_index: 25
# x_coord: -10.95
# y_coord: 46.43
# crown_base: 7.03601
# crown_d1: 5.51326
# crown_d2: 3.07494
# crown_d3: 10.9714
# crown_base_height: 7.008449999999999
# crown_center_height: 12.521709999999999
# tree_height: 18.03497
# crown_volume: 218.358637194232
# single_leaf_area: 6e-05
# total_leaf_area: 32.753795579134795
# total_tree_branch_area: 7.3609047759976685
# total_tree_stem_area: 0
# total_tree_ground_area: 29.70456279872054
# total_tree_canopy_veg_area: 40.11470035513246
# leaf_density: 2500
# branch_scale: 0.01
#
# tree_index: 26
# x_coord: -19.75
# y_coord: 44.52
# crown_base: 8.51181
# crown_d1: 7.69118
# crown_d2: 3.80068
# crown_d3: 15.3055
# crown_base_height: 8.473380000000002
# crown_center_height: 16.16456
# tree_height: 23.85574
# crown_volume: 465.3762286247591
# single_leaf_area: 6e-05
# total_leaf_area: 69.80643429371386
# total_tree_branch_area: 16.416714016010445
# total_tree_stem_area: 0
# total_tree_ground_area: 45.3808351213428
# total_tree_canopy_veg_area: 86.22314830972431
# leaf_density: 2500
# branch_scale: 0.01
#
# tree_index: 27
# x_coord: -32.01
# y_coord: 45.45
# crown_base: 10.1895
# crown_d1: 9.44878
# crown_d2: 5.12178
# crown_d3: 18.8031
# crown_base_height: 10.142270000000003
# crown_center_height: 19.591050000000003
# tree_height: 29.039830000000002
# crown_volume: 1038.2601522643822
# single_leaf_area: 6e-05
# total_leaf_area: 155.73902283965734
# total_tree_branch_area: 34.4008828672174
# total_tree_stem_area: 0
# total_tree_ground_area: 82.41223884970195
# total_tree_canopy_veg_area: 190.13990570687474
# leaf_density: 2500
# branch_scale: 0.01
#
# tree_index: 28
# x_coord: -35.98
# y_coord: 25.05
# crown_base: 7.68207
# crown_d1: 6.56095
# crown_d2: 3.50254
# crown_d3: 13.0563
# crown_base_height: 7.64927
# crown_center_height: 14.21022
# tree_height: 20.77117
# crown_volume: 337.1487430465854
# single_leaf_area: 6e-05
# total_leaf_area: 50.57231145698781
# total_tree_branch_area: 11.259721097561576
# total_tree_stem_area: 0
# total_tree_ground_area: 38.54038779215496
# total_tree_canopy_veg_area: 61.832032554549386
# leaf_density: 2500
# branch_scale: 0.01
#
# tree_index: 29
# x_coord: -35.85
# y_coord: 17.18
# crown_base: 10.4675
# crown_d1: 9.43915
# crown_d2: 5.06283
# crown_d3: 18.7839
# crown_base_height: 10.4203
# crown_center_height: 19.85945
# tree_height: 29.2986
# crown_volume: 1013.4636738985837
# single_leaf_area: 6e-05
# total_leaf_area: 152.01955108478754
# total_tree_branch_area: 34.045641935847115
# total_tree_stem_area: 0
# total_tree_ground_area: 80.52608078311478
# total_tree_canopy_veg_area: 186.06519302063464
# leaf_density: 2500
# branch_scale: 0.01
#
# tree_index: 30
# x_coord: -44.04
# y_coord: -0.0715
# crown_base: 8.71349
# crown_d1: 7.17077
# crown_d2: 3.60014
# crown_d3: 14.2698
# crown_base_height: 8.677620000000001
# crown_center_height: 15.84839
# tree_height: 23.01916
# crown_volume: 389.30786846728654
# single_leaf_area: 6e-05
# total_leaf_area: 58.39618027009298
# total_tree_branch_area: 13.672561883469806
# total_tree_stem_area: 0
# total_tree_ground_area: 40.71820757749376
# total_tree_canopy_veg_area: 72.06874215356278
# leaf_density: 2500
# branch_scale: 0.01
#
# tree_index: 31
# x_coord: -55.46
# y_coord: -12.51
# crown_base: 8.27629
# crown_d1: 7.24858
# crown_d2: 3.80628
# crown_d3: 14.4247
# crown_base_height: 8.24006
# crown_center_height: 15.48864
# tree_height: 22.73722
# crown_volume: 439.88890850011427
# single_leaf_area: 6e-05
# total_leaf_area: 65.98333627501714
# total_tree_branch_area: 14.743281425474605
# total_tree_stem_area: 0
# total_tree_ground_area: 45.514663751394856
# total_tree_canopy_veg_area: 80.72661770049174
# leaf_density: 2500
# branch_scale: 0.01
#
# tree_index: 32
# x_coord: -61.31
# y_coord: -17.92
# crown_base: 12.4462
# crown_d1: 10.0468
# crown_d2: 5.84473
# crown_d3: 19.9932
# crown_base_height: 12.395999999999999
# crown_center_height: 22.4428
# tree_height: 32.489599999999996
# crown_volume: 1437.6238639743044
# single_leaf_area: 6e-05
# total_leaf_area: 215.64357959614566
# total_tree_branch_area: 46.67215599470599
# total_tree_stem_area: 0
# total_tree_ground_area: 107.31953437718762
# total_tree_canopy_veg_area: 262.31573559085166
# leaf_density: 2500
# branch_scale: 0.01
#
# tree_index: 33
# x_coord: -53.73
# y_coord: -22.33
# crown_base: 7.37257
# crown_d1: 6.29264
# crown_d2: 3.20294
# crown_d3: 12.5224
# crown_base_height: 7.341129999999999
# crown_center_height: 13.633769999999998
# tree_height: 19.926409999999997
# crown_volume: 270.4077299399545
# single_leaf_area: 6e-05
# total_leaf_area: 40.56115949099317
# total_tree_branch_area: 9.516187473966438
# total_tree_stem_area: 0
# total_tree_ground_area: 32.22904813479968
# total_tree_canopy_veg_area: 50.07734696495961
# leaf_density: 2500
# branch_scale: 0.01
#
# tree_index: 34
# x_coord: -57.35
# y_coord: -30.19
# crown_base: 6.18283
# crown_d1: 5.356
# crown_d2: 2.74332
# crown_d3: 10.6584
# crown_base_height: 6.1560299999999994
# crown_center_height: 11.51203
# tree_height: 16.86803
# crown_volume: 168.84263336724484
# single_leaf_area: 6e-05
# total_leaf_area: 25.326395005086727
# total_tree_branch_area: 6.1593382126109155
# total_tree_stem_area: 0
# total_tree_ground_area: 23.64301251408395
# total_tree_canopy_veg_area: 31.485733217697643
# leaf_density: 2500
# branch_scale: 0.01
#
# tree_index: 35
# x_coord: -47.31
# y_coord: -32.36
# crown_base: 8.28893
# crown_d1: 6.04166
# crown_d2: 3.24871
# crown_d3: 12.0229
# crown_base_height: 8.25872
# crown_center_height: 14.30038
# tree_height: 20.34204
# crown_volume: 267.09562914427414
# single_leaf_area: 6e-05
# total_leaf_area: 40.06434437164112
# total_tree_branch_area: 9.104441730004064
# total_tree_stem_area: 0
# total_tree_ground_area: 33.15673537706618
# total_tree_canopy_veg_area: 49.16878610164518
# leaf_density: 2500
# branch_scale: 0.01
#
# tree_index: 36
# x_coord: -8.072
# y_coord: 57.81
# crown_base: 8.14651
# crown_d1: 7.08654
# crown_d2: 3.42492
# crown_d3: 14.1022
# crown_base_height: 8.111069999999998
# crown_center_height: 15.19761
# tree_height: 22.284149999999997
# crown_volume: 348.19594999294696
# single_leaf_area: 6e-05
# total_leaf_area: 52.22939249894204
# total_tree_branch_area: 12.621753333856276
# total_tree_stem_area: 0
# total_tree_ground_area: 36.8511237493488
# total_tree_canopy_veg_area: 64.85114583279832
# leaf_density: 2500
# branch_scale: 0.01
#
# tree_index: 37
# x_coord: -30.52
# y_coord: 31.71
# crown_base: 15.804
# crown_d1: 13.2214
# crown_d2: 9.39113
# crown_d3: 26.3107
# crown_base_height: 15.737950000000001
# crown_center_height: 28.95935
# tree_height: 42.180749999999996
# crown_volume: 4884.293564446398
# single_leaf_area: 6e-05
# total_leaf_area: 732.6440346669597
# total_tree_branch_area: 172.14228306719528
# total_tree_stem_area: 0
# total_tree_ground_area: 277.06749461742316
# total_tree_canopy_veg_area: 904.786317734155
# leaf_density: 2500
# branch_scale: 0.01
#
# tree_index: 38
# x_coord: -19.55
# y_coord: 14.86
# crown_base: 4.59547
# crown_d1: 3.76563
# crown_d2: 2.28351
# crown_d3: 7.4936
# crown_base_height: 4.576639999999999
# crown_center_height: 8.34227
# tree_height: 12.1079
# crown_volume: 82.24927721798196
# single_leaf_area: 6e-05
# total_leaf_area: 12.337391582697293
# total_tree_branch_area: 3.0784443583068346
# total_tree_stem_area: 0
# total_tree_ground_area: 16.38157703053313
# total_tree_canopy_veg_area: 15.415835941004127
# leaf_density: 2500
# branch_scale: 0.01
#
# tree_index: 39
# x_coord: -28.44
# y_coord: 21.97
# crown_base: 8.237
# crown_d1: 7.46358
# crown_d2: 3.75779
# crown_d3: 14.8525
# crown_base_height: 8.19967
# crown_center_height: 15.66325
# tree_height: 23.126829999999998
# crown_volume: 441.4696114560579
# single_leaf_area: 6e-05
# total_leaf_area: 66.22044171840868
# total_tree_branch_area: 15.292201751147275
# total_tree_stem_area: 0
# total_tree_ground_area: 44.362384886615196
# total_tree_canopy_veg_area: 81.51264346955595
# leaf_density: 2500
# branch_scale: 0.01
#
# tree_index: 40
# x_coord: -30.85
# y_coord: 10.57
# crown_base: 6.1068
# crown_d1: 5.03874
# crown_d2: 2.66158
# crown_d3: 10.0271
# crown_base_height: 6.08161
# crown_center_height: 11.12035
# tree_height: 16.15909
# crown_volume: 149.5166670592388
# single_leaf_area: 6e-05
# total_leaf_area: 22.427500058885823
# total_tree_branch_area: 5.435569098346863
# total_tree_stem_area: 0
# total_tree_ground_area: 22.255067793620853
# total_tree_canopy_veg_area: 27.863069157232687
# leaf_density: 2500
# branch_scale: 0.01
#
# tree_index: 41
# x_coord: -38.57
# y_coord: 6.612
# crown_base: 12.4073
# crown_d1: 11.2092
# crown_d2: 6.38919
# crown_d3: 22.3064
# crown_base_height: 12.351299999999998
# crown_center_height: 23.560499999999998
# tree_height: 34.7697
# crown_volume: 1916.7030500317414
# single_leaf_area: 6e-05
# total_leaf_area: 287.5054575047612
# total_tree_branch_area: 65.04294077140052
# total_tree_stem_area: 0
# total_tree_ground_area: 128.2453063130113
# total_tree_canopy_veg_area: 352.5483982761617
# leaf_density: 2500
# branch_scale: 0.01
#
# tree_index: 42
# x_coord: -46.38
# y_coord: -7.698
# crown_base: 5.90074
# crown_d1: 4.86883
# crown_d2: 2.52232
# crown_d3: 9.68897
# crown_base_height: 5.876395
# crown_center_height: 10.745225
# tree_height: 15.614055
# crown_volume: 129.75185854172813
# single_leaf_area: 6e-05
# total_leaf_area: 19.462778781259217
# total_tree_branch_area: 4.858027202742847
# total_tree_stem_area: 0
# total_tree_ground_area: 19.987120911244816
# total_tree_canopy_veg_area: 24.320805984002064
# leaf_density: 2500
# branch_scale: 0.01
#
# tree_index: 43
# x_coord: -37.19
# y_coord: -7.071
# crown_base: 9.07556
# crown_d1: 6.75589
# crown_d2: 3.75281
# crown_d3: 13.4442
# crown_base_height: 9.04177
# crown_center_height: 15.79766
# tree_height: 22.55355
# crown_volume: 398.5513948588473
# single_leaf_area: 6e-05
# total_leaf_area: 59.78270922882709
# total_tree_branch_area: 12.961305006270775
# total_tree_stem_area: 0
# total_tree_ground_area: 44.244880562610625
# total_tree_canopy_veg_area: 72.74401423509786
# leaf_density: 2500
# branch_scale: 0.01
#
# tree_index: 44
# x_coord: -45.63
# y_coord: -17.92
# crown_base: 7.38712
# crown_d1: 6.07885
# crown_d2: 3.26187
# crown_d3: 12.0969
# crown_base_height: 7.35672
# crown_center_height: 13.43557
# tree_height: 19.51442
# crown_volume: 270.9214137761169
# single_leaf_area: 6e-05
# total_leaf_area: 40.63821206641753
# total_tree_branch_area: 9.159013163514508
# total_tree_stem_area: 0
# total_tree_ground_area: 33.425904625395866
# total_tree_canopy_veg_area: 49.79722522993204
# leaf_density: 2500
# branch_scale: 0.01
#
# tree_index: 45
# x_coord: -38.1
# y_coord: -15.59
# crown_base: 7.6628
# crown_d1: 5.77475
# crown_d2: 2.96908
# crown_d3: 11.4918
# crown_base_height: 7.63395
# crown_center_height: 13.4087
# tree_height: 19.18345
# crown_volume: 213.23848873297834
# single_leaf_area: 6e-05
# total_leaf_area: 31.98577330994675
# total_tree_branch_area: 7.601906801213062
# total_tree_stem_area: 0
# total_tree_ground_area: 27.69450912156089
# total_tree_canopy_veg_area: 39.58768011115981
# leaf_density: 2500
# branch_scale: 0.01
#
# tree_index: 46
# x_coord: -39.94
# y_coord: -25.32
# crown_base: 7.3396
# crown_d1: 5.36381
# crown_d2: 2.82372
# crown_d3: 10.674
# crown_base_height: 7.312790000000001
# crown_center_height: 12.6766
# tree_height: 18.04041
# crown_volume: 179.1452323735551
# single_leaf_area: 6e-05
# total_leaf_area: 26.871784856033265
# total_tree_branch_area: 6.388109725308312
# total_tree_stem_area: 0
# total_tree_ground_area: 25.04915802016968
# total_tree_canopy_veg_area: 33.25989458134158
# leaf_density: 2500
# branch_scale: 0.01
#
# tree_index: 47
# x_coord: -42.04
# y_coord: -41.16
# crown_base: 6.6688
# crown_d1: 4.91711
# crown_d2: 2.76075
# crown_d3: 9.78504
# crown_base_height: 6.64421
# crown_center_height: 11.56132
# tree_height: 16.47843
# crown_volume: 156.98302551049412
# single_leaf_area: 6e-05
# total_leaf_area: 23.547453826574117
# total_tree_branch_area: 5.472821412972561
# total_tree_stem_area: 0
# total_tree_ground_area: 23.944404158717333
# total_tree_canopy_veg_area: 29.020275239546677
# leaf_density: 2500
# branch_scale: 0.01
#
# tree_index: 48
# x_coord: -54.12
# y_coord: -40.04
# crown_base: 10.7282
# crown_d1: 8.51048
# crown_d2: 4.5341
# crown_d3: 16.9359
# crown_base_height: 10.68567
# crown_center_height: 19.19615
# tree_height: 27.706629999999997
# crown_volume: 732.866471646347
# single_leaf_area: 6e-05
# total_leaf_area: 109.92997074695205
# total_tree_branch_area: 24.770538835413728
# total_tree_stem_area: 0
# total_tree_ground_area: 64.58505909593353
# total_tree_canopy_veg_area: 134.70050958236578
# leaf_density: 2500
# branch_scale: 0.01
#
# tree_index: 49
# x_coord: 3.454
# y_coord: 68.29
# crown_base: 8.19025
# crown_d1: 7.65839
# crown_d2: 3.64086
# crown_d3: 15.2402
# crown_base_height: 8.151959999999999
# crown_center_height: 15.81035
# tree_height: 23.46874
# crown_volume: 425.2399390768147
# single_leaf_area: 6e-05
# total_leaf_area: 63.78599086152221
# total_tree_branch_area: 15.500810217608763
# total_tree_stem_area: 0
# total_tree_ground_area: 41.644517229810845
# total_tree_canopy_veg_area: 79.28680107913097
# leaf_density: 2500
# branch_scale: 0.01
#
# tree_index: 50
# x_coord: -9.33
# y_coord: 66.01
# crown_base: 11.0449
# crown_d1: 8.04103
# crown_d2: 4.46436
# crown_d3: 16.0016
# crown_base_height: 11.00467
# crown_center_height: 19.0457
# tree_height: 27.086729999999996
# crown_volume: 671.3031858443563
# single_leaf_area: 6e-05
# total_leaf_area: 100.69547787665344
# total_tree_branch_area: 21.93940077351581
# total_tree_stem_area: 0
# total_tree_ground_area: 62.613544456775735
# total_tree_canopy_veg_area: 122.63487865016926
# leaf_density: 2500
# branch_scale: 0.01
#
# tree_index: 51
# x_coord: -23.22
# y_coord: 34.66
# crown_base: 10.0857
# crown_d1: 7.70034
# crown_d2: 3.95389
# crown_d3: 15.3237
# crown_base_height: 10.04721
# crown_center_height: 17.74755
# tree_height: 25.44789
# crown_volume: 504.25205434910595
# single_leaf_area: 6e-05
# total_leaf_area: 75.63780815236589
# total_tree_branch_area: 17.495502489455557
# total_tree_stem_area: 0
# total_tree_ground_area: 49.11329120036641
# total_tree_canopy_veg_area: 93.13331064182145
# leaf_density: 2500
# branch_scale: 0.01
#
# tree_index: 52
# x_coord: -9.953
# y_coord: 37.92
# crown_base: 7.47201
# crown_d1: 6.27257
# crown_d2: 3.24118
# crown_d3: 12.4824
# crown_base_height: 7.44064
# crown_center_height: 13.71321
# tree_height: 19.98578
# crown_volume: 276.0199206510645
# single_leaf_area: 6e-05
# total_leaf_area: 41.40298809765968
# total_tree_branch_area: 9.592019349889766
# total_tree_stem_area: 0
# total_tree_ground_area: 33.00320928874423
# total_tree_canopy_veg_area: 50.99500744754945
# leaf_density: 2500
# branch_scale: 0.01
#
# tree_index: 53
# x_coord: -20.51
# y_coord: 26.96
# crown_base: 8.99153
# crown_d1: 7.33505
# crown_d2: 3.98385
# crown_d3: 14.5967
# crown_base_height: 8.954830000000001
# crown_center_height: 16.28988
# tree_height: 23.62493
# crown_volume: 487.638115095012
# single_leaf_area: 6e-05
# total_leaf_area: 73.1457172642518
# total_tree_branch_area: 15.965565484505849
# total_tree_stem_area: 0
# total_tree_ground_area: 49.86040808464278
# total_tree_canopy_veg_area: 89.11128274875765
# leaf_density: 2500
# branch_scale: 0.01
#
# tree_index: 54
# x_coord: -13.52
# y_coord: 22.7
# crown_base: 6.48572
# crown_d1: 4.81341
# crown_d2: 2.72788
# crown_d3: 9.57869
# crown_base_height: 6.4616549999999995
# crown_center_height: 11.275065
# tree_height: 16.088475
# crown_volume: 150.034794786012
# single_leaf_area: 6e-05
# total_leaf_area: 22.505219217901796
# total_tree_branch_area: 5.227498985200363
# total_tree_stem_area: 0
# total_tree_ground_area: 23.377625444229555
# total_tree_canopy_veg_area: 27.73271820310216
# leaf_density: 2500
# branch_scale: 0.01
#
# tree_index: 55
# x_coord: -21.65
# y_coord: 7.308
# crown_base: 6.62146
# crown_d1: 5.48584
# crown_d2: 2.83805
# crown_d3: 10.9168
# crown_base_height: 6.59402
# crown_center_height: 12.07986
# tree_height: 17.5657
# crown_volume: 185.08525902147184
# single_leaf_area: 6e-05
# total_leaf_area: 27.762788853220776
# total_tree_branch_area: 6.650761758450559
# total_tree_stem_area: 0
# total_tree_ground_area: 25.30404537246874
# total_tree_canopy_veg_area: 34.41355061167133
# leaf_density: 2500
# branch_scale: 0.01
#
# tree_index: 56
# x_coord: -19.71
# y_coord: -0.5995
# crown_base: 7.34535
# crown_d1: 5.88513
# crown_d2: 2.97728
# crown_d3: 11.7114
# crown_base_height: 7.315919999999998
# crown_center_height: 13.201049999999999
# tree_height: 19.08618
# crown_volume: 218.51639649448958
# single_leaf_area: 6e-05
# total_leaf_area: 32.77745947417343
# total_tree_branch_area: 7.850339536848538
# total_tree_stem_area: 0
# total_tree_ground_area: 27.847693656872014
# total_tree_canopy_veg_area: 40.62779901102197
# leaf_density: 2500
# branch_scale: 0.01
#
# tree_index: 57
# x_coord: -30.47
# y_coord: 2.29
# crown_base: 12.1165
# crown_d1: 9.34061
# crown_d2: 5.31218
# crown_d3: 18.5878
# crown_base_height: 12.069790000000003
# crown_center_height: 21.410400000000003
# tree_height: 30.75101
# crown_volume: 1104.1025512922045
# single_leaf_area: 6e-05
# total_leaf_area: 165.61538269383067
# total_tree_branch_area: 36.12771739845106
# total_tree_stem_area: 0
# total_tree_ground_area: 88.65340844646693
# total_tree_canopy_veg_area: 201.74310009228174
# leaf_density: 2500
# branch_scale: 0.01
#
# tree_index: 58
# x_coord: -28.22
# y_coord: -5.292
# crown_base: 8.40269
# crown_d1: 6.51677
# crown_d2: 3.43639
# crown_d3: 12.9684
# crown_base_height: 8.37012
# crown_center_height: 14.886890000000001
# tree_height: 21.403660000000002
# crown_volume: 322.3486798087438
# single_leaf_area: 6e-05
# total_leaf_area: 48.35230197131157
# total_tree_branch_area: 10.985241526292885
# total_tree_stem_area: 0
# total_tree_ground_area: 37.098364658651114
# total_tree_canopy_veg_area: 59.33754349760446
# leaf_density: 2500
# branch_scale: 0.01
#
# tree_index: 59
# x_coord: -29.01
# y_coord: -15.89
# crown_base: 4.76054
# crown_d1: 4.21291
# crown_d2: 2.37348
# crown_d3: 8.3837
# crown_base_height: 4.7394799999999995
# crown_center_height: 8.95239
# tree_height: 13.165299999999998
# crown_volume: 99.41271707095272
# single_leaf_area: 6e-05
# total_leaf_area: 14.911907560642907
# total_tree_branch_area: 3.7227209053920514
# total_tree_stem_area: 0
# total_tree_ground_area: 17.697871021031673
# total_tree_canopy_veg_area: 18.634628466034957
# leaf_density: 2500
# branch_scale: 0.01
#
# tree_index: 60
# x_coord: -30.25
# y_coord: -23.89
# crown_base: 6.84385
# crown_d1: 5.14884
# crown_d2: 2.68185
# crown_d3: 10.2462
# crown_base_height: 6.818110000000001
# crown_center_height: 11.96695
# tree_height: 17.11579
# crown_volume: 155.1197058494238
# single_leaf_area: 6e-05
# total_leaf_area: 23.26795587741357
# total_tree_branch_area: 5.654270265120241
# total_tree_stem_area: 0
# total_tree_ground_area: 22.59533785999718
# total_tree_canopy_veg_area: 28.92222614253381
# leaf_density: 2500
# branch_scale: 0.01
#
# tree_index: 61
# x_coord: -30.56
# y_coord: -41.16
# crown_base: 7.78573
# crown_d1: 6.05248
# crown_d2: 3.09308
# crown_d3: 12.0444
# crown_base_height: 7.755449999999999
# crown_center_height: 13.807929999999999
# tree_height: 19.86041
# crown_volume: 242.55167492608848
# single_leaf_area: 6e-05
# total_leaf_area: 36.38275123891327
# total_tree_branch_area: 8.5933013075614
# total_tree_stem_area: 0
# total_tree_ground_area: 30.056068949350742
# total_tree_canopy_veg_area: 44.976052546474676
# leaf_density: 2500
# branch_scale: 0.01
#
# tree_index: 62
# x_coord: 0.09636
# y_coord: 60.4
# crown_base: 7.1046
# crown_d1: 6.5466
# crown_d2: 3.17631
# crown_d3: 13.0277
# crown_base_height: 7.0718499999999995
# crown_center_height: 13.61845
# tree_height: 20.16505
# crown_volume: 276.6624249661089
# single_leaf_area: 6e-05
# total_leaf_area: 41.49936374491634
# total_tree_branch_area: 10.050884873997942
# total_tree_stem_area: 0
# total_tree_ground_area: 31.695356173369646
# total_tree_canopy_veg_area: 51.55024861891428
# leaf_density: 2500
# branch_scale: 0.01
#
# tree_index: 63
# x_coord: 11.38
# y_coord: 58.78
# crown_base: 9.2063
# crown_d1: 7.73722
# crown_d2: 3.92752
# crown_d3: 15.3971
# crown_base_height: 9.167629999999999
# crown_center_height: 16.90485
# tree_height: 24.64207
# crown_volume: 499.9313430647258
# single_leaf_area: 6e-05
# total_leaf_area: 74.98970145970887
# total_tree_branch_area: 17.33908879957065
# total_tree_stem_area: 0
# total_tree_ground_area: 48.46036526020256
# total_tree_canopy_veg_area: 92.32879025927951
# leaf_density: 2500
# branch_scale: 0.01
#
# tree_index: 64
# x_coord: -2.36
# y_coord: 51.88
# crown_base: 8.24531
# crown_d1: 6.69599
# crown_d2: 3.54014
# crown_d3: 13.325
# crown_base_height: 8.21182
# crown_center_height: 14.90781
# tree_height: 21.6038
# crown_volume: 351.5153382410727
# single_leaf_area: 6e-05
# total_leaf_area: 52.727300736160906
# total_tree_branch_area: 11.872646429638253
# total_tree_stem_area: 0
# total_tree_ground_area: 39.37229650593931
# total_tree_canopy_veg_area: 64.59994716579916
# leaf_density: 2500
# branch_scale: 0.01
#
# tree_index: 65
# x_coord: -3.294
# y_coord: 43.66
# crown_base: 12.6156
# crown_d1: 9.87524
# crown_d2: 5.64965
# crown_d3: 19.6517
# crown_base_height: 12.566210000000003
# crown_center_height: 22.441450000000003
# tree_height: 32.31669
# crown_volume: 1320.3204684779828
# single_leaf_area: 6e-05
# total_leaf_area: 198.0480702716974
# total_tree_branch_area: 43.65413589018161
# total_tree_stem_area: 0
# total_tree_ground_area: 100.27506687012033
# total_tree_canopy_veg_area: 241.70220616187902
# leaf_density: 2500
# branch_scale: 0.01
#
# tree_index: 66
# x_coord: -9.326
# y_coord: 29.85
# crown_base: 4.78096
# crown_d1: 4.44159
# crown_d2: 2.50126
# crown_d3: 8.83877
# crown_base_height: 4.758755000000001
# crown_center_height: 9.200345
# tree_height: 13.641935
# crown_volume: 116.39779462132343
# single_leaf_area: 6e-05
# total_leaf_area: 17.459669193198515
# total_tree_branch_area: 4.268879981281587
# total_tree_stem_area: 0
# total_tree_ground_area: 19.65475110624632
# total_tree_canopy_veg_area: 21.7285491744801
# leaf_density: 2500
# branch_scale: 0.01
#
# tree_index: 67
# x_coord: -5.588
# y_coord: 21.64
# crown_base: 7.74929
# crown_d1: 6.9373
# crown_d2: 3.31674
# crown_d3: 13.8052
# crown_base_height: 7.71459
# crown_center_height: 14.65189
# tree_height: 21.58919
# crown_volume: 319.670044773351
# single_leaf_area: 6e-05
# total_leaf_area: 47.95050671600264
# total_tree_branch_area: 11.655967364447138
# total_tree_stem_area: 0
# total_tree_ground_area: 34.559920081301556
# total_tree_canopy_veg_area: 59.60647408044978
# leaf_density: 2500
# branch_scale: 0.01
#
# tree_index: 68
# x_coord: -11.74
# y_coord: 13.68
# crown_base: 6.19748
# crown_d1: 5.46644
# crown_d2: 2.90971
# crown_d3: 10.8782
# crown_base_height: 6.170139999999998
# crown_center_height: 11.636579999999999
# tree_height: 17.10302
# crown_volume: 193.86196397545794
# single_leaf_area: 6e-05
# total_leaf_area: 29.07929459631869
# total_tree_branch_area: 6.805546002846199
# total_tree_stem_area: 0
# total_tree_ground_area: 26.598018633990943
# total_tree_canopy_veg_area: 35.88484059916489
# leaf_density: 2500
# branch_scale: 0.01
#
# tree_index: 69
# x_coord: -7.313
# y_coord: -2.117
# crown_base: 5.26134
# crown_d1: 4.4475
# crown_d2: 2.49052
# crown_d3: 8.85053
# crown_base_height: 5.239105
# crown_center_height: 9.686605
# tree_height: 14.134104999999998
# crown_volume: 115.55390683101268
# single_leaf_area: 6e-05
# total_leaf_area: 17.3330860246519
# total_tree_branch_area: 4.228022188872283
# total_tree_stem_area: 0
# total_tree_ground_area: 19.486324929344466
# total_tree_canopy_veg_area: 21.561108213524186
# leaf_density: 2500
# branch_scale: 0.01
#
# tree_index: 70
# x_coord: -11.62
# y_coord: -11.57
# crown_base: 8.66551
# crown_d1: 6.66242
# crown_d2: 3.50992
# crown_d3: 13.2582
# crown_base_height: 8.632189999999998
# crown_center_height: 15.294609999999999
# tree_height: 21.95703
# crown_volume: 343.8072672036585
# single_leaf_area: 6e-05
# total_leaf_area: 51.57109008054878
# total_tree_branch_area: 11.717899008207823
# total_tree_stem_area: 0
# total_tree_ground_area: 38.70297135316355
# total_tree_canopy_veg_area: 63.2889890887566
# leaf_density: 2500
# branch_scale: 0.01
#
# tree_index: 71
# x_coord: -20.11
# y_coord: -11.82
# crown_base: 6.36801
# crown_d1: 4.71013
# crown_d2: 2.63356
# crown_d3: 9.37316
# crown_base_height: 6.344460000000001
# crown_center_height: 11.054590000000001
# tree_height: 15.76472
# crown_volume: 136.83838431068756
# single_leaf_area: 6e-05
# total_leaf_area: 20.525757646603132
# total_tree_branch_area: 4.853810450788963
# total_tree_stem_area: 0
# total_tree_ground_area: 21.788950248297958
# total_tree_canopy_veg_area: 25.379568097392095
# leaf_density: 2500
# branch_scale: 0.01
#
# tree_index: 72
# x_coord: -22.41
# y_coord: -23.0
# crown_base: 5.51354
# crown_d1: 4.51275
# crown_d2: 2.5904
# crown_d3: 8.98037
# crown_base_height: 5.490975
# crown_center_height: 10.003725
# tree_height: 14.516475
# crown_volume: 126.84213604162953
# single_leaf_area: 6e-05
# total_leaf_area: 19.02632040624443
# total_tree_branch_area: 4.515772174638456
# total_tree_stem_area: 0
# total_tree_ground_area: 21.08062756217875
# total_tree_canopy_veg_area: 23.542092580882887
# leaf_density: 2500
# branch_scale: 0.01
#
# tree_index: 73
# x_coord: -37.13
# y_coord: -33.5
# crown_base: 12.7772
# crown_d1: 11.1862
# crown_d2: 6.2903
# crown_d3: 22.2606
# crown_base_height: 12.7213
# crown_center_height: 23.9075
# tree_height: 35.0937
# crown_volume: 1854.0178291959369
# single_leaf_area: 6e-05
# total_leaf_area: 278.1026743793905
# total_tree_branch_area: 64.23089990076845
# total_tree_stem_area: 0
# total_tree_ground_area: 124.30614255930993
# total_tree_canopy_veg_area: 342.333574280159
# leaf_density: 2500
# branch_scale: 0.01
#
# tree_index: 74
# x_coord: -22.73
# y_coord: -40.87
# crown_base: 8.4858
# crown_d1: 7.44418
# crown_d2: 3.66649
# crown_d3: 14.8139
# crown_base_height: 8.44857
# crown_center_height: 15.89275
# tree_height: 23.336930000000002
# crown_volume: 419.18572507148247
# single_leaf_area: 6e-05
# total_leaf_area: 62.87785876072237
# total_tree_branch_area: 14.86415258586662
# total_tree_stem_area: 0
# total_tree_ground_area: 42.23289788849972
# total_tree_canopy_veg_area: 77.74201134658898
# leaf_density: 2500
# branch_scale: 0.01
#
# tree_index: 75
# x_coord: -40.42
# y_coord: -51.05
# crown_base: 8.41192
# crown_d1: 6.29398
# crown_d2: 3.39515
# crown_d3: 12.525
# crown_base_height: 8.38044
# crown_center_height: 14.674420000000001
# tree_height: 20.9684
# crown_volume: 303.9008401930017
# single_leaf_area: 6e-05
# total_leaf_area: 45.585126028950256
# total_tree_branch_area: 10.235889734592162
# total_tree_stem_area: 0
# total_tree_ground_area: 36.213275247895815
# total_tree_canopy_veg_area: 55.82101576354242
# leaf_density: 2500
# branch_scale: 0.01
#
# tree_index: 76
# x_coord: -49.12
# y_coord: -48.31
# crown_base: 7.93771
# crown_d1: 6.80264
# crown_d2: 3.52176
# crown_d3: 13.5373
# crown_base_height: 7.90372
# crown_center_height: 14.70636
# tree_height: 21.509
# crown_volume: 353.41551454797434
# single_leaf_area: 6e-05
# total_leaf_area: 53.01232718219615
# total_tree_branch_area: 12.074505476871177
# total_tree_stem_area: 0
# total_tree_ground_area: 38.96452493605141
# total_tree_canopy_veg_area: 65.08683265906733
# leaf_density: 2500
# branch_scale: 0.01
#
# tree_index: 77
# x_coord: -30.55
# y_coord: -55.22
# crown_base: 9.51243
# crown_d1: 8.18636
# crown_d2: 4.02643
# crown_d3: 16.2909
# crown_base_height: 9.471519999999998
# crown_center_height: 17.65788
# tree_height: 25.844240000000003
# crown_volume: 555.9295443803112
# single_leaf_area: 6e-05
# total_leaf_area: 83.38943165704667
# total_tree_branch_area: 19.897063187146195
# total_tree_stem_area: 0
# total_tree_ground_area: 50.93193535163777
# total_tree_canopy_veg_area: 103.28649484419287
# leaf_density: 2500
# branch_scale: 0.01
#
# tree_index: 78
# x_coord: 20.15
# y_coord: 66.75
# crown_base: 10.008
# crown_d1: 8.22584
# crown_d2: 4.32125
# crown_d3: 16.3694
# crown_base_height: 9.966859999999999
# crown_center_height: 18.1927
# tree_height: 26.41854
# crown_volume: 643.4097714543303
# single_leaf_area: 6e-05
# total_leaf_area: 96.51146571814955
# total_tree_branch_area: 21.775071363187685
# total_tree_stem_area: 0
# total_tree_ground_area: 58.66359284775145
# total_tree_canopy_veg_area: 118.28653708133723
# leaf_density: 2500
# branch_scale: 0.01
#
# tree_index: 79
# x_coord: 11.6
# y_coord: 67.29
# crown_base: 8.94453
# crown_d1: 8.34838
# crown_d2: 4.14915
# crown_d3: 16.6133
# crown_base_height: 8.902799999999997
# crown_center_height: 17.251179999999998
# tree_height: 25.599559999999997
# crown_volume: 602.0174636897522
# single_leaf_area: 6e-05
# total_leaf_area: 90.30261955346282
# total_tree_branch_area: 21.155618328509778
# total_tree_stem_area: 0
# total_tree_ground_area: 54.08391781007982
# total_tree_canopy_veg_area: 111.4582378819726
# leaf_density: 2500
# branch_scale: 0.01
#
# tree_index: 80
# x_coord: 19.8
# y_coord: 56.84
# crown_base: 7.39687
# crown_d1: 5.59783
# crown_d2: 2.88815
# crown_d3: 11.1397
# crown_base_height: 7.368889999999999
# crown_center_height: 12.966719999999999
# tree_height: 18.56455
# crown_volume: 195.59052161482822
# single_leaf_area: 6e-05
# total_leaf_area: 29.33857824222423
# total_tree_branch_area: 7.007831426775554
# total_tree_stem_area: 0
# total_tree_ground_area: 26.20531370390333
# total_tree_canopy_veg_area: 36.34640966899978
# leaf_density: 2500
# branch_scale: 0.01
#
# tree_index: 81
# x_coord: 6.065
# y_coord: 49.41
# crown_base: 7.3504
# crown_d1: 6.37147
# crown_d2: 3.3307
# crown_d3: 12.6792
# crown_base_height: 7.318529999999999
# crown_center_height: 13.69
# tree_height: 20.06147
# crown_volume: 296.0733283973412
# single_leaf_area: 6e-05
# total_leaf_area: 44.41099925960118
# total_tree_branch_area: 10.147659155955964
# total_tree_stem_area: 0
# total_tree_ground_area: 34.8514544207233
# total_tree_canopy_veg_area: 54.55865841555714
# leaf_density: 2500
# branch_scale: 0.01
#
# tree_index: 82
# x_coord: 10.87
# y_coord: 33.85
# crown_base: 4.11946
# crown_d1: 3.27927
# crown_d2: 2.05709
# crown_d3: 6.52574
# crown_base_height: 4.103059999999999
# crown_center_height: 7.38233
# tree_height: 10.6616
# crown_volume: 58.126258800478006
# single_leaf_area: 6e-05
# total_leaf_area: 8.7189388200717
# total_tree_branch_area: 2.2982531235620103
# total_tree_stem_area: 0
# total_tree_ground_area: 13.294024005451979
# total_tree_canopy_veg_area: 11.017191943633712
# leaf_density: 2500
# branch_scale: 0.01
#
# tree_index: 83
# x_coord: 7.727
# y_coord: 26.2
# crown_base: 8.172
# crown_d1: 7.20415
# crown_d2: 3.67665
# crown_d3: 14.3363
# crown_base_height: 8.136000000000001
# crown_center_height: 15.340150000000001
# tree_height: 22.5443
# crown_volume: 407.920878419065
# single_leaf_area: 6e-05
# total_leaf_area: 61.18813176285975
# total_tree_branch_area: 14.042716907892585
# total_tree_stem_area: 0
# total_tree_ground_area: 42.46728050003106
# total_tree_canopy_veg_area: 75.23084867075234
# leaf_density: 2500
# branch_scale: 0.01
#
# tree_index: 84
# x_coord: 1.297
# y_coord: 34.65
# crown_base: 6.34311
# crown_d1: 4.75891
# crown_d2: 2.65539
# crown_d3: 9.47022
# crown_base_height: 6.31931
# crown_center_height: 11.07822
# tree_height: 15.837129999999998
# crown_volume: 140.55708171930883
# single_leaf_area: 6e-05
# total_leaf_area: 21.08356225789632
# total_tree_branch_area: 4.987147512370474
# total_tree_stem_area: 0
# total_tree_ground_area: 22.151671557033357
# total_tree_canopy_veg_area: 26.070709770266795
# leaf_density: 2500
# branch_scale: 0.01
#
# tree_index: 85
# x_coord: 1.713
# y_coord: 14.92
# crown_base: 5.00438
# crown_d1: 4.11562
# crown_d2: 2.32542
# crown_d3: 8.19008
# crown_base_height: 4.9838000000000005
# crown_center_height: 9.09942
# tree_height: 13.215040000000002
# crown_volume: 93.22377494533788
# single_leaf_area: 6e-05
# total_leaf_area: 13.983566241800682
# total_tree_branch_area: 3.515467472327111
# total_tree_stem_area: 0
# total_tree_ground_area: 16.98840787269073
# total_tree_canopy_veg_area: 17.499033714127794
# leaf_density: 2500
# branch_scale: 0.01
#
# tree_index: 86
# x_coord: -1.777
# y_coord: 5.929
# crown_base: 7.22378
# crown_d1: 5.39151
# crown_d2: 2.78305
# crown_d3: 10.7291
# crown_base_height: 7.196819999999999
# crown_center_height: 12.58833
# tree_height: 17.97984
# crown_volume: 174.92063374992665
# single_leaf_area: 6e-05
# total_leaf_area: 26.238095062489
# total_tree_branch_area: 6.339078015287466
# total_tree_stem_area: 0
# total_tree_ground_area: 24.33278901688859
# total_tree_canopy_veg_area: 32.577173077776465
# leaf_density: 2500
# branch_scale: 0.01
#
# tree_index: 87
# x_coord: 7.86
# y_coord: 7.838
# crown_base: 7.17792
# crown_d1: 6.55546
# crown_d2: 3.39421
# crown_d3: 13.0454
# crown_base_height: 7.145160000000001
# crown_center_height: 13.70062
# tree_height: 20.25608
# crown_volume: 316.35099033093314
# single_leaf_area: 6e-05
# total_leaf_area: 47.45264854963997
# total_tree_branch_area: 10.855115416210827
# total_tree_stem_area: 0
# total_tree_ground_area: 36.19322560860715
# total_tree_canopy_veg_area: 58.307763965850796
# leaf_density: 2500
# branch_scale: 0.01
#
# tree_index: 88
# x_coord: -15.23
# y_coord: -19.28
# crown_base: 6.96335
# crown_d1: 5.52223
# crown_d2: 3.04579
# crown_d3: 10.9892
# crown_base_height: 6.93572
# crown_center_height: 12.45795
# tree_height: 17.98018
# crown_volume: 214.58680481509333
# single_leaf_area: 6e-05
# total_leaf_area: 32.188020722264
# total_tree_branch_area: 7.300403256747223
# total_tree_stem_area: 0
# total_tree_ground_area: 29.144042100984564
# total_tree_canopy_veg_area: 39.48842397901122
# leaf_density: 2500
# branch_scale: 0.01
#
# tree_index: 89
# x_coord: -14.34
# y_coord: -28.95
# crown_base: 9.42993
# crown_d1: 7.27807
# crown_d2: 4.04184
# crown_d3: 14.4834
# crown_base_height: 9.39356
# crown_center_height: 16.67163
# tree_height: 23.9497
# crown_volume: 498.03867922714204
# single_leaf_area: 6e-05
# total_leaf_area: 74.7058018840713
# total_tree_branch_area: 16.113911443982754
# total_tree_stem_area: 0
# total_tree_ground_area: 51.3225359773067
# total_tree_canopy_veg_area: 90.81971332805406
# leaf_density: 2500
# branch_scale: 0.01
#
# tree_index: 90
# x_coord: -24.54
# y_coord: -32.25
# crown_base: 8.03634
# crown_d1: 5.98014
# crown_d2: 3.10119
# crown_d3: 11.9005
# crown_base_height: 8.006450000000001
# crown_center_height: 13.98659
# tree_height: 19.96673
# crown_volume: 240.91104439522323
# single_leaf_area: 6e-05
# total_leaf_area: 36.13665665928348
# total_tree_branch_area: 8.437137348750692
# total_tree_stem_area: 0
# total_tree_ground_area: 30.21388852040545
# total_tree_canopy_veg_area: 44.57379400803417
# leaf_density: 2500
# branch_scale: 0.01
#
# tree_index: 91
# x_coord: -14.69
# y_coord: -37.11
# crown_base: 7.31167
# crown_d1: 5.37388
# crown_d2: 2.88029
# crown_d3: 10.694
# crown_base_height: 7.284790000000001
# crown_center_height: 12.65867
# tree_height: 18.03255
# crown_volume: 186.74501039469783
# single_leaf_area: 6e-05
# total_leaf_area: 28.011751559204672
# total_tree_branch_area: 6.553762256010778
# total_tree_stem_area: 0
# total_tree_ground_area: 26.062874086511677
# total_tree_canopy_veg_area: 34.56551381521545
# leaf_density: 2500
# branch_scale: 0.01
#
# tree_index: 92
# x_coord: -23.72
# y_coord: -48.72
# crown_base: 13.7299
# crown_d1: 10.3789
# crown_d2: 6.15716
# crown_d3: 20.6541
# crown_base_height: 13.67805
# crown_center_height: 24.05695
# tree_height: 34.43585
# crown_volume: 1648.1654864197242
# single_leaf_area: 6e-05
# total_leaf_area: 247.22482296295863
# total_tree_branch_area: 54.36327859789772
# total_tree_stem_area: 0
# total_tree_ground_area: 119.09972297784866
# total_tree_canopy_veg_area: 301.58810156085633
# leaf_density: 2500
# branch_scale: 0.01
#
# tree_index: 93
# x_coord: -22.08
# y_coord: -64.46
# crown_base: 11.7618
# crown_d1: 9.81195
# crown_d2: 5.59681
# crown_d3: 19.5258
# crown_base_height: 11.71275
# crown_center_height: 21.5247
# tree_height: 31.33665
# crown_volume: 1287.4342638557803
# single_leaf_area: 6e-05
# total_leaf_area: 193.11513957836704
# total_tree_branch_area: 41.981550889076
# total_tree_stem_area: 0
# total_tree_ground_area: 98.40813476340945
# total_tree_canopy_veg_area: 235.09669046744304
# leaf_density: 2500
# branch_scale: 0.01
#
# tree_index: 94
# x_coord: 26.0
# y_coord: 51.77
# crown_base: 6.95135
# crown_d1: 5.92222
# crown_d2: 3.03751
# crown_d3: 11.7852
# crown_base_height: 6.921729999999999
# crown_center_height: 12.84395
# tree_height: 18.766170000000002
# crown_volume: 228.88038677203872
# single_leaf_area: 6e-05
# total_leaf_area: 34.332058015805806
# total_tree_branch_area: 8.099542635843036
# total_tree_stem_area: 0
# total_tree_ground_area: 28.98580094610282
# total_tree_canopy_veg_area: 42.43160065164884
# leaf_density: 2500
# branch_scale: 0.01
#
# tree_index: 95
# x_coord: 14.58
# y_coord: 49.39
# crown_base: 12.3996
# crown_d1: 10.3834
# crown_d2: 5.92439
# crown_d3: 20.663
# crown_base_height: 12.347699999999998
# crown_center_height: 22.731099999999998
# tree_height: 33.1145
# crown_volume: 1526.565609595243
# single_leaf_area: 6e-05
# total_leaf_area: 228.98484143928644
# total_tree_branch_area: 50.88125158854128
# total_tree_stem_area: 0
# total_tree_ground_area: 110.26486576616833
# total_tree_canopy_veg_area: 279.86609302782773
# leaf_density: 2500
# branch_scale: 0.01
#
# tree_index: 96
# x_coord: 7.045
# y_coord: 41.65
# crown_base: 8.48943
# crown_d1: 7.39702
# crown_d2: 3.70153
# crown_d3: 14.7201
# crown_base_height: 8.452459999999999
# crown_center_height: 15.84948
# tree_height: 23.2465
# crown_volume: 424.5295735389367
# single_leaf_area: 6e-05
# total_leaf_area: 63.6794360308405
# total_tree_branch_area: 14.86091937394628
# total_tree_stem_area: 0
# total_tree_ground_area: 43.04397989382245
# total_tree_canopy_veg_area: 78.54035540478678
# leaf_density: 2500
# branch_scale: 0.01
#
# tree_index: 97
# x_coord: 22.36
# y_coord: 42.17
# crown_base: 10.0783
# crown_d1: 8.46124
# crown_d2: 4.56367
# crown_d3: 16.8379
# crown_base_height: 10.036010000000001
# crown_center_height: 18.49725
# tree_height: 26.958490000000005
# crown_volume: 738.1609882437691
# single_leaf_area: 6e-05
# total_leaf_area: 110.72414823656537
# total_tree_branch_area: 24.372753982186133
# total_tree_stem_area: 0
# total_tree_ground_area: 65.43021367823472
# total_tree_canopy_veg_area: 135.0969022187515
# leaf_density: 2500
# branch_scale: 0.01
#
# ...
# leaf_density: 2500
# branch_scale: 0.01
#
# tree_index: 157
# x_coord: 44.03
# y_coord: -1.171
# crown_base: 7.82347
# crown_d1: 7.02471
# crown_d2: 3.52025
# crown_d3: 13.9792
# crown_base_height: 7.78836
# crown_center_height: 14.81307
# tree_height: 21.83778
# crown_volume: 364.63976140274536
# single_leaf_area: 6e-05
# total_leaf_area: 54.6959642104118
# total_tree_branch_area: 12.766913496984513
# total_tree_stem_area: 0
# total_tree_ground_area: 38.93111901445883
# total_tree_canopy_veg_area: 67.46287770739632
# leaf_density: 2500
# branch_scale: 0.01
#
# tree_index: 158
# x_coord: 42.29
# y_coord: -9.517
# crown_base: 6.47983
# crown_d1: 5.24298
# crown_d2: 2.8004
# crown_d3: 10.4335
# crown_base_height: 6.453600000000001
# crown_center_height: 11.69658
# tree_height: 16.93956
# crown_volume: 172.22926503906402
# single_leaf_area: 6e-05
# total_leaf_area: 25.8343897558596
# total_tree_branch_area: 6.121682360824651
# total_tree_stem_area: 0
# total_tree_ground_area: 24.63712407434284
# total_tree_canopy_veg_area: 31.95607211668425
# leaf_density: 2500
# branch_scale: 0.01
#
# tree_index: 159
# x_coord: 25.78
# y_coord: -10.91
# crown_base: 10.8572
# crown_d1: 8.0394
# crown_d2: 4.29909
# crown_d3: 15.9984
# crown_base_height: 10.817
# crown_center_height: 18.8564
# tree_height: 26.8958
# crown_volume: 622.3938904083528
# single_leaf_area: 6e-05
# total_leaf_area: 93.35908356125292
# total_tree_branch_area: 20.985382021666023
# total_tree_stem_area: 0
# total_tree_ground_area: 58.063464662321145
# total_tree_canopy_veg_area: 114.34446558291894
# leaf_density: 2500
# branch_scale: 0.01
#
# tree_index: 160
# x_coord: 34.25
# y_coord: -10.15
# crown_base: 6.03435
# crown_d1: 5.34057
# crown_d2: 2.80181
# crown_d3: 10.6277
# crown_base_height: 6.007630000000001
# crown_center_height: 11.3482
# tree_height: 16.688769999999998
# crown_volume: 175.61175501600985
# single_leaf_area: 6e-05
# total_leaf_area: 26.341763252401478
# total_tree_branch_area: 6.306546373084646
# total_tree_stem_area: 0
# total_tree_ground_area: 24.66193987945246
# total_tree_canopy_veg_area: 32.64830962548612
# leaf_density: 2500
# branch_scale: 0.01
#
# tree_index: 161
# x_coord: 40.3
# y_coord: -30.78
# crown_base: 7.4865
# crown_d1: 6.77128
# crown_d2: 3.43124
# crown_d3: 13.4748
# crown_base_height: 7.4526200000000005
# crown_center_height: 14.2239
# tree_height: 20.99518
# crown_volume: 333.9347185871215
# single_leaf_area: 6e-05
# total_leaf_area: 50.09020778806822
# total_tree_branch_area: 11.60713308626069
# total_tree_stem_area: 0
# total_tree_ground_area: 36.98725188447991
# total_tree_canopy_veg_area: 61.69734087432891
# leaf_density: 2500
# branch_scale: 0.01
#
# tree_index: 162
# x_coord: 33.61
# y_coord: -37.0
# crown_base: 10.8506
# crown_d1: 8.39763
# crown_d2: 4.58644
# crown_d3: 16.7113
# crown_base_height: 10.808620000000001
# crown_center_height: 19.20625
# tree_height: 27.60388
# crown_volume: 739.9404644428957
# single_leaf_area: 6e-05
# total_leaf_area: 110.99106966643436
# total_tree_branch_area: 24.480699299703637
# total_tree_stem_area: 0
# total_tree_ground_area: 66.08475823919032
# total_tree_canopy_veg_area: 135.471768966138
# leaf_density: 2500
# branch_scale: 0.01
#
# tree_index: 163
# x_coord: 18.36
# y_coord: -40.12
# crown_base: 6.19586
# crown_d1: 4.88362
# crown_d2: 2.71462
# crown_d3: 9.7184
# crown_base_height: 6.171440000000001
# crown_center_height: 11.055060000000001
# tree_height: 15.938680000000002
# crown_volume: 150.74695965682244
# single_leaf_area: 6e-05
# total_leaf_area: 22.612043948523365
# total_tree_branch_area: 5.3061292734205665
# total_tree_stem_area: 0
# total_tree_ground_area: 23.150904399321988
# total_tree_canopy_veg_area: 27.91817322194393
# leaf_density: 2500
# branch_scale: 0.01
#
# tree_index: 164
# x_coord: 24.41
# y_coord: -53.63
# crown_base: 17.6638
# crown_d1: 12.7989
# crown_d2: 9.81152
# crown_d3: 25.4699
# crown_base_height: 17.59985
# crown_center_height: 30.39875
# tree_height: 43.197649999999996
# crown_volume: 5160.999798226104
# single_leaf_area: 6e-05
# total_leaf_area: 774.1499697339156
# total_tree_branch_area: 176.61521001755398
# total_tree_stem_area: 0
# total_tree_ground_area: 302.42832186122075
# total_tree_canopy_veg_area: 950.7651797514695
# leaf_density: 2500
# branch_scale: 0.01
#
# tree_index: 165
# x_coord: 27.25
# y_coord: -62.45
# crown_base: 12.6741
# crown_d1: 10.2311
# crown_d2: 6.21976
# crown_d3: 20.3599
# crown_base_height: 12.622950000000001
# crown_center_height: 22.85405
# tree_height: 33.08515
# crown_volume: 1657.899470658692
# single_leaf_area: 6e-05
# total_leaf_area: 248.68492059880379
# total_tree_branch_area: 52.10904234273967
# total_tree_stem_area: 0
# total_tree_ground_area: 121.53381386107252
# total_tree_canopy_veg_area: 300.79396294154344
# leaf_density: 2500
# branch_scale: 0.01
#
# tree_index: 166
# x_coord: 59.94
# y_coord: 20.36
# crown_base: 9.54711
# crown_d1: 8.95593
# crown_d2: 4.43248
# crown_d3: 17.8223
# crown_base_height: 9.502329999999999
# crown_center_height: 18.45826
# tree_height: 27.414189999999998
# crown_volume: 737.0430733722574
# single_leaf_area: 6e-05
# total_leaf_area: 110.5564610058386
# total_tree_branch_area: 26.23893777202615
# total_tree_stem_area: 0
# total_tree_ground_area: 61.72249057654459
# total_tree_canopy_veg_area: 136.79539877786476
# leaf_density: 2500
# branch_scale: 0.01
#
# tree_index: 167
# x_coord: 62.19
# y_coord: 8.445
# crown_base: 8.31464
# crown_d1: 7.14816
# crown_d2: 3.49528
# crown_d3: 14.2248
# crown_base_height: 8.278880000000001
# crown_center_height: 15.427040000000002
# tree_height: 22.575200000000002
# crown_volume: 365.80262540235987
# single_leaf_area: 6e-05
# total_leaf_area: 54.87039381035398
# total_tree_branch_area: 13.110833058551322
# total_tree_stem_area: 0
# total_tree_ground_area: 38.380781774858136
# total_tree_canopy_veg_area: 67.98122686890531
# leaf_density: 2500
# branch_scale: 0.01
#
# tree_index: 168
# x_coord: 52.31
# y_coord: 5.182
# crown_base: 8.97986
# crown_d1: 7.00614
# crown_d2: 3.54104
# crown_d3: 13.9422
# crown_base_height: 8.94482
# crown_center_height: 15.95096
# tree_height: 22.9571
# crown_volume: 367.9841271037997
# single_leaf_area: 6e-05
# total_leaf_area: 55.19761906556996
# total_tree_branch_area: 12.928530077570509
# total_tree_stem_area: 0
# total_tree_ground_area: 39.39231807069938
# total_tree_canopy_veg_area: 68.12614914314047
# leaf_density: 2500
# branch_scale: 0.01
#
# tree_index: 169
# x_coord: 53.76
# y_coord: -4.865
# crown_base: 11.4882
# crown_d1: 10.0533
# crown_d2: 5.5763
# crown_d3: 20.006
# crown_base_height: 11.437899999999999
# crown_center_height: 21.4912
# tree_height: 31.5445
# crown_volume: 1309.4517866805145
# single_leaf_area: 6e-05
# total_leaf_area: 196.41776800207717
# total_tree_branch_area: 43.701468359344126
# total_tree_stem_area: 0
# total_tree_ground_area: 97.68820586378463
# total_tree_canopy_veg_area: 240.1192363614213
# leaf_density: 2500
# branch_scale: 0.01
#
# tree_index: 170
# x_coord: 44.28
# y_coord: -18.44
# crown_base: 5.87925
# crown_d1: 4.45654
# crown_d2: 2.61658
# crown_d3: 8.86852
# crown_base_height: 5.8569700000000005
# crown_center_height: 10.31351
# tree_height: 14.77005
# crown_volume: 127.806944799384
# single_leaf_area: 6e-05
# total_leaf_area: 19.1710417199076
# total_tree_branch_area: 4.482979171858481
# total_tree_stem_area: 0
# total_tree_ground_area: 21.508885502999636
# total_tree_canopy_veg_area: 23.65402089176608
# leaf_density: 2500
# branch_scale: 0.01
#
# tree_index: 171
# x_coord: 36.01
# y_coord: -22.92
# crown_base: 13.3766
# crown_d1: 10.2177
# crown_d2: 6.0302
# crown_d3: 20.3333
# crown_base_height: 13.32555
# crown_center_height: 23.54325
# tree_height: 33.76095
# crown_volume: 1556.3425435743543
# single_leaf_area: 6e-05
# total_leaf_area: 233.45138153615312
# total_tree_branch_area: 51.07149570196605
# total_tree_stem_area: 0
# total_tree_ground_area: 114.23871396505726
# total_tree_canopy_veg_area: 284.5228772381192
# leaf_density: 2500
# branch_scale: 0.01
#
# tree_index: 172
# x_coord: 24.97
# y_coord: -44.42
# crown_base: 9.04328
# crown_d1: 8.50269
# crown_d2: 4.17713
# crown_d3: 16.9204
# crown_base_height: 9.00079
# crown_center_height: 17.50348
# tree_height: 26.006169999999997
# crown_volume: 621.4424810102095
# single_leaf_area: 6e-05
# total_leaf_area: 93.21637215153142
# total_tree_branch_area: 22.050107564041824
# total_tree_stem_area: 0
# total_tree_ground_area: 54.81581249671071
# total_tree_canopy_veg_area: 115.26647971557324
# leaf_density: 2500
# branch_scale: 0.01
#
# tree_index: 173
# x_coord: 43.57
# y_coord: -38.06
# crown_base: 12.5144
# crown_d1: 10.9175
# crown_d2: 6.36015
# crown_d3: 21.7258
# crown_base_height: 12.459799999999998
# crown_center_height: 23.377299999999998
# tree_height: 34.294799999999995
# crown_volume: 1849.8926486610344
# single_leaf_area: 6e-05
# total_leaf_area: 277.48389729915516
# total_tree_branch_area: 61.20056024322603
# total_tree_stem_area: 0
# total_tree_ground_area: 127.08216043011458
# total_tree_canopy_veg_area: 338.6844575423812
# leaf_density: 2500
# branch_scale: 0.01
#
# tree_index: 174
# x_coord: 37.51
# y_coord: -43.98
# crown_base: 5.98501
# crown_d1: 4.77244
# crown_d2: 2.67996
# crown_d3: 9.49715
# crown_base_height: 5.961145
# crown_center_height: 10.733585
# tree_height: 15.506024999999998
# crown_volume: 143.57727627602398
# single_leaf_area: 6e-05
# total_leaf_area: 21.536591441403598
# total_tree_branch_area: 5.0592736210045315
# total_tree_stem_area: 0
# total_tree_ground_area: 22.563501522704946
# total_tree_canopy_veg_area: 26.59586506240813
# leaf_density: 2500
# branch_scale: 0.01
#
# tree_index: 175
# x_coord: 18.49
# y_coord: -60.67
# crown_base: 14.8084
# crown_d1: 12.9663
# crown_d2: 8.65839
# crown_d3: 25.8029
# crown_base_height: 14.743550000000003
# crown_center_height: 27.709850000000003
# tree_height: 40.67615000000001
# crown_volume: 4071.729913576218
# single_leaf_area: 6e-05
# total_leaf_area: 610.7594870364327
# total_tree_branch_area: 141.11378302077657
# total_tree_stem_area: 0
# total_tree_ground_area: 235.51803021541716
# total_tree_canopy_veg_area: 751.8732700572093
# leaf_density: 2500
# branch_scale: 0.01
#
# tree_index: 176
# x_coord: 69.55
# y_coord: 11.61
# crown_base: 10.7297
# crown_d1: 7.99075
# crown_d2: 4.37465
# crown_d3: 15.9016
# crown_base_height: 10.689749999999998
# crown_center_height: 18.6805
# tree_height: 26.67125
# crown_volume: 640.5643689304894
# single_leaf_area: 6e-05
# total_leaf_area: 96.08465533957342
# total_tree_branch_area: 21.104218490904373
# total_tree_stem_area: 0
# total_tree_ground_area: 60.12242614246061
# total_tree_canopy_veg_area: 117.18887383047779
# leaf_density: 2500
# branch_scale: 0.01
#
# tree_index: 177
# x_coord: 70.41
# y_coord: 2.053
# crown_base: 7.38181
# crown_d1: 6.36317
# crown_d2: 3.33691
# crown_d3: 12.6627
# crown_base_height: 7.349989999999998
# crown_center_height: 13.713159999999998
# tree_height: 20.07633
# crown_volume: 296.79127005465307
# single_leaf_area: 6e-05
# total_leaf_area: 44.518690508197956
# total_tree_branch_area: 10.140564098751634
# total_tree_stem_area: 0
# total_tree_ground_area: 34.98153476034584
# total_tree_canopy_veg_area: 54.65925460694959
# leaf_density: 2500
# branch_scale: 0.01
#
# tree_index: 178
# x_coord: 60.11
# y_coord: -0.1432
# crown_base: 14.2099
# crown_d1: 10.9876
# crown_d2: 6.8919
# crown_d3: 21.8652
# crown_base_height: 14.154899999999998
# crown_center_height: 25.1425
# tree_height: 36.1301
# crown_volume: 2186.0967801969673
# single_leaf_area: 6e-05
# total_leaf_area: 327.9145170295451
# total_tree_branch_area: 70.03666857700576
# total_tree_stem_area: 0
# total_tree_ground_area: 149.22026513048579
# total_tree_canopy_veg_area: 397.95118560655084
# leaf_density: 2500
# branch_scale: 0.01
#
# tree_index: 179
# x_coord: 49.76
# y_coord: -12.92
# crown_base: 5.04372
# crown_d1: 4.3764
# crown_d2: 2.41078
# crown_d3: 8.70903
# crown_base_height: 5.021834999999999
# crown_center_height: 9.398235
# tree_height: 13.774635
# crown_volume: 106.54198364569253
# single_leaf_area: 6e-05
# total_leaf_area: 15.981297546853877
# total_tree_branch_area: 3.9821927835786544
# total_tree_stem_area: 0
# total_tree_ground_area: 18.258497334400282
# total_tree_canopy_veg_area: 19.96349033043253
# leaf_density: 2500
# branch_scale: 0.01
#
# tree_index: 180
# x_coord: 53.86
# y_coord: -22.14
# crown_base: 12.0712
# crown_d1: 8.98781
# crown_d2: 5.365
# crown_d3: 17.8857
# crown_base_height: 12.026239999999998
# crown_center_height: 21.014049999999997
# tree_height: 30.00186
# crown_volume: 1083.6323080788798
# single_leaf_area: 6e-05
# total_leaf_area: 162.54484621183195
# total_tree_branch_area: 33.771067091677736
# total_tree_stem_area: 0
# total_tree_ground_area: 90.42516820662208
# total_tree_canopy_veg_area: 196.3159133035097
# leaf_density: 2500
# branch_scale: 0.01
#
# tree_index: 181
# x_coord: 48.88
# y_coord: -28.81
# crown_base: 13.124
# crown_d1: 10.1266
# crown_d2: 6.03834
# crown_d3: 20.152
# crown_base_height: 13.073400000000003
# crown_center_height: 23.200000000000003
# tree_height: 33.3266
# crown_volume: 1546.6334236199261
# single_leaf_area: 6e-05
# total_leaf_area: 231.99501354298891
# total_tree_branch_area: 49.874795108354746
# total_tree_stem_area: 0
# total_tree_ground_area: 114.54733747901021
# total_tree_canopy_veg_area: 281.86980865134365
# leaf_density: 2500
# branch_scale: 0.01
#
# tree_index: 182
# x_coord: 60.51
# y_coord: -29.15
# crown_base: 9.2273
# crown_d1: 8.59557
# crown_d2: 4.3474
# crown_d3: 17.1052
# crown_base_height: 9.184329999999997
# crown_center_height: 17.779899999999998
# tree_height: 26.37547
# crown_volume: 680.49116783784
# single_leaf_area: 6e-05
# total_leaf_area: 102.07367517567599
# total_tree_branch_area: 23.59842797425959
# total_tree_stem_area: 0
# total_tree_ground_area: 59.37574539889501
# total_tree_canopy_veg_area: 125.67210314993558
# leaf_density: 2500
# branch_scale: 0.01
#
# tree_index: 183
# x_coord: 45.67
# y_coord: -45.64
# crown_base: 11.8718
# crown_d1: 10.6907
# crown_d2: 5.96862
# crown_d3: 21.2744
# crown_base_height: 11.8183
# crown_center_height: 22.509
# tree_height: 33.1997
# crown_volume: 1595.3009052628163
# single_leaf_area: 6e-05
# total_leaf_area: 239.29513578942243
# total_tree_branch_area: 54.012261430285434
# total_tree_stem_area: 0
# total_tree_ground_area: 111.91743093970575
# total_tree_canopy_veg_area: 293.30739721970787
# leaf_density: 2500
# branch_scale: 0.01
#
# tree_index: 184
# x_coord: 33.55
# y_coord: -53.23
# crown_base: 14.2735
# crown_d1: 10.8173
# crown_d2: 6.88499
# crown_d3: 21.5265
# crown_base_height: 14.219449999999998
# crown_center_height: 25.036749999999998
# tree_height: 35.85405
# crown_volume: 2147.9002632686006
# single_leaf_area: 6e-05
# total_leaf_area: 322.1850394902901
# total_tree_branch_area: 67.65659599524231
# total_tree_stem_area: 0
# total_tree_ground_area: 148.92119081946979
# total_tree_canopy_veg_area: 389.8416354855324
# leaf_density: 2500
# branch_scale: 0.01
#
# tree_index: 185
# x_coord: 66.7
# y_coord: -6.899
# crown_base: 7.44413
# crown_d1: 5.80741
# crown_d2: 3.0953
# crown_d3: 11.5568
# crown_base_height: 7.415120000000001
# crown_center_height: 13.22253
# tree_height: 19.02994
# crown_volume: 233.06474968090498
# single_leaf_area: 6e-05
# total_leaf_area: 34.95971245213575
# total_tree_branch_area: 8.049249007286239
# total_tree_stem_area: 0
# total_tree_ground_area: 30.09922878885402
# total_tree_canopy_veg_area: 43.00896145942198
# leaf_density: 2500
# branch_scale: 0.01
#
# tree_index: 186
# x_coord: 59.57
# y_coord: -14.42
# crown_base: 4.86277
# crown_d1: 4.52231
# crown_d2: 2.4035
# crown_d3: 8.9994
# crown_base_height: 4.84016
# crown_center_height: 9.36247
# tree_height: 13.88478
# crown_volume: 109.43019969001031
# single_leaf_area: 6e-05
# total_leaf_area: 16.414529953501546
# total_tree_branch_area: 4.17467345390858
# total_tree_stem_area: 0
# total_tree_ground_area: 18.148390925767526
# total_tree_canopy_veg_area: 20.589203407410125
# leaf_density: 2500
# branch_scale: 0.01
#
# tree_index: 187
# x_coord: 64.64
# y_coord: -21.55
# crown_base: 7.25261
# crown_d1: 6.13301
# crown_d2: 3.18868
# crown_d3: 12.2047
# crown_base_height: 7.2219500000000005
# crown_center_height: 13.35496
# tree_height: 19.48797
# crown_volume: 261.20660692323
# single_leaf_area: 6e-05
# total_leaf_area: 39.1809910384845
# total_tree_branch_area: 9.044521252011384
# total_tree_stem_area: 0
# total_tree_ground_area: 31.94270923941467
# total_tree_canopy_veg_area: 48.225512290495885
# leaf_density: 2500
# branch_scale: 0.01
#
# tree_index: 188
# x_coord: 54.85
# y_coord: -38.59
# crown_base: 7.77614
# crown_d1: 5.95639
# crown_d2: 3.23549
# crown_d3: 11.8532
# crown_base_height: 7.746349999999999
# crown_center_height: 13.702739999999999
# tree_height: 19.65913
# crown_volume: 261.18718149643394
# single_leaf_area: 6e-05
# total_leaf_area: 39.17807722446509
# total_tree_branch_area: 8.82106455605731
# total_tree_stem_area: 0
# total_tree_ground_area: 32.88743452365031
# total_tree_canopy_veg_area: 47.9991417805224
# leaf_density: 2500
# branch_scale: 0.01

# %%
def get_circle_derived_values(circle, trees, leaf_density):

    # Initialize lists to store values for the current circle
    d1_values = [trees[tree_index - 1].crown_d1 for tree_index in circle.tree_indices]
    d2_values = [trees[tree_index - 1].crown_d2 for tree_index in circle.tree_indices]
    single_leaf_areas = [trees[tree_index - 1].single_leaf_area for tree_index in circle.tree_indices]
    tree_branch_areas = [trees[tree_index - 1].total_tree_branch_area for tree_index in circle.tree_indices]
    crown_volumes = [trees[tree_index - 1].crown_volume for tree_index in circle.tree_indices]
    crown_center_height = [trees[tree_index - 1].crown_center_height for tree_index in circle.tree_indices]
    tree_heights = [trees[tree_index - 1].tree_height for tree_index in circle.tree_indices]
    crown_volumes_in_circle = circle.crown_vol_in_circle
    total_tree_canopy_veg_area = [trees[tree_index - 1].total_tree_canopy_veg_area for tree_index in circle.tree_indices]


    # Calculate number of trees found in the circle
    crown_percentages = circle.crown_percentages
    tree_percent_total = np.sum(crown_percentages)
    # Calculate area of the circle
    pixel_area = math.pi * (radius ** 2)
    # Calculate tree density
    tree_density = tree_percent_total / pixel_area

    # Calculate leaf, branch and total canopy vegetation areas, added adjusted areas with partial crown percentages
    adj_leaf_areas = [single_leaf_area * leaf_density * adj_crown_volumes for single_leaf_area, adj_crown_volumes in zip(single_leaf_areas, crown_volumes_in_circle)]
    adj_branch_areas = [branch_area * crown_percentage for branch_area, crown_percentage in zip(tree_branch_areas, crown_percentages)]
    total_adj_tree_canopy_veg_area = [adj_leaf_area + adj_branch_area for adj_leaf_area, adj_branch_area in zip(adj_leaf_areas, adj_branch_areas)]

    # Calculate mean and standard deviation of 'd1' values
    mean_d1 = np.mean(d1_values)
    std_d1 = np.std(d1_values)
    mean_d2 = np.mean(d2_values)
    std_d2 = np.std(d2_values)
    mean_crown_center_height = np.mean(crown_center_height)
    std_crown_center_height = np.std(crown_center_height)
    mean_tree_height = np.mean(tree_heights)
    std_tree_height = np.std(tree_heights)
    mean_crown_volume = np.mean(crown_volumes_in_circle)
    std_crown_volume = np.std(crown_volumes_in_circle)
    total_crown_volume = np.sum(crown_volumes)
    total_pixel_veg_area = np.sum(total_adj_tree_canopy_veg_area)
    total_leaf_veg_area = np.sum(adj_leaf_areas)
    adj_total_crown_volume = np.sum(crown_volumes_in_circle)

    # Calculate h1 and h2 each circle
    h1 = mean_crown_center_height - (2 * std_crown_center_height)
    h2 = mean_crown_center_height + (2 * std_crown_center_height)

    LAI = total_pixel_veg_area/pixel_area
    LAI_without_branch = total_leaf_veg_area/pixel_area
    Fa_with_branch = LAI/(adj_total_crown_volume / pixel_area)
    Fa_without_branch = LAI_without_branch/(adj_total_crown_volume / pixel_area)

    # Update circle with calculated values
    circle.tree_percent_total = tree_percent_total
    circle.tree_density = tree_density
    circle.mean_crown_d1 = mean_d1
    circle.std_crown_d1 = std_d1
    circle.mean_crown_d2 = mean_d2
    circle.std_crown_d2 = std_d2
    circle.mean_crown_center_height = mean_crown_center_height
    circle.std_crown_center_height = std_crown_center_height
    circle.tree_heights = np.array(tree_heights)
    circle.mean_tree_height = mean_tree_height
    circle.std_tree_height = std_tree_height
    circle.mean_crown_volume = mean_crown_volume
    circle.std_crown_volume = std_crown_volume
    circle.total_crown_volume = total_crown_volume
    circle.adj_crown_volume = adj_total_crown_volume
    circle.single_leaf_areas = np.array(single_leaf_areas)
    circle.adj_leaf_areas = np.array(adj_leaf_areas)
    circle.adj_branch_areas = np.array(adj_branch_areas)
    circle.total_tree_canopy_veg_area = np.array(total_adj_tree_canopy_veg_area)
    circle.pixel_area = pixel_area
    circle.total_vegetation_area_per_pixel = total_pixel_veg_area
    circle.total_leaf_veg_area = total_leaf_veg_area
    circle.LAI_with_branch = LAI
    circle.LAI_without_branch = LAI_without_branch
    circle.h1 = h1
    circle.h2 = h2
    circle.Fa_b = Fa_with_branch
    circle.Fa = Fa_without_branch

def output_derived_data(circle):
    # Print results
    print(f"Total Trees found in {circle.circle_name}: {circle.tree_percent_total}")
    print(f"Tree Indices: {circle.tree_indices}")
    print(f"Tree Density: {circle.tree_density}")
    print(f"Mean Vertical Crown Radius: {circle.mean_crown_d1}, STD Vertical Crown Radius: {circle.std_crown_d1}")
    print(f"Mean Horizontal Crown Radius: {circle.mean_crown_d2}, STD Horizontal Crown Radius: {circle.std_crown_d2}")
    print(f"Mean Crown Center Height: {circle.mean_crown_center_height}, STD Crown Center Height: {circle.std_crown_center_height}")
    print(f"Tree Heights: {circle.tree_heights}")
    print(f"Mean Tree Height: {circle.mean_tree_height}, STD Tree Height: {circle.std_tree_height}")
    print(f"Crown Volume found in Circle: {circle.circle_name}: {circle.crown_vol_in_circle}")
    print(f"Mean Crown Volume: {circle.mean_crown_volume}, STD Crown Volume: {circle.std_crown_volume}")
    print(f"Total Crown Volume: {circle.total_crown_volume}")
    print(f"Adjusted Partial Crown Volumes: {circle.adj_crown_volume}")
    print(f"h1: {circle.h1}, h2: {circle.h2}")
    print(f"Tree Single Leaf Areas: {circle.single_leaf_areas}")
    print(f"Tree Total Leaf Areas: {circle.adj_leaf_areas}")
    print(f"Tree Branch Areas: {circle.adj_branch_areas}")
    print(f"Total Vegetation Areas per tree: {circle.total_tree_canopy_veg_area}")
    print(f"Total Vegetation Areas per Pixel: {circle.total_vegetation_area_per_pixel}")
    print(f"Total Vegetation Areas per Pixel without branch areas: {circle.total_leaf_veg_area}")
    print(f"Circle Pixel area: {circle.pixel_area}")
    print(f"LAI Index per Unit Area: {circle.LAI_with_branch}")
    print(f"LAI Index per Unit Area without branch areas: {circle.LAI_without_branch}")
    print(f"Fa per Unit Area: {circle.Fa_b}")
    print(f"Fa per Unit Area without branch areas: {circle.Fa}")
    print()

# %%
# Redirecting stdout to a text file
output_file = output_path + 'redwood_gort_data_raw_output_class.txt'

# Use %%capture to capture output
with ipy_io.capture_output() as captured_output:

    print("California Redwood Results:\n")

    tree_sum = 0

    for circle in redwood_circle_objects:

        get_circle_derived_values(circle, redwood_tree_objects, redwood_leaf_density_ratio)
        output_derived_data(circle)

    tree_sum = 0
    for circle in redwood_circle_objects:

        circle_name = circle.circle_name
        tree_indices = circle.tree_indices
        crown_percentages = circle.crown_percentages
        tree_percent_total = circle.tree_percent_total
        tree_sum += tree_percent_total

        print(f"Total Trees found in {circle_name}: {tree_percent_total}")
        print(f"Tree indices: {tree_indices}")
        print("Percent of tree crown in circle: " + ", ".join([f"{percentage:.4f}" for percentage in crown_percentages]))
        print()  # Print a blank line for separation

    # Print total number of trees found in all circles
    print(f"Total number of trees found in all circles: {tree_sum} out of {len(redwood_tree_objects)}")

with open(output_file, "w") as file:
    file.write(captured_output.stdout)

# %%
for circle in redwood_circle_objects:
    circle.print_attributes()
# Out:
# circle_name: Circle(3, 1)
# x_coord: -33.300000
# y_coord: 33.300000
# row: 3
# column: 1
# tree_indices: [ 7 14 15 16 17 19 20 26 27 28 29 37 39 51 53]
# crown_vol_in_circle: [ 248.26696059    0.32523409   34.91988234  495.41275132  504.32625546
#   171.29795503  401.21370334  150.14615303 1002.6985605   337.14874305
#   515.6410405  4884.29356445  441.46961146  504.25205435  410.04984457]
# crown_percentages: [0.39477425 0.00057048 0.15108792 0.99471357 1.         0.69163379
#  0.08520866 0.32263391 0.96574886 1.         0.50879085 1.
#  1.         1.         0.84088965]
# tree_heights: [25.94412 26.03559 19.14973 23.71524 23.94105 19.64225 41.67815 23.85574
#  29.03983 20.77117 29.2986  42.18075 23.12683 25.44789 23.62493]
# single_leaf_areas: [0.00006 0.00006 0.00006 0.00006 0.00006 0.00006 0.00006 0.00006 0.00006
#  0.00006 0.00006 0.00006 0.00006 0.00006 0.00006]
# adj_branch_areas: [  8.34306024   0.01131375   1.26253713  16.58470654  16.9899038
#    6.02454366  13.53606327   5.29658866  33.22261348  11.2597211
#   17.32211098 172.14228307  15.29220175  17.49550249  13.42527879]
# adj_leaf_areas: [ 37.24004409   0.04878511   5.23798235  74.3119127   75.64893832
#   25.69469325  60.1820555   22.52192295 150.40478408  50.57231146
#   77.34615608 732.64403467  66.22044172  75.63780815  61.50747669]
# total_tree_canopy_veg_area: [ 45.58310433   0.06009886   6.50051948  90.89661924  92.63884212
#   31.71923692  73.71811877  27.81851161 183.62739756  61.83203255
#   94.66826705 904.78631773  81.51264347  93.13331064  74.93275548]
# Fa_leaf_branch_per_tree: []
# Fa_array: []
# Fa_b_array: []
# total_Fa: []
# total_Fa_b: []
# Li_dz_leaf: []
# Li_dz_branch: []
# tree_height_array: []
# total_Li_dz_leaf: []
# total_Li_dz_branch: []
# acc_LAI_leaf: []
# acc_LAI_branch: []
# tree_density: 0.011432
# tree_percent_total: 9.956052
# mean_crown_d1: 8.339923
# std_crown_d1: 2.046458
# mean_crown_d2: 4.697061
# std_crown_d2: 1.923723
# mean_crown_center_height: 18.156869
# std_crown_center_height: 4.632891
# mean_tree_height: 26.496791
# std_tree_height: 6.668287
# total_leaf_veg_area: 1515.219347
# mean_crown_volume: 673.430821
# std_crown_volume: 1149.824549
# total_crown_volume: 16560.656916
# adj_crown_volume: 10101.462314
# pixel_area: 870.920169
# total_vegetation_area_per_pixel: 1863.427776
# LAI_with_branch: 2.139608
# LAI_without_branch: 1.739791
# h1: 8.891086
# h2: 27.422651
# Fa: 0.150000
# Fa_b: 0.184471
# new_Fa: 0
# circle_name: Circle(3, 2)
# x_coord: 0.000000
# y_coord: 33.300000
# row: 3
# column: 2
# tree_indices: [ 25  52  54  64  65  66  67  81  82  83  84  85  95  96  98  99 113]
# crown_vol_in_circle: [  84.98753398  276.01992065   54.17303291   48.47742456 1320.32046848
#   116.39779462  319.67004477  110.40875224   58.1262588   407.92087842
#   140.55708172    5.32954688   43.05603325  424.52957354  124.8790332
#    79.18475554    9.72830138]
# crown_percentages: [0.38921077 1.         0.3610698  0.13790984 1.         1.
#  1.         0.37291016 1.         1.         1.         0.0571694
#  0.02820451 1.         0.12251754 0.1002597  0.01532992]
# tree_heights: [18.03497  19.98578  16.088475 21.6038   32.31669  13.641935 21.58919
#  20.06147  10.6616   22.5443   15.83713  13.21504  33.1145   23.2465
#  30.38947  27.58894  26.73423 ]
# single_leaf_areas: [0.00006 0.00006 0.00006 0.00006 0.00006 0.00006 0.00006 0.00006 0.00006
#  0.00006 0.00006 0.00006 0.00006 0.00006 0.00006 0.00006 0.00006]
# adj_branch_areas: [ 2.86494344  9.59201935  1.887492    1.63735479 43.65413589  4.26887998
#  11.65596736  3.7841652   2.29825312 14.04271691  4.98714751  0.20097715
#   1.43508071 14.86091937  4.15412457  2.71537954  0.33692774]
# adj_leaf_areas: [ 12.7481301   41.4029881    8.12595494   7.27161368 198.04807027
#   17.45966919  47.95050672  16.56131284   8.71893882  61.18813176
#   21.08356226   0.79943203   6.45840499  63.67943603  18.73185498
#   11.87771333   1.45924521]
# total_tree_canopy_veg_area: [ 15.61307353  50.99500745  10.01344693   8.90896847 241.70220616
#   21.72854917  59.60647408  20.34547804  11.01719194  75.23084867
#   26.07070977   1.00040918   7.8934857   78.5403554   22.88597955
#   14.59309287   1.79617295]
# Fa_leaf_branch_per_tree: []
# Fa_array: []
# Fa_b_array: []
# total_Fa: []
# total_Fa_b: []
# Li_dz_leaf: []
# Li_dz_branch: []
# tree_height_array: []
# total_Li_dz_leaf: []
# total_Li_dz_branch: []
# acc_LAI_leaf: []
# acc_LAI_branch: []
# tree_density: 0.011005
# tree_percent_total: 9.584582
# mean_crown_d1: 6.733948
# std_crown_d1: 2.038745
# mean_crown_d2: 3.631536
# std_crown_d2: 1.107609
# mean_crown_center_height: 14.833936
# std_crown_center_height: 4.501150
# mean_tree_height: 21.567884
# std_tree_height: 6.530722
# total_leaf_veg_area: 543.564965
# mean_crown_volume: 213.162731
# std_crown_volume: 304.960744
# total_crown_volume: 8142.980297
# adj_crown_volume: 3623.766435
# pixel_area: 870.920169
# total_vegetation_area_per_pixel: 667.941450
# LAI_with_branch: 0.766938
# LAI_without_branch: 0.624127
# h1: 5.831636
# h2: 23.836236
# Fa: 0.150000
# Fa_b: 0.184322
# new_Fa: 0
# circle_name: Circle(3, 3)
# x_coord: 33.300000
# y_coord: 33.300000
# row: 3
# column: 3
# tree_indices: [ 97  98 111 112 113 114 125 126 127 128 129 130 131 140 141]
# crown_vol_in_circle: [604.85630127 118.80292344  66.28184141 453.32256806 618.63798096
#  753.34881741 342.42600528 380.81025801 674.99740358 576.27370727
#  119.68429761 922.2860028   15.94064843  18.41581267 200.51814652]
# crown_percentages: [0.81940974 0.11655633 0.44822891 1.         0.97485383 1.
#  1.         0.4863087  0.98710554 1.         0.20643442 1.
#  0.09163184 0.01391531 1.        ]
# tree_heights: [26.95849 30.38947 15.93318 24.70248 26.73423 27.53051 21.83597 28.19755
#  27.07965 26.15139 25.25244 29.42302 16.89113 31.59196 17.72365]
# single_leaf_areas: [0.00006 0.00006 0.00006 0.00006 0.00006 0.00006 0.00006 0.00006 0.00006
#  0.00006 0.00006 0.00006 0.00006 0.00006 0.00006]
# adj_branch_areas: [19.97127193  3.95200164  2.32955873 15.52014788 21.4257647  24.00814264
#  11.98528724 12.97488519 21.97895624 19.63101598  3.95852524 31.32184236
#   0.54240323  0.60311634  7.33771468]
# adj_leaf_areas: [ 90.72844519  17.82043852   9.94227621  67.99838521  92.79569714
#  113.00232261  51.36390079  57.1215387  101.24961054  86.44105609
#   17.95264464 138.34290042   2.39109726   2.7623719   30.07772198]
# total_tree_canopy_veg_area: [110.69971712  21.77244015  12.27183494  83.51853309 114.22146185
#  137.01046525  63.34918803  70.09642389 123.22856677 106.07207207
#   21.91116988 169.66474278   2.93350049   3.36548824  37.41543666]
# Fa_leaf_branch_per_tree: []
# Fa_array: []
# Fa_b_array: []
# total_Fa: []
# total_Fa_b: []
# Li_dz_leaf: []
# Li_dz_branch: []
# tree_height_array: []
# total_Li_dz_leaf: []
# total_Li_dz_branch: []
# acc_LAI_leaf: []
# acc_LAI_branch: []
# tree_density: 0.011648
# tree_percent_total: 10.144445
# mean_crown_d1: 7.710251
# std_crown_d1: 1.451725
# mean_crown_d2: 4.163124
# std_crown_d2: 0.838107
# mean_crown_center_height: 17.382757
# std_crown_center_height: 3.270934
# mean_tree_height: 25.093008
# std_tree_height: 4.705493
# total_leaf_veg_area: 879.990407
# mean_crown_volume: 391.106848
# std_crown_volume: 283.002979
# total_crown_volume: 9332.112975
# adj_crown_volume: 5866.602715
# pixel_area: 870.920169
# total_vegetation_area_per_pixel: 1077.531041
# LAI_with_branch: 1.237233
# LAI_without_branch: 1.010415
# h1: 10.840888
# h2: 23.924626
# Fa: 0.150000
# Fa_b: 0.183672
# new_Fa: 0
# circle_name: Circle(2, 1)
# x_coord: -33.300000
# y_coord: 0.000000
# row: 2
# column: 1
# tree_indices: [10 20 21 29 30 40 41 42 43 45 55 56 57 58 59 71]
# crown_vol_in_circle: [ 328.29306162 2155.26675515   29.62535153  384.72080471  389.30786847
#   149.51666706 1916.70305003  109.01194627  398.55139486  118.00937087
#   185.08525902  218.51639649 1104.10255129  322.34867981   53.29306517
#    32.60791062]
# crown_percentages: [0.19725387 0.4577296  0.0654476  0.37960986 1.         1.
#  1.         0.84015711 1.         0.55341497 1.         1.
#  1.         1.         0.53607895 0.23829506]
# tree_heights: [32.66945  41.67815  23.67867  29.2986   23.01916  16.15909  34.7697
#  15.614055 22.55355  19.18345  17.5657   19.08618  30.75101  21.40366
#  13.1653   15.76472 ]
# single_leaf_areas: [0.00006 0.00006 0.00006 0.00006 0.00006 0.00006 0.00006 0.00006 0.00006
#  0.00006 0.00006 0.00006 0.00006 0.00006 0.00006 0.00006]
# adj_branch_areas: [10.74836106 72.71393503  1.00231942 12.92406141 13.67256188  5.4355691
#  65.04294077  4.08150609 12.96130501  4.20700899  6.65076176  7.85033954
#  36.1277174  10.98524153  1.99567232  1.15663904]
# adj_leaf_areas: [ 49.24395924 323.29001327   4.44380273  57.70812071  58.39618027
#   22.42750006 287.5054575   16.35179194  59.78270923  17.70140563
#   27.76278885  32.77745947 165.61538269  48.35230197   7.99395978
#    4.89118659]
# total_tree_canopy_veg_area: [ 59.99232031 396.0039483    5.44612215  70.63218212  72.06874215
#   27.86306916 352.54839828  20.43329803  72.74401424  21.90841462
#   34.41355061  40.62779901 201.74310009  59.3375435    9.9896321
#    6.04782563]
# Fa_leaf_branch_per_tree: []
# Fa_array: []
# Fa_b_array: []
# total_Fa: []
# total_Fa_b: []
# Li_dz_leaf: []
# Li_dz_branch: []
# tree_height_array: []
# total_Li_dz_leaf: []
# total_Li_dz_branch: []
# acc_LAI_leaf: []
# acc_LAI_branch: []
# tree_density: 0.012938
# tree_percent_total: 11.267987
# mean_crown_d1: 7.321148
# std_crown_d1: 2.507572
# mean_crown_d2: 4.116787
# std_crown_d2: 1.844348
# mean_crown_center_height: 16.201380
# std_crown_center_height: 5.369891
# mean_tree_height: 23.522528
# std_tree_height: 7.863382
# total_leaf_veg_area: 1184.244020
# mean_crown_volume: 493.435008
# std_crown_volume: 634.791754
# total_crown_volume: 13102.414570
# adj_crown_volume: 7894.960133
# pixel_area: 870.920169
# total_vegetation_area_per_pixel: 1451.799960
# LAI_with_branch: 1.666972
# LAI_without_branch: 1.359762
# h1: 5.461598
# h2: 26.941161
# Fa: 0.150000
# Fa_b: 0.183889
# new_Fa: 0
# circle_name: Circle(2, 2)
# x_coord: 0.000000
# y_coord: 0.000000
# row: 2
# column: 2
# tree_indices: [ 68  69  70  85  86  87  99 100 101 102 103 104 117 119 132]
# crown_vol_in_circle: [  38.47160577  115.55390683  179.88718515   83.99186079  174.92063375
#   316.35099033   93.51171712   69.32120454 1799.76097955  207.14797833
#   375.42111311   69.40172645  410.05614612   25.4771108   124.45557524]
# crown_percentages: [0.19844845 1.         0.52322101 0.90097039 1.         1.
#  0.11839977 0.19335343 0.87467548 1.         1.         0.2368027
#  0.49515844 0.07688243 0.12043727]
# tree_heights: [17.10302  14.134105 21.95703  13.21504  17.97984  20.25608  27.58894
#  21.43225  35.1838   18.05195  22.91923  20.29331  28.24967  21.60506
#  29.44043 ]
# single_leaf_areas: [0.00006 0.00006 0.00006 0.00006 0.00006 0.00006 0.00006 0.00006 0.00006
#  0.00006 0.00006 0.00006 0.00006 0.00006 0.00006]
# adj_branch_areas: [ 1.35055004  4.22802219  6.13105094  3.1673321   6.33907802 10.85511542
#   3.20667534  2.3579919  57.38081405  7.45716365 13.14458936  2.32273232
#  13.00413845  0.87824624  4.0201804 ]
# adj_leaf_areas: [  5.77074087  17.33308602  26.98307777  12.59877912  26.23809506
#   47.45264855  14.02675757  10.39818068 269.96414693  31.07219675
#   56.31316697  10.41025897  61.50842192   3.82156662  18.66833629]
# total_tree_canopy_veg_area: [  7.1212909   21.56110821  33.11412871  15.76611121  32.57717308
#   58.30776397  17.23343291  12.75617258 327.34496098  38.5293604
#   69.45775633  12.73299129  74.51256036   4.69981286  22.68851669]
# Fa_leaf_branch_per_tree: []
# Fa_array: []
# Fa_b_array: []
# total_Fa: []
# total_Fa_b: []
# Li_dz_leaf: []
# Li_dz_branch: []
# tree_height_array: []
# total_Li_dz_leaf: []
# total_Li_dz_branch: []
# acc_LAI_leaf: []
# acc_LAI_branch: []
# tree_density: 0.010033
# tree_percent_total: 8.738349
# mean_crown_d1: 6.830581
# std_crown_d1: 1.771449
# mean_crown_d2: 3.708265
# std_crown_d2: 1.134018
# mean_crown_center_height: 15.130069
# std_crown_center_height: 4.023632
# mean_tree_height: 21.960650
# std_tree_height: 5.782158
# total_leaf_veg_area: 612.559460
# mean_crown_volume: 272.248649
# std_crown_volume: 424.167714
# total_crown_volume: 7512.188856
# adj_crown_volume: 4083.729734
# pixel_area: 870.920169
# total_vegetation_area_per_pixel: 748.403140
# LAI_with_branch: 0.859325
# LAI_without_branch: 0.703347
# h1: 7.082805
# h2: 23.177333
# Fa: 0.150000
# Fa_b: 0.183265
# new_Fa: 0
# circle_name: Circle(2, 3)
# x_coord: 33.300000
# y_coord: 0.000000
# row: 2
# column: 3
# tree_indices: [100 101 115 116 117 129 131 132 142 143 144 145 157 158 159 160 168 169]
# crown_vol_in_circle: [ 65.45917983 184.34990967  19.66457376 534.90820461  69.93172424
#  104.11869699 122.25584734 872.16685615 212.93031063 307.18840034
#  164.34342747 216.88424073 364.6397614  172.22926504 583.13563587
#  175.61175502  10.09397527  66.24610961]
# crown_percentages: [0.18258132 0.0895932  0.06284319 1.         0.08444522 0.17958649
#  0.70276489 0.84400718 1.         1.         1.         1.
#  1.         1.         0.93692378 1.         0.02743046 0.05059072]
# tree_heights: [21.43225 35.1838  21.63262 24.303   28.24967 25.25244 16.89113 29.44043
#  19.06706 21.01402 16.29731 18.76865 21.83778 16.93956 26.8958  16.68877
#  22.9571  31.5445 ]
# single_leaf_areas: [0.00006 0.00006 0.00006 0.00006 0.00006 0.00006 0.00006 0.00006 0.00006
#  0.00006 0.00006 0.00006 0.00006 0.00006 0.00006 0.00006 0.00006 0.00006]
# adj_branch_areas: [ 2.2266234   5.8775293   0.67734465 18.16875746  2.21774953  3.44369728
#   4.15992902 28.1728488   7.49612409 10.92304856  5.96209527  7.97974075
#  12.7669135   6.12168236 19.66170343  6.30654637  0.35463558  2.21088878]
# adj_leaf_areas: [  9.81887697  27.65248645   2.94968606  80.23623069  10.48975864
#   15.61780455  18.3383771  130.82502842  31.9395466   46.07826005
#   24.65151412  32.53263611  54.69596421  25.83438976  87.47034538
#   26.34176325   1.51409629   9.93691644]
# total_tree_canopy_veg_area: [ 12.04550037  33.53001575   3.62703071  98.40498815  12.70750816
#   19.06150183  22.49830612 158.99787723  39.43567068  57.00130861
#   30.61360939  40.51237686  67.46287771  31.95607212 107.13204881
#   32.64830963   1.86873187  12.14780522]
# Fa_leaf_branch_per_tree: []
# Fa_array: []
# Fa_b_array: []
# total_Fa: []
# total_Fa_b: []
# Li_dz_leaf: []
# Li_dz_branch: []
# tree_height_array: []
# total_Li_dz_leaf: []
# total_Li_dz_branch: []
# acc_LAI_leaf: []
# acc_LAI_branch: []
# tree_density: 0.012815
# tree_percent_total: 11.160766
# mean_crown_d1: 7.155391
# std_crown_d1: 1.644920
# mean_crown_d2: 3.850999
# std_crown_d2: 1.085269
# mean_crown_center_height: 15.866603
# std_crown_center_height: 3.718497
# mean_tree_height: 23.021994
# std_tree_height: 5.344951
# total_leaf_veg_area: 636.923681
# mean_crown_volume: 235.897660
# std_crown_volume: 219.371700
# total_crown_volume: 9792.862288
# adj_crown_volume: 4246.157874
# pixel_area: 870.920169
# total_vegetation_area_per_pixel: 781.651539
# LAI_with_branch: 0.897501
# LAI_without_branch: 0.731323
# h1: 8.429610
# h2: 23.303596
# Fa: 0.150000
# Fa_b: 0.184084
# new_Fa: 0
# circle_name: Circle(1, 1)
# x_coord: -33.300000
# y_coord: -33.300000
# row: 1
# column: 1
# tree_indices: [35 44 45 46 47 59 60 61 72 73 74 75 89 90 91 92]
# crown_vol_in_circle: [ 252.16325357    2.23624201   31.34699879  179.14523237  156.98302551
#    16.44489273  155.11970585  242.55167493  110.35780144 1854.0178292
#   419.09078715   22.77045171   44.07673176  240.9110444     8.09527231
#   515.00435537]
# crown_percentages: [0.94409352 0.00825421 0.14700441 1.         1.         0.16542041
#  1.         1.         0.87004055 1.         0.99977352 0.07492724
#  0.08850062 1.         0.04334934 0.31247127]
# tree_heights: [20.34204  19.51442  19.18345  18.04041  16.47843  13.1653   17.11579
#  19.86041  14.516475 35.0937   23.33693  20.9684   23.9497   19.96673
#  18.03255  34.43585 ]
# single_leaf_areas: [0.00006 0.00006 0.00006 0.00006 0.00006 0.00006 0.00006 0.00006 0.00006
#  0.00006 0.00006 0.00006 0.00006 0.00006 0.00006 0.00006]
# adj_branch_areas: [ 8.59544447  0.07560041  1.11751384  6.38810973  5.47282141  0.61581403
#   5.65427027  8.59330131  3.92890489 64.2308999  14.86078613  0.76694698
#   1.42609115  8.43713735  0.28410125 16.98696246]
# adj_leaf_areas: [ 37.82448804   0.3354363    4.70204982  26.87178486  23.54745383
#    2.46673391  23.26795588  36.38275124  16.55367022 278.10267438
#   62.86361807   3.41556776   6.61150976  36.13665666   1.21429085
#   77.25065331]
# total_tree_canopy_veg_area: [ 46.41993251   0.41103671   5.81956366  33.25989458  29.02027524
#    3.08254794  28.92222614  44.97605255  20.48257511 342.33357428
#   77.7244042    4.18251474   8.03760091  44.57379401   1.49839209
#   94.23761577]
# Fa_leaf_branch_per_tree: []
# Fa_array: []
# Fa_b_array: []
# total_Fa: []
# total_Fa_b: []
# Li_dz_leaf: []
# Li_dz_branch: []
# tree_height_array: []
# total_Li_dz_leaf: []
# total_Li_dz_branch: []
# acc_LAI_leaf: []
# acc_LAI_branch: []
# tree_density: 0.011085
# tree_percent_total: 9.653835
# mean_crown_d1: 6.377407
# std_crown_d1: 1.866804
# mean_crown_d2: 3.458460
# std_crown_d2: 1.118900
# mean_crown_center_height: 14.497630
# std_crown_center_height: 4.049604
# mean_tree_height: 20.875037
# std_tree_height: 5.904918
# total_leaf_veg_area: 637.547295
# mean_crown_volume: 265.644706
# std_crown_volume: 434.913295
# total_crown_volume: 6862.274638
# adj_crown_volume: 4250.315299
# pixel_area: 870.920169
# total_vegetation_area_per_pixel: 784.982000
# LAI_with_branch: 0.901325
# LAI_without_branch: 0.732039
# h1: 6.398422
# h2: 22.596838
# Fa: 0.150000
# Fa_b: 0.184688
# new_Fa: 0
# circle_name: Circle(1, 2)
# x_coord: 0.000000
# y_coord: -33.300000
# row: 1
# column: 2
# tree_indices: [ 89  91 104 105 106 107 108 118 119 120 121 122 134 135 137 138 148 149]
# crown_vol_in_circle: [ 365.30168916  149.10914681  138.1480804   372.29770436 1654.29575764
#   355.70100231  164.66917344    1.34914925  275.273782    336.84590532
#   280.63417162  560.84204477   29.68550314  466.95310965  653.21700419
#    12.34199369  217.65698382 1085.72477292]
# crown_percentages: [0.73348056 0.79846389 0.47136923 1.         1.         0.29323644
#  0.40075607 0.01548652 0.83069534 1.         1.         1.
#  0.09110396 1.         0.62735711 0.19955016 0.08589633 1.        ]
# tree_heights: [23.9497   18.03255  20.29331  22.20358  33.39685  30.95908  22.55828
#  12.20447  21.60506  22.31398  21.03272  25.26886  20.53896  23.99456
#  29.66155  10.510445 37.6341   29.64743 ]
# single_leaf_areas: [0.00006 0.00006 0.00006 0.00006 0.00006 0.00006 0.00006 0.00006 0.00006
#  0.00006 0.00006 0.00006 0.00006 0.00006 0.00006 0.00006 0.00006 0.00006]
# adj_branch_areas: [11.81924078  5.23294248  4.62353068 12.64263258 54.32723578 11.48282141
#   5.68696325  0.05101276  9.48923003 11.66628319  9.9552331  18.80970399
#   1.0096538  16.19977413 21.13997203  0.4800081   6.95077197 34.64603661]
# adj_leaf_areas: [ 54.79525337  22.36637202  20.72221206  55.84465565 248.14436365
#   53.35515035  24.70037602   0.20237239  41.2910673   50.5268858
#   42.09512574  84.12630672   4.45282547  70.04296645  97.98255063
#    1.85129905  32.64854757 162.85871594]
# total_tree_canopy_veg_area: [ 66.61449416  27.5993145   25.34574274  68.48728823 302.47159942
#   64.83797176  30.38733927   0.25338515  50.78029733  62.19316899
#   52.05035884 102.93601071   5.46247928  86.24274058 119.12252266
#    2.33130716  39.59931955 197.50475255]
# Fa_leaf_branch_per_tree: []
# Fa_array: []
# Fa_b_array: []
# total_Fa: []
# total_Fa_b: []
# Li_dz_leaf: []
# Li_dz_branch: []
# tree_height_array: []
# total_Li_dz_leaf: []
# total_Li_dz_branch: []
# acc_LAI_leaf: []
# acc_LAI_branch: []
# tree_density: 0.013259
# tree_percent_total: 11.547396
# mean_crown_d1: 7.319446
# std_crown_d1: 2.023681
# mean_crown_d2: 4.054246
# std_crown_d2: 1.307719
# mean_crown_center_height: 16.336415
# std_crown_center_height: 4.614968
# mean_tree_height: 23.655860
# std_tree_height: 6.629756
# total_leaf_veg_area: 1068.007046
# mean_crown_volume: 395.558165
# std_crown_volume: 397.338104
# total_crown_volume: 11740.725922
# adj_crown_volume: 7120.046975
# pixel_area: 870.920169
# total_vegetation_area_per_pixel: 1304.220093
# LAI_with_branch: 1.497520
# LAI_without_branch: 1.226297
# h1: 7.106479
# h2: 25.566351
# Fa: 0.150000
# Fa_b: 0.183176
# new_Fa: 0
# circle_name: Circle(1, 3)
# x_coord: 33.300000
# y_coord: -33.300000
# row: 1
# column: 3
# tree_indices: [134 146 147 148 161 162 163 164 170 171 172 173 174 181 183 184]
# crown_vol_in_circle: [  51.78149284  226.26833601  728.68185772 2180.85508789  333.93471859
#   739.94046444   80.77904964  683.02376102   11.41207667 1553.55157093
#   543.28417205 1763.14647611  143.57727628  783.8958775   601.09016132
#   391.76682025]
# crown_percentages: [0.15891592 0.9266583  1.         0.86065443 1.         1.
#  0.53585857 0.1323433  0.08929152 0.99820671 0.87423082 0.95310746
#  1.         0.50684012 0.37678795 0.18239526]
# tree_heights: [20.53896  19.65288  27.56906  37.6341   20.99518  27.60388  15.93868
#  43.19765  14.77005  33.76095  26.00617  34.2948   15.506025 33.3266
#  33.1997   35.85405 ]
# single_leaf_areas: [0.00006 0.00006 0.00006 0.00006 0.00006 0.00006 0.00006 0.00006 0.00006
#  0.00006 0.00006 0.00006 0.00006 0.00006 0.00006 0.00006]
# adj_branch_areas: [ 1.76117551  8.20905049 25.56903131 69.64456714 11.60713309 24.4806993
#   2.84333482 23.37384029  0.40029203 50.97990973 19.2768837  58.33071027
#   5.05927362 25.27854738 20.35116938 12.34024221]
# adj_leaf_areas: [  7.76722393  33.9402504  109.30227866 327.12826318  50.09020779
#  110.99106967  12.11685745 102.45356415   1.7118115  233.03273564
#   81.49262581 264.47197142  21.53659144 117.58438163  90.1635242
#   58.76502304]
# total_tree_canopy_veg_area: [  9.52839944  42.1493009  134.87130997 396.77283032  61.69734087
#  135.47176897  14.96019227 125.82740444   2.11210354 284.01264537
#  100.76950951 322.80268169  26.59586506 142.862929   110.51469358
#   71.10526524]
# Fa_leaf_branch_per_tree: []
# Fa_array: []
# Fa_b_array: []
# total_Fa: []
# total_Fa_b: []
# Li_dz_leaf: []
# Li_dz_branch: []
# tree_height_array: []
# total_Li_dz_leaf: []
# total_Li_dz_branch: []
# acc_LAI_leaf: []
# acc_LAI_branch: []
# tree_density: 0.012166
# tree_percent_total: 10.595290
# mean_crown_d1: 8.514418
# std_crown_d1: 2.538544
# mean_crown_d2: 4.973075
# std_crown_d2: 1.986133
# mean_crown_center_height: 18.976128
# std_crown_center_height: 6.013906
# mean_tree_height: 27.490546
# std_tree_height: 8.532562
# total_leaf_veg_area: 1622.548380
# mean_crown_volume: 676.061825
# std_crown_volume: 618.844493
# total_crown_volume: 19807.168793
# adj_crown_volume: 10816.989199
# pixel_area: 870.920169
# total_vegetation_area_per_pixel: 1982.054240
# LAI_with_branch: 2.275816
# LAI_without_branch: 1.863028
# h1: 6.948317
# h2: 31.003940
# Fa: 0.150000
# Fa_b: 0.183235
# new_Fa: 0

# %%
### This block assigns French Guiana tree and circle data and plots and outputs the overhead visual representation of the site

# Redirecting stdout to a text file
output_file = output_path + 'guiana_tree_search_output_class.txt'

# Create the output directory if it doesn't exist
if not os.path.exists(output_path):
    os.makedirs(output_path)

# Specify region to French Guiana
region = 'guiana'

# Initialize list of Tree objects for French Guiana
guiana_tree_objects = []

# Initializes list of Circle objects for French Guiana site. Circles are assigned names and x_coord and y_coord
guiana_circle_objects = create_circle_data(radius)

# Use %%capture to capture output
with ipy_io.capture_output() as captured_output:

    # Load matlab data into lists for French Guiana
    guiana_tree_elements, guiana_x_values, guiana_y_values = load_matlab(region)
    
    # Get total tree count for French Guiana
    total_trees = len(guiana_x_values)

    # Loop interates through all trees in French Guiana
    for tree_index, (x, y, tree_element) in enumerate(zip(guiana_x_values, guiana_y_values, guiana_tree_elements), start=1):

        # Declare Tree object for French Guiana
        tree = lidar_sim_class_declarations.Tree(tree_index)
        print(f"Processing tree {tree_index} of {total_trees}")

        # Calls functions to assign basic tree info, then find tree in any of the circles in French Guiana
        calc_basic_tree_info(tree_index, tree_element, tree, guiana_x_values, guiana_y_values, "guiana")
        find_tree_in_circle(tree, guiana_circle_objects)

        # Append the Tree object to the list for French Guiana
        guiana_tree_objects.append(tree)

# Writes captured output to file for French Guiana
with open(output_file, "w") as file:
    file.write(captured_output.stdout)

print("French Guiana Trees:")

# Print attributes of each tree in French Guiana
for tree in guiana_tree_objects:
    print()
    tree.print_attributes()

print()

# Plot trees and circles for French Guiana
plot_trees(guiana_tree_objects, guiana_circle_objects, region)
# Out:
# French Guiana Trees:
#
# tree_index: 1
# x_coord: 55.95
# y_coord: -20.39
# crown_base: 10.6903
# crown_d1: 3.13846
# crown_d2: 1.41868
# crown_d3: 6.24553
# crown_base_height: 10.674605
# crown_center_height: 13.813065
# tree_height: 16.951525
# crown_volume: 26.459041027951855
# single_leaf_area: 0.01161
# total_leaf_area: 767.9736658363026
# total_tree_branch_area: 24.280263975442065
# total_tree_stem_area: 0
# total_tree_ground_area: 6.3229356980697204
# total_tree_canopy_veg_area: 792.2539298117447
# leaf_density: 291.5
# branch_scale: 0
#
# tree_index: 2
# x_coord: -51.72
# y_coord: 33.54
# crown_base: 8.87645
# crown_d1: 2.82546
# crown_d2: 1.16317
# crown_d3: 5.62266
# crown_base_height: 8.86232
# crown_center_height: 11.68778
# tree_height: 14.51324
# crown_volume: 16.012684903254968
# single_leaf_area: 0.01161
# total_leaf_area: 464.7681793169755
# total_tree_branch_area: 15.379986075110526
# total_tree_stem_area: 0
# total_tree_ground_area: 4.250463173232403
# total_tree_canopy_veg_area: 480.148165392086
# leaf_density: 291.5
# branch_scale: 0
#
# tree_index: 3
# x_coord: -62.09
# y_coord: 13.0
# crown_base: 9.98903
# crown_d1: 2.94564
# crown_d2: 1.3905
# crown_d3: 5.86181
# crown_base_height: 9.974294999999998
# crown_center_height: 12.919934999999999
# tree_height: 15.865575
# crown_volume: 23.856694235049183
# single_leaf_area: 0.01161
# total_leaf_area: 692.4405501723026
# total_tree_branch_area: 21.260998941771625
# total_tree_stem_area: 0
# total_tree_ground_area: 6.074238765187493
# total_tree_canopy_veg_area: 713.7015491140742
# leaf_density: 291.5
# branch_scale: 0
#
# tree_index: 4
# x_coord: 33.89
# y_coord: -55.33
# crown_base: 13.4656
# crown_d1: 4.39925
# crown_d2: 2.17272
# crown_d3: 8.7545
# crown_base_height: 13.443599999999998
# crown_center_height: 17.84285
# tree_height: 22.2421
# crown_volume: 86.99109071684141
# single_leaf_area: 0.01161
# total_leaf_area: 2524.9164080563223
# total_tree_branch_area: 78.38716352843524
# total_tree_stem_area: 0
# total_tree_ground_area: 14.830554762205162
# total_tree_canopy_veg_area: 2603.3035715847577
# leaf_density: 291.5
# branch_scale: 0
#
# tree_index: 5
# x_coord: 53.8
# y_coord: -33.69
# crown_base: 10.0644
# crown_d1: 3.21945
# crown_d2: 1.33417
# crown_d3: 6.4067
# crown_base_height: 10.0483
# crown_center_height: 13.26775
# tree_height: 16.487199999999998
# crown_volume: 24.004498424219026
# single_leaf_area: 0.01161
# total_leaf_area: 696.7305667629573
# total_tree_branch_area: 22.757133704286748
# total_tree_stem_area: 0
# total_tree_ground_area: 5.592065047807629
# total_tree_canopy_veg_area: 719.487700467244
# leaf_density: 291.5
# branch_scale: 0
#
# tree_index: 6
# x_coord: -53.52
# y_coord: -4.385
# crown_base: 14.1612
# crown_d1: 4.44842
# crown_d2: 2.37698
# crown_d3: 8.85236
# crown_base_height: 14.13896
# crown_center_height: 18.58738
# tree_height: 23.0358
# crown_volume: 105.27989644939342
# single_leaf_area: 0.01161
# total_leaf_area: 3055.7489944436443
# total_tree_branch_area: 92.40578750317097
# total_tree_stem_area: 0
# total_tree_ground_area: 17.75010505686178
# total_tree_canopy_veg_area: 3148.154781946815
# leaf_density: 291.5
# branch_scale: 0
#
# tree_index: 7
# x_coord: -53.43
# y_coord: -12.93
# crown_base: 13.6542
# crown_d1: 4.3873
# crown_d2: 2.38285
# crown_d3: 8.73074
# crown_base_height: 13.632270000000002
# crown_center_height: 18.01957
# tree_height: 22.406869999999998
# crown_volume: 104.34685170605836
# single_leaf_area: 0.01161
# total_leaf_area: 3028.667370768344
# total_tree_branch_area: 88.65873631245317
# total_tree_stem_area: 0
# total_tree_ground_area: 17.83788179051895
# total_tree_canopy_veg_area: 3117.326107080797
# leaf_density: 291.5
# branch_scale: 0
#
# tree_index: 8
# x_coord: -41.57
# y_coord: 26.13
# crown_base: 10.8755
# crown_d1: 3.45135
# crown_d2: 1.54776
# crown_d3: 6.86818
# crown_base_height: 10.85824
# crown_center_height: 14.30959
# tree_height: 17.76094
# crown_volume: 34.63258029135336
# single_leaf_area: 0.01161
# total_leaf_area: 1005.2106429565313
# total_tree_branch_area: 31.38079110243513
# total_tree_stem_area: 0
# total_tree_ground_area: 7.525876894118249
# total_tree_canopy_veg_area: 1036.5914340589663
# leaf_density: 291.5
# branch_scale: 0
#
# tree_index: 9
# x_coord: -64.31
# y_coord: 28.41
# crown_base: 16.4606
# crown_d1: 4.85346
# crown_d2: 3.06327
# crown_d3: 9.65838
# crown_base_height: 16.436329999999998
# crown_center_height: 21.28979
# tree_height: 26.14325
# crown_volume: 190.7702370687919
# single_leaf_area: 0.01161
# total_leaf_area: 5537.106130921685
# total_tree_branch_area: 163.9540182649972
# total_tree_stem_area: 0
# total_tree_ground_area: 29.479521372710174
# total_tree_canopy_veg_area: 5701.060149186682
# leaf_density: 291.5
# branch_scale: 0
#
# tree_index: 10
# x_coord: -58.1
# y_coord: 2.741
# crown_base: 11.6378
# crown_d1: 3.98927
# crown_d2: 1.73891
# crown_d3: 7.93865
# crown_base_height: 11.617855
# crown_center_height: 15.607125
# tree_height: 19.596395
# crown_volume: 50.52848190299975
# single_leaf_area: 0.01161
# total_leaf_area: 1466.5891872345678
# total_tree_branch_area: 47.223286562792644
# total_tree_stem_area: 0
# total_tree_ground_area: 9.49957296128109
# total_tree_canopy_veg_area: 1513.8124737973606
# leaf_density: 291.5
# branch_scale: 0
#
# tree_index: 11
# x_coord: -27.89
# y_coord: 63.75
# crown_base: 5.38576
# crown_d1: 1.66946
# crown_d2: 0.827106
# crown_d3: 3.32222
# crown_base_height: 5.37741
# crown_center_height: 7.04687
# tree_height: 8.716330000000001
# crown_volume: 4.783953721724948
# single_leaf_area: 0.01161
# total_leaf_area: 138.85425677306662
# total_tree_branch_area: 4.999514606135195
# total_tree_stem_area: 0
# total_tree_ground_area: 2.1491771538663467
# total_tree_canopy_veg_area: 143.85377137920182
# leaf_density: 291.5
# branch_scale: 0
#
# tree_index: 12
# x_coord: -34.99
# y_coord: 22.71
# crown_base: 14.0803
# crown_d1: 4.23008
# crown_d2: 2.32535
# crown_d3: 8.41785
# crown_base_height: 14.059144999999997
# crown_center_height: 18.289225
# tree_height: 22.519305
# crown_volume: 95.81066403606438
# single_leaf_area: 0.01161
# total_leaf_area: 2780.9045236467687
# total_tree_branch_area: 81.74805599255528
# total_tree_stem_area: 0
# total_tree_ground_area: 16.98738511495014
# total_tree_canopy_veg_area: 2862.652579639324
# leaf_density: 291.5
# branch_scale: 0
#
# tree_index: 13
# x_coord: -46.89
# y_coord: -9.659
# crown_base: 8.67898
# crown_d1: 2.82502
# crown_d2: 1.19346
# crown_d3: 5.62179
# crown_base_height: 8.664855
# crown_center_height: 11.489875
# tree_height: 14.314895
# crown_volume: 16.854888025195688
# single_leaf_area: 0.01161
# total_leaf_area: 489.2131249313049
# total_tree_branch_area: 15.698653014056127
# total_tree_stem_area: 0
# total_tree_ground_area: 4.474717353822899
# total_tree_canopy_veg_area: 504.911777945361
# leaf_density: 291.5
# branch_scale: 0
#
# tree_index: 14
# x_coord: -60.23
# y_coord: 25.45
# crown_base: 7.28397
# crown_d1: 2.27435
# crown_d2: 0.974761
# crown_d3: 4.52595
# crown_base_height: 7.272595000000001
# crown_center_height: 9.546945000000001
# tree_height: 11.821295
# crown_volume: 9.051951077208654
# single_leaf_area: 0.01161
# total_leaf_area: 262.7328800159812
# total_tree_branch_area: 8.941802806844503
# total_tree_stem_area: 0
# total_tree_ground_area: 2.9850125565135053
# total_tree_canopy_veg_area: 271.67468282282573
# leaf_density: 291.5
# branch_scale: 0
#
# tree_index: 15
# x_coord: -68.85
# y_coord: -3.106
# crown_base: 16.9863
# crown_d1: 5.53237
# crown_d2: 3.53129
# crown_d3: 11.0094
# crown_base_height: 16.95863
# crown_center_height: 22.491
# tree_height: 28.02337
# crown_volume: 288.9792077486032
# single_leaf_area: 0.01161
# total_leaf_area: 8387.621504903209
# total_tree_branch_area: 256.91040361406596
# total_tree_stem_area: 0
# total_tree_ground_area: 39.17568886597469
# total_tree_canopy_veg_area: 8644.531908517274
# leaf_density: 291.5
# branch_scale: 0
#
# tree_index: 16
# x_coord: -40.19
# y_coord: 3.119
# crown_base: 9.22239
# crown_d1: 3.03456
# crown_d2: 1.21585
# crown_d3: 6.03877
# crown_base_height: 9.207215000000001
# crown_center_height: 12.241775
# tree_height: 15.276335
# crown_volume: 18.79075959984238
# single_leaf_area: 0.01161
# total_leaf_area: 545.4017973854252
# total_tree_branch_area: 17.953269943817684
# total_tree_stem_area: 0
# total_tree_ground_area: 4.644188844472275
# total_tree_canopy_veg_area: 563.3550673292428
# leaf_density: 291.5
# branch_scale: 0
#
# tree_index: 17
# x_coord: -37.54
# y_coord: 55.19
# crown_base: 8.24161
# crown_d1: 2.68145
# crown_d2: 1.17591
# crown_d3: 5.33609
# crown_base_height: 8.228205
# crown_center_height: 10.909655
# tree_height: 13.591104999999999
# crown_volume: 15.531252482862438
# single_leaf_area: 0.01161
# total_leaf_area: 450.7946033150823
# total_tree_branch_area: 14.56279765196183
# total_tree_stem_area: 0
# total_tree_ground_area: 4.344082254804986
# total_tree_canopy_veg_area: 465.35740096704416
# leaf_density: 291.5
# branch_scale: 0
#
# tree_index: 18
# x_coord: -55.77
# y_coord: 34.29
# crown_base: 6.16187
# crown_d1: 1.85898
# crown_d2: 0.835532
# crown_d3: 3.69937
# crown_base_height: 6.1525750000000015
# crown_center_height: 8.011555000000001
# tree_height: 9.870535
# crown_volume: 5.436125843220271
# single_leaf_area: 0.01161
# total_leaf_area: 157.78355259946838
# total_tree_branch_area: 5.690459279025754
# total_tree_stem_area: 0
# total_tree_ground_area: 2.193188943622418
# total_tree_canopy_veg_area: 163.47401187849414
# leaf_density: 291.5
# branch_scale: 0
#
# tree_index: 19
# x_coord: -35.57
# y_coord: 37.83
# crown_base: 13.4167
# crown_d1: 4.17673
# crown_d2: 2.07372
# crown_d3: 8.3117
# crown_base_height: 13.39582
# crown_center_height: 17.57255
# tree_height: 21.749280000000002
# crown_volume: 75.23592130080719
# single_leaf_area: 0.01161
# total_leaf_area: 2183.722615755929
# total_tree_branch_area: 68.41538885160287
# total_tree_stem_area: 0
# total_tree_ground_area: 13.509836876122083
# total_tree_canopy_veg_area: 2252.138004607532
# leaf_density: 291.5
# branch_scale: 0
#
# tree_index: 20
# x_coord: 42.83
# y_coord: -53.73
# crown_base: 10.7986
# crown_d1: 3.30559
# crown_d2: 1.45377
# crown_d3: 6.57813
# crown_base_height: 10.782075
# crown_center_height: 14.087665000000001
# tree_height: 17.393255
# crown_volume: 29.263684125543485
# single_leaf_area: 0.01161
# total_leaf_area: 849.3784317438997
# total_tree_branch_area: 26.915622687198464
# total_tree_stem_area: 0
# total_tree_ground_area: 6.6395902377964635
# total_tree_canopy_veg_area: 876.2940544310982
# leaf_density: 291.5
# branch_scale: 0
#
# tree_index: 21
# x_coord: -68.12
# y_coord: -17.51
# crown_base: 12.6628
# crown_d1: 3.9627
# crown_d2: 1.93912
# crown_d3: 7.88576
# crown_base_height: 12.64298
# crown_center_height: 16.60568
# tree_height: 20.56838
# crown_volume: 62.41502884490536
# single_leaf_area: 0.01161
# total_leaf_area: 1811.5962122233782
# total_tree_branch_area: 55.30480778509188
# total_tree_stem_area: 0
# total_tree_ground_area: 11.812973889943478
# total_tree_canopy_veg_area: 1866.9010200084701
# leaf_density: 291.5
# branch_scale: 0
#
# tree_index: 22
# x_coord: -52.24
# y_coord: 15.08
# crown_base: 12.0699
# crown_d1: 3.54204
# crown_d2: 1.6495
# crown_d3: 7.04867
# crown_base_height: 12.052195000000001
# crown_center_height: 15.594235000000001
# tree_height: 19.136275
# crown_volume: 40.368880925239544
# single_leaf_area: 0.01161
# total_leaf_area: 1171.7067688550778
# total_tree_branch_area: 37.05725171395271
# total_tree_stem_area: 0
# total_tree_ground_area: 8.54780315691795
# total_tree_canopy_veg_area: 1208.7640205690304
# leaf_density: 291.5
# branch_scale: 0
#
# tree_index: 23
# x_coord: -59.7
# y_coord: -5.179
# crown_base: 8.76313
# crown_d1: 2.82061
# crown_d2: 1.20901
# crown_d3: 5.61302
# crown_base_height: 8.74903
# crown_center_height: 11.56964
# tree_height: 14.39025
# crown_volume: 17.269964174309123
# single_leaf_area: 0.01161
# total_leaf_area: 501.26071015932234
# total_tree_branch_area: 15.635849092388082
# total_tree_stem_area: 0
# total_tree_ground_area: 4.592082255516305
# total_tree_canopy_veg_area: 516.8965592517104
# leaf_density: 291.5
# branch_scale: 0
#
# tree_index: 24
# x_coord: -62.95
# y_coord: -22.69
# crown_base: 6.70193
# crown_d1: 2.23829
# crown_d2: 0.959392
# crown_d3: 4.4542
# crown_base_height: 6.690740000000001
# crown_center_height: 8.929030000000001
# tree_height: 11.16732
# crown_volume: 8.629728829770148
# single_leaf_area: 0.01161
# total_leaf_area: 250.47787928407857
# total_tree_branch_area: 8.530999778347685
# total_tree_stem_area: 0
# total_tree_ground_area: 2.8916255812819656
# total_tree_canopy_veg_area: 259.0088790624263
# leaf_density: 291.5
# branch_scale: 0
#
# tree_index: 25
# x_coord: -20.95
# y_coord: 62.43
# crown_base: 7.41325
# crown_d1: 2.28574
# crown_d2: 1.03725
# crown_d3: 4.54862
# crown_base_height: 7.401819999999999
# crown_center_height: 9.68756
# tree_height: 11.9733
# crown_volume: 10.301069676019296
# single_leaf_area: 0.01161
# total_leaf_area: 298.98854734646005
# total_tree_branch_area: 9.769247060032018
# total_tree_stem_area: 0
# total_tree_ground_area: 3.380000462438629
# total_tree_canopy_veg_area: 308.75779440649205
# leaf_density: 291.5
# branch_scale: 0
#
# tree_index: 26
# x_coord: -12.1
# y_coord: 62.76
# crown_base: 9.62786
# crown_d1: 3.23292
# crown_d2: 1.35847
# crown_d3: 6.43351
# crown_base_height: 9.611695000000001
# crown_center_height: 12.844615000000001
# tree_height: 16.077535
# crown_volume: 24.99100211892505
# single_leaf_area: 0.01161
# total_leaf_area: 725.3638365017996
# total_tree_branch_area: 23.068583575029315
# total_tree_stem_area: 0
# total_tree_ground_area: 5.797623074246745
# total_tree_canopy_veg_area: 748.4324200768289
# leaf_density: 291.5
# branch_scale: 0
#
# tree_index: 27
# x_coord: -50.76
# y_coord: 41.55
# crown_base: 5.89239
# crown_d1: 2.00269
# crown_d2: 0.894584
# crown_d3: 3.98536
# crown_base_height: 5.8823799999999995
# crown_center_height: 7.88507
# tree_height: 9.88776
# crown_volume: 6.713431953416284
# single_leaf_area: 0.01161
# total_leaf_area: 194.85736244790763
# total_tree_branch_area: 6.966595055847189
# total_tree_stem_area: 0
# total_tree_ground_area: 2.5141554434596536
# total_tree_canopy_veg_area: 201.82395750375483
# leaf_density: 291.5
# branch_scale: 0
#
# tree_index: 28
# x_coord: -9.239
# y_coord: 43.94
# crown_base: 16.7933
# crown_d1: 5.41356
# crown_d2: 3.40086
# crown_d3: 10.773
# crown_base_height: 16.76624
# crown_center_height: 22.1798
# tree_height: 27.593359999999997
# crown_volume: 262.2702752692046
# single_leaf_area: 0.01161
# total_leaf_area: 7612.394739688664
# total_tree_branch_area: 231.13377138308493
# total_tree_stem_area: 0
# total_tree_ground_area: 36.33518543285813
# total_tree_canopy_veg_area: 7843.52851107175
# leaf_density: 291.5
# branch_scale: 0
#
# tree_index: 29
# x_coord: -56.78
# y_coord: 38.91
# crown_base: 10.3637
# crown_d1: 3.45746
# crown_d2: 1.45864
# crown_d3: 6.88035
# crown_base_height: 10.346415
# crown_center_height: 13.803875
# tree_height: 17.261335
# crown_volume: 30.81356956459124
# single_leaf_area: 0.01161
# total_leaf_area: 894.3638566122609
# total_tree_branch_area: 29.09048341642117
# total_tree_stem_area: 0
# total_tree_ground_area: 6.684148818335839
# total_tree_canopy_veg_area: 923.454340028682
# leaf_density: 291.5
# branch_scale: 0
#
# tree_index: 30
# x_coord: -31.36
# y_coord: 36.34
# crown_base: 9.38803
# crown_d1: 2.96256
# crown_d2: 1.29036
# crown_d3: 5.89549
# crown_base_height: 9.373215
# crown_center_height: 12.335775
# tree_height: 15.298335
# crown_volume: 20.662246947733312
# single_leaf_area: 0.01161
# total_leaf_area: 599.7217176579594
# total_tree_branch_area: 18.518033772823795
# total_tree_stem_area: 0
# total_tree_ground_area: 5.230842653245836
# total_tree_canopy_veg_area: 618.2397514307831
# leaf_density: 291.5
# branch_scale: 0
#
# tree_index: 31
# x_coord: -55.26
# y_coord: 27.08
# crown_base: 9.50065
# crown_d1: 3.11663
# crown_d2: 1.35091
# crown_d3: 6.20209
# crown_base_height: 9.485064999999999
# crown_center_height: 12.601695
# tree_height: 15.718325
# crown_volume: 23.824658768770757
# single_leaf_area: 0.01161
# total_leaf_area: 691.5107207635713
# total_tree_branch_area: 21.979042510279072
# total_tree_stem_area: 0
# total_tree_ground_area: 5.733274105870144
# total_tree_canopy_veg_area: 713.4897632738504
# leaf_density: 291.5
# branch_scale: 0
#
# tree_index: 32
# x_coord: -55.47
# y_coord: 4.86
# crown_base: 14.3508
# crown_d1: 4.49595
# crown_d2: 2.4258
# crown_d3: 8.94695
# crown_base_height: 14.328325
# crown_center_height: 18.824275
# tree_height: 23.320225
# crown_volume: 110.8204898454716
# single_leaf_area: 0.01161
# total_leaf_area: 3216.5647177648134
# total_tree_branch_area: 97.51774310490144
# total_tree_stem_area: 0
# total_tree_ground_area: 18.486719688631705
# total_tree_canopy_veg_area: 3314.082460869715
# leaf_density: 291.5
# branch_scale: 0
#
# tree_index: 33
# x_coord: -43.09
# y_coord: 7.562
# crown_base: 12.4032
# crown_d1: 4.0144
# crown_d2: 1.86686
# crown_d3: 7.98866
# crown_base_height: 12.38313
# crown_center_height: 16.39753
# tree_height: 20.41193
# crown_volume: 58.60474143723782
# single_leaf_area: 0.01161
# total_leaf_area: 1701.0026202158278
# total_tree_branch_area: 54.08141962052308
# total_tree_stem_area: 0
# total_tree_ground_area: 10.948972717698377
# total_tree_canopy_veg_area: 1755.084039836351
# leaf_density: 291.5
# branch_scale: 0
#
# tree_index: 34
# x_coord: -56.85
# y_coord: 12.05
# crown_base: 7.91257
# crown_d1: 2.58283
# crown_d2: 1.08757
# crown_d3: 5.13983
# crown_base_height: 7.899655000000001
# crown_center_height: 10.482485
# tree_height: 13.065315
# crown_volume: 12.796725971817821
# single_leaf_area: 0.01161
# total_leaf_area: 371.42497133201226
# total_tree_branch_area: 12.485918320566494
# total_tree_stem_area: 0
# total_tree_ground_area: 3.7159025095973663
# total_tree_canopy_veg_area: 383.91088965257876
# leaf_density: 291.5
# branch_scale: 0
#
# tree_index: 35
# x_coord: -54.58
# y_coord: 1.669
# crown_base: 6.43192
# crown_d1: 1.89564
# crown_d2: 0.886136
# crown_d3: 3.77232
# crown_base_height: 6.42244
# crown_center_height: 8.31808
# tree_height: 10.21372
# crown_volume: 6.235126004295361
# single_leaf_area: 0.01161
# total_leaf_area: 180.97453227467287
# total_tree_branch_area: 6.22688523417803
# total_tree_stem_area: 0
# total_tree_ground_area: 2.466894823501045
# total_tree_canopy_veg_area: 187.2014175088509
# leaf_density: 291.5
# branch_scale: 0
#
# tree_index: 36
# x_coord: -56.35
# y_coord: 17.51
# crown_base: 10.4634
# crown_d1: 3.4153
# crown_d2: 1.53555
# crown_d3: 6.79645
# crown_base_height: 10.446325
# crown_center_height: 13.861625
# tree_height: 17.276925
# crown_volume: 33.732256350251475
# single_leaf_area: 0.01161
# total_leaf_area: 979.0787405660492
# total_tree_branch_area: 30.173208728268413
# total_tree_stem_area: 0
# total_tree_ground_area: 7.407604679731974
# total_tree_canopy_veg_area: 1009.2519492943176
# leaf_density: 291.5
# branch_scale: 0
#
# tree_index: 37
# x_coord: -63.08
# y_coord: -8.831
# crown_base: 11.7411
# crown_d1: 3.75668
# crown_d2: 1.7384
# crown_d3: 7.4758
# crown_base_height: 11.72232
# crown_center_height: 15.479
# tree_height: 19.23568
# crown_volume: 47.55456777029218
# single_leaf_area: 0.01161
# total_leaf_area: 1380.2713295327308
# total_tree_branch_area: 43.3377235050459
# total_tree_stem_area: 0
# total_tree_ground_area: 9.494001572590463
# total_tree_canopy_veg_area: 1423.6090530377767
# leaf_density: 291.5
# branch_scale: 0
#
# tree_index: 38
# x_coord: -55.26
# y_coord: -40.48
# crown_base: 8.84776
# crown_d1: 2.79807
# crown_d2: 1.24379
# crown_d3: 5.56816
# crown_base_height: 8.833769999999998
# crown_center_height: 11.631839999999999
# tree_height: 14.42991
# crown_volume: 18.131816116667064
# single_leaf_area: 0.01161
# total_leaf_area: 526.2759627862616
# total_tree_branch_area: 16.61294605557308
# total_tree_stem_area: 0
# total_tree_ground_area: 4.860086447980322
# total_tree_canopy_veg_area: 542.8889088418347
# leaf_density: 291.5
# branch_scale: 0
#
# tree_index: 39
# x_coord: -44.22
# y_coord: -53.16
# crown_base: 9.98524
# crown_d1: 3.34206
# crown_d2: 1.44137
# crown_d3: 6.65069
# crown_base_height: 9.968525
# crown_center_height: 13.310585
# tree_height: 16.652645
# crown_volume: 29.083978106539824
# single_leaf_area: 0.01161
# total_leaf_area: 844.1624645423185
# total_tree_branch_area: 26.961740707112266
# total_tree_stem_area: 0
# total_tree_ground_area: 6.526807890913051
# total_tree_canopy_veg_area: 871.1242052494308
# leaf_density: 291.5
# branch_scale: 0
#
# tree_index: 40
# x_coord: -41.75
# y_coord: -49.65
# crown_base: 7.80107
# crown_d1: 2.47375
# crown_d2: 1.00489
# crown_d3: 4.92276
# crown_base_height: 7.788700000000001
# crown_center_height: 10.262450000000001
# tree_height: 12.7362
# crown_volume: 10.46360810008496
# single_leaf_area: 0.01161
# total_leaf_area: 303.706225104966
# total_tree_branch_area: 10.41827479968926
# total_tree_stem_area: 0
# total_tree_ground_area: 3.172392551819594
# total_tree_canopy_veg_area: 314.12449990465524
# leaf_density: 291.5
# branch_scale: 0
#
# tree_index: 41
# x_coord: -14.78
# y_coord: 59.19
# crown_base: 9.14956
# crown_d1: 3.06913
# crown_d2: 1.28633
# crown_d3: 6.10757
# crown_base_height: 9.134215
# crown_center_height: 12.203344999999999
# tree_height: 15.272474999999998
# crown_volume: 21.272017937701783
# single_leaf_area: 0.01161
# total_leaf_area: 617.4203206417943
# total_tree_branch_area: 19.45852454411236
# total_tree_stem_area: 0
# total_tree_ground_area: 5.198220164436286
# total_tree_canopy_veg_area: 636.8788451859067
# leaf_density: 291.5
# branch_scale: 0
#
# tree_index: 42
# x_coord: -11.51
# y_coord: 48.89
# crown_base: 9.54994
# crown_d1: 3.02337
# crown_d2: 1.29478
# crown_d3: 6.0165
# crown_base_height: 9.53482
# crown_center_height: 12.55819
# tree_height: 15.58156
# crown_volume: 21.231069572366568
# single_leaf_area: 0.01161
# total_leaf_area: 616.2317943379397
# total_tree_branch_area: 20.12783953721735
# total_tree_stem_area: 0
# total_tree_ground_area: 5.266739492445493
# total_tree_canopy_veg_area: 636.3596338751571
# leaf_density: 291.5
# branch_scale: 0
#
# tree_index: 43
# x_coord: 1.826
# y_coord: 64.59
# crown_base: 16.2269
# crown_d1: 4.82017
# crown_d2: 3.02319
# crown_d3: 9.59215
# crown_base_height: 16.202805
# crown_center_height: 21.022975000000002
# tree_height: 25.843145
# crown_volume: 184.53631733610644
# single_leaf_area: 0.01161
# total_leaf_area: 5356.16661068049
# total_tree_branch_area: 155.63364424840694
# total_tree_stem_area: 0
# total_tree_ground_area: 28.71314455757366
# total_tree_canopy_veg_area: 5511.800254928897
# leaf_density: 291.5
# branch_scale: 0
#
# tree_index: 44
# x_coord: -35.97
# y_coord: 26.66
# crown_base: 10.5905
# crown_d1: 3.33451
# crown_d2: 1.47105
# crown_d3: 6.63567
# crown_base_height: 10.573825000000001
# crown_center_height: 13.908335000000001
# tree_height: 17.242845
# crown_volume: 30.225639775870825
# single_leaf_area: 0.01161
# total_leaf_area: 877.2991944946508
# total_tree_branch_area: 28.189564329439364
# total_tree_stem_area: 0
# total_tree_ground_area: 6.798369125269716
# total_tree_canopy_veg_area: 905.4887588240902
# leaf_density: 291.5
# branch_scale: 0
#
# tree_index: 45
# x_coord: -14.72
# y_coord: 37.98
# crown_base: 14.656
# crown_d1: 4.39418
# crown_d2: 2.43086
# crown_d3: 8.74441
# crown_base_height: 14.634025
# crown_center_height: 19.028205
# tree_height: 23.422385000000002
# crown_volume: 108.76429447611159
# single_leaf_area: 0.01161
# total_leaf_area: 3156.883647169139
# total_tree_branch_area: 94.14757467171614
# total_tree_stem_area: 0
# total_tree_ground_area: 18.56392338435924
# total_tree_canopy_veg_area: 3251.031221840855
# leaf_density: 291.5
# branch_scale: 0
#
# tree_index: 46
# x_coord: -52.98
# y_coord: 20.79
# crown_base: 9.91388
# crown_d1: 2.89561
# crown_d2: 1.35739
# crown_d3: 5.76226
# crown_base_height: 9.899400000000002
# crown_center_height: 12.795010000000001
# tree_height: 15.690620000000001
# crown_volume: 22.347964245937668
# single_leaf_area: 0.01161
# total_leaf_area: 648.6496622383409
# total_tree_branch_area: 19.728506658550426
# total_tree_stem_area: 0
# total_tree_ground_area: 5.788408378356634
# total_tree_canopy_veg_area: 668.3781688968912
# leaf_density: 291.5
# branch_scale: 0
#
# tree_index: 47
# x_coord: -59.23
# y_coord: -21.06
# crown_base: 17.4492
# crown_d1: 5.14603
# crown_d2: 3.65408
# crown_d3: 10.2406
# crown_base_height: 17.423470000000002
# crown_center_height: 22.5695
# tree_height: 27.71553
# crown_volume: 287.8173866738158
# single_leaf_area: 0.01161
# total_leaf_area: 8353.899648207504
# total_tree_branch_area: 232.41944454268832
# total_tree_stem_area: 0
# total_tree_ground_area: 41.94748961925249
# total_tree_canopy_veg_area: 8586.319092750193
# leaf_density: 291.5
# branch_scale: 0
#
# tree_index: 48
# x_coord: -19.49
# y_coord: 13.46
# crown_base: 7.88253
# crown_d1: 2.44978
# crown_d2: 1.05821
# crown_d3: 4.87506
# crown_base_height: 7.870279999999999
# crown_center_height: 10.32006
# tree_height: 12.76984
# crown_volume: 11.491042120767972
# single_leaf_area: 0.01161
# total_leaf_area: 333.5274975552904
# total_tree_branch_area: 11.011788885027036
# total_tree_stem_area: 0
# total_tree_ground_area: 3.5179818557486713
# total_tree_canopy_veg_area: 344.5392864403174
# leaf_density: 291.5
# branch_scale: 0
#
# tree_index: 49
# x_coord: -44.83
# y_coord: 2.61
# crown_base: 8.72944
# crown_d1: 2.9844
# crown_d2: 1.26109
# crown_d3: 5.93895
# crown_base_height: 8.714514999999999
# crown_center_height: 11.698915
# tree_height: 14.683315
# crown_volume: 19.88098073269889
# single_leaf_area: 0.01161
# total_leaf_area: 577.0454657665854
# total_tree_branch_area: 18.15835200336956
# total_tree_stem_area: 0
# total_tree_ground_area: 4.9962255560662685
# total_tree_canopy_veg_area: 595.203817769955
# leaf_density: 291.5
# branch_scale: 0
#
# tree_index: 50
# x_coord: -52.82
# y_coord: -8.078
# crown_base: 10.2807
# crown_d1: 3.01292
# crown_d2: 1.40029
# crown_d3: 5.99572
# crown_base_height: 10.26564
# crown_center_height: 13.278559999999999
# tree_height: 16.29148
# crown_volume: 24.746408875345463
# single_leaf_area: 0.01161
# total_leaf_area: 718.2645176069021
# total_tree_branch_area: 22.201169024494465
# total_tree_stem_area: 0
# total_tree_ground_area: 6.160072838478651
# total_tree_canopy_veg_area: 740.4656866313966
# leaf_density: 291.5
# branch_scale: 0
#
# tree_index: 51
# x_coord: -41.89
# y_coord: -8.363
# crown_base: 14.9043
# crown_d1: 4.50817
# crown_d2: 2.64196
# crown_d3: 8.97126
# crown_base_height: 14.88176
# crown_center_height: 19.38993
# tree_height: 23.8981
# crown_volume: 131.80787849030477
# single_leaf_area: 0.01161
# total_leaf_area: 3825.7236731810963
# total_tree_branch_area: 111.91838656069477
# total_tree_stem_area: 0
# total_tree_ground_area: 21.928167941255232
# total_tree_canopy_veg_area: 3937.642059741791
# leaf_density: 291.5
# branch_scale: 0
#
# tree_index: 52
# x_coord: -65.38
# y_coord: -20.5
# crown_base: 10.1219
# crown_d1: 3.24198
# crown_d2: 1.44052
# crown_d3: 6.45154
# crown_base_height: 10.105690000000001
# crown_center_height: 13.34767
# tree_height: 16.58965
# crown_volume: 28.1797752688293
# single_leaf_area: 0.01161
# total_leaf_area: 817.9179771777705
# total_tree_branch_area: 25.455472113521246
# total_tree_stem_area: 0
# total_tree_ground_area: 6.519112225128465
# total_tree_canopy_veg_area: 843.3734492912918
# leaf_density: 291.5
# branch_scale: 0
#
# tree_index: 53
# x_coord: -7.519
# y_coord: 20.27
# crown_base: 9.68658
# crown_d1: 3.0525
# crown_d2: 1.32462
# crown_d3: 6.07447
# crown_base_height: 9.671314999999998
# crown_center_height: 12.723814999999998
# tree_height: 15.776315
# crown_volume: 22.435042572270742
# single_leaf_area: 0.01161
# total_leaf_area: 651.1771106601583
# total_tree_branch_area: 20.74189795411879
# total_tree_stem_area: 0
# total_tree_ground_area: 5.512295472302394
# total_tree_canopy_veg_area: 671.9190086142771
# leaf_density: 291.5
# branch_scale: 0
#
# tree_index: 54
# x_coord: -15.88
# y_coord: 62.85
# crown_base: 11.884
# crown_d1: 3.52902
# crown_d2: 1.71994
# crown_d3: 7.02276
# crown_base_height: 11.86636
# crown_center_height: 15.39538
# tree_height: 18.9244
# crown_volume: 43.72897751155086
# single_leaf_area: 0.01161
# total_leaf_area: 1269.2335722727637
# total_tree_branch_area: 38.61910465775062
# total_tree_stem_area: 0
# total_tree_ground_area: 9.293439292966077
# total_tree_canopy_veg_area: 1307.8526769305142
# leaf_density: 291.5
# branch_scale: 0
#
# tree_index: 55
# x_coord: -22.54
# y_coord: 59.04
# crown_base: 12.3964
# crown_d1: 3.9458
# crown_d2: 1.89477
# crown_d3: 7.85215
# crown_base_height: 12.376675
# crown_center_height: 16.322475
# tree_height: 20.268275
# crown_volume: 59.338515556685834
# single_leaf_area: 0.01161
# total_leaf_area: 1722.3004140328064
# total_tree_branch_area: 52.95062628161909
# total_tree_stem_area: 0
# total_tree_ground_area: 11.278799398731405
# total_tree_canopy_veg_area: 1775.2510403144256
# leaf_density: 291.5
# branch_scale: 0
#
# tree_index: 56
# x_coord: -42.94
# y_coord: 49.3
# crown_base: 10.0628
# crown_d1: 3.12786
# crown_d2: 1.38321
# crown_d3: 6.22445
# crown_base_height: 10.047165
# crown_center_height: 13.175025
# tree_height: 16.302885
# crown_volume: 25.06756533802341
# single_leaf_area: 0.01161
# total_leaf_area: 727.5860839361295
# total_tree_branch_area: 22.657525225170488
# total_tree_stem_area: 0
# total_tree_ground_area: 6.0107146750550084
# total_tree_canopy_veg_area: 750.2436091613
# leaf_density: 291.5
# branch_scale: 0
#
# tree_index: 57
# x_coord: -15.24
# y_coord: 19.46
# crown_base: 8.63613
# crown_d1: 2.62988
# crown_d2: 1.17463
# crown_d3: 5.23346
# crown_base_height: 8.62298
# crown_center_height: 11.25286
# tree_height: 13.88274
# crown_volume: 15.199409597876118
# single_leaf_area: 0.01161
# total_leaf_area: 441.16286357835435
# total_tree_branch_area: 14.297202960668486
# total_tree_stem_area: 0
# total_tree_ground_area: 4.334630172634147
# total_tree_canopy_veg_area: 455.4600665390228
# leaf_density: 291.5
# branch_scale: 0
#
# tree_index: 58
# x_coord: -36.27
# y_coord: -3.445
# crown_base: 7.14055
# crown_d1: 2.17502
# crown_d2: 0.953338
# crown_d3: 4.3283
# crown_base_height: 7.1296800000000005
# crown_center_height: 9.3047
# tree_height: 11.47972
# crown_volume: 8.280292391153964
# single_leaf_area: 0.01161
# total_leaf_area: 240.3354866532438
# total_tree_branch_area: 8.222043626059627
# total_tree_stem_area: 0
# total_tree_ground_area: 2.8552469831842804
# total_tree_canopy_veg_area: 248.55753027930342
# leaf_density: 291.5
# branch_scale: 0
#
# tree_index: 59
# x_coord: -39.27
# y_coord: 39.57
# crown_base: 9.52676
# crown_d1: 3.14938
# crown_d2: 1.27317
# crown_d3: 6.26728
# crown_base_height: 9.511019999999998
# crown_center_height: 12.6604
# tree_height: 15.80978
# crown_volume: 21.383877993413677
# single_leaf_area: 0.01161
# total_leaf_area: 620.667058758832
# total_tree_branch_area: 20.4745661176958
# total_tree_stem_area: 0
# total_tree_ground_area: 5.0924018362535675
# total_tree_canopy_veg_area: 641.1416248765278
# leaf_density: 291.5
# branch_scale: 0
#
# tree_index: 60
# x_coord: -11.26
# y_coord: 6.897
# crown_base: 12.6689
# crown_d1: 3.78328
# crown_d2: 1.84632
# crown_d3: 7.52872
# crown_base_height: 12.649980000000001
# crown_center_height: 16.43326
# tree_height: 20.216540000000002
# crown_volume: 54.022047713024364
# single_leaf_area: 0.01161
# total_leaf_area: 1567.9899348705324
# total_tree_branch_area: 48.31486324293428
# total_tree_stem_area: 0
# total_tree_ground_area: 10.70936747604414
# total_tree_canopy_veg_area: 1616.3047981134666
# leaf_density: 291.5
# branch_scale: 0
#
# tree_index: 61
# x_coord: -48.47
# y_coord: 10.88
# crown_base: 7.45524
# crown_d1: 2.27319
# crown_d2: 1.02921
# crown_d3: 4.52364
# crown_base_height: 7.44387
# crown_center_height: 9.71706
# tree_height: 11.99025
# crown_volume: 10.08631066688077
# single_leaf_area: 0.01161
# total_leaf_area: 292.7551671062144
# total_tree_branch_area: 9.64753566233738
# total_tree_stem_area: 0
# total_tree_ground_area: 3.3278049789769346
# total_tree_canopy_veg_area: 302.40270276855176
# leaf_density: 291.5
# branch_scale: 0
#
# tree_index: 62
# x_coord: -40.71
# y_coord: -0.4413
# crown_base: 9.52397
# crown_d1: 3.22823
# crown_d2: 1.33272
# crown_d3: 6.42417
# crown_base_height: 9.507825
# crown_center_height: 12.736055
# tree_height: 15.964285
# crown_volume: 24.01767195766439
# single_leaf_area: 0.01161
# total_leaf_area: 697.112928571209
# total_tree_branch_area: 22.491570768740825
# total_tree_stem_area: 0
# total_tree_ground_area: 5.579916538861325
# total_tree_canopy_veg_area: 719.6044993399498
# leaf_density: 291.5
# branch_scale: 0
#
# tree_index: 63
# x_coord: -36.33
# y_coord: 0.8319
# crown_base: 13.1332
# crown_d1: 4.20483
# crown_d2: 2.06325
# crown_d3: 8.36761
# crown_base_height: 13.112175
# crown_center_height: 17.317005
# tree_height: 21.521835
# crown_volume: 74.97919250878066
# single_leaf_area: 0.01161
# total_leaf_area: 2176.2710625673585
# total_tree_branch_area: 67.3731132528148
# total_tree_stem_area: 0
# total_tree_ground_area: 13.373761693477617
# total_tree_canopy_veg_area: 2243.644175820173
# leaf_density: 291.5
# branch_scale: 0
#
# tree_index: 64
# x_coord: -35.1
# y_coord: 7.774
# crown_base: 12.6198
# crown_d1: 3.96251
# crown_d2: 1.95062
# crown_d3: 7.88539
# crown_base_height: 12.599984999999998
# crown_center_height: 16.562495
# tree_height: 20.525005
# crown_volume: 63.15450363219711
# single_leaf_area: 0.01161
# total_leaf_area: 1833.0594679245214
# total_tree_branch_area: 55.65910256021888
# total_tree_stem_area: 0
# total_tree_ground_area: 11.953503643939785
# total_tree_canopy_veg_area: 1888.7185704847402
# leaf_density: 291.5
# branch_scale: 0
#
# tree_index: 65
# x_coord: -31.55
# y_coord: 25.57
# crown_base: 12.2631
# crown_d1: 3.75113
# crown_d2: 1.76803
# crown_d3: 7.46475
# crown_base_height: 12.244345
# crown_center_height: 15.995474999999999
# tree_height: 19.746605
# crown_volume: 49.11679095674714
# single_leaf_area: 0.01161
# total_leaf_area: 1425.6148575195857
# total_tree_branch_area: 45.07833748581036
# total_tree_stem_area: 0
# total_tree_ground_area: 9.820398977790788
# total_tree_canopy_veg_area: 1470.693195005396
# leaf_density: 291.5
# branch_scale: 0
#
# tree_index: 66
# x_coord: -56.55
# y_coord: -14.75
# crown_base: 13.406
# crown_d1: 4.59306
# crown_d2: 2.25936
# crown_d3: 9.1402
# crown_base_height: 13.383040000000001
# crown_center_height: 17.976100000000002
# tree_height: 22.56916
# crown_volume: 98.21133158191903
# single_leaf_area: 0.01161
# total_leaf_area: 2850.5838991652
# total_tree_branch_area: 89.41312111318918
# total_tree_stem_area: 0
# total_tree_ground_area: 16.036911925043274
# total_tree_canopy_veg_area: 2939.9970202783893
# leaf_density: 291.5
# branch_scale: 0
#
# tree_index: 67
# x_coord: -59.71
# y_coord: -33.37
# crown_base: 6.30793
# crown_d1: 2.11034
# crown_d2: 0.920986
# crown_d3: 4.19958
# crown_base_height: 6.2973799999999995
# crown_center_height: 8.40772
# tree_height: 10.51806
# crown_volume: 7.498028676253159
# single_leaf_area: 0.01161
# total_leaf_area: 217.63028232824794
# total_tree_branch_area: 7.588717030446088
# total_tree_stem_area: 0
# total_tree_ground_area: 2.664746679298061
# total_tree_canopy_veg_area: 225.21899935869402
# leaf_density: 291.5
# branch_scale: 0
#
# tree_index: 68
# x_coord: -50.63
# y_coord: 3.362
# crown_base: 7.45398
# crown_d1: 2.4669
# crown_d2: 1.03396
# crown_d3: 4.90913
# crown_base_height: 7.441645
# crown_center_height: 9.908545
# tree_height: 12.375445000000001
# crown_volume: 11.047083331267848
# single_leaf_area: 0.01161
# total_leaf_area: 320.6415936900493
# total_tree_branch_area: 10.78666485410892
# total_tree_stem_area: 0
# total_tree_ground_area: 3.358592767623692
# total_tree_canopy_veg_area: 331.4282585441582
# leaf_density: 291.5
# branch_scale: 0
#
# tree_index: 69
# x_coord: 5.984
# y_coord: 56.69
# crown_base: 10.4179
# crown_d1: 3.36
# crown_d2: 1.47021
# crown_d3: 6.68639
# crown_base_height: 10.401095
# crown_center_height: 13.761095
# tree_height: 17.121095
# crown_volume: 30.421920806998543
# single_leaf_area: 0.01161
# total_leaf_area: 882.9962514231328
# total_tree_branch_area: 27.966085217701142
# total_tree_stem_area: 0
# total_tree_ground_area: 6.790607322990747
# total_tree_canopy_veg_area: 910.9623366408339
# leaf_density: 291.5
# branch_scale: 0
#
# tree_index: 70
# x_coord: -27.64
# y_coord: 45.09
# crown_base: 6.55228
# crown_d1: 1.9813
# crown_d2: 0.936482
# crown_d3: 3.94278
# crown_base_height: 6.542369999999999
# crown_center_height: 8.52367
# tree_height: 10.50497
# crown_volume: 7.278430131302763
# single_leaf_area: 0.01161
# total_leaf_area: 211.2564345610627
# total_tree_branch_area: 7.251603578564986
# total_tree_stem_area: 0
# total_tree_ground_area: 2.7551721589244798
# total_tree_canopy_veg_area: 218.50803813962767
# leaf_density: 291.5
# branch_scale: 0
#
# tree_index: 71
# x_coord: -42.87
# y_coord: 53.53
# crown_base: 8.58227
# crown_d1: 2.53581
# crown_d2: 1.09653
# crown_d3: 5.04626
# crown_base_height: 8.56959
# crown_center_height: 11.1054
# tree_height: 13.64121
# crown_volume: 12.77163080061819
# single_leaf_area: 0.01161
# total_leaf_area: 370.69658398794303
# total_tree_branch_area: 12.144897845550812
# total_tree_stem_area: 0
# total_tree_ground_area: 3.777382020129128
# total_tree_canopy_veg_area: 382.84148183349384
# leaf_density: 291.5
# branch_scale: 0
#
# tree_index: 72
# x_coord: -12.51
# y_coord: 40.53
# crown_base: 6.94355
# crown_d1: 2.1898
# crown_d2: 0.963744
# crown_d3: 4.3577
# crown_base_height: 6.932600000000001
# crown_center_height: 9.1224
# tree_height: 11.3122
# crown_volume: 8.51954566869248
# single_leaf_area: 0.01161
# total_leaf_area: 247.27981303379926
# total_tree_branch_area: 8.375431996562064
# total_tree_stem_area: 0
# total_tree_ground_area: 2.91791910289495
# total_tree_canopy_veg_area: 255.65524503036133
# leaf_density: 291.5
# branch_scale: 0
#
# tree_index: 73
# x_coord: -18.55
# y_coord: 35.24
# crown_base: 8.05596
# crown_d1: 2.66147
# crown_d2: 1.07256
# crown_d3: 5.29632
# crown_base_height: 8.04265
# crown_center_height: 10.70412
# tree_height: 13.365590000000001
# crown_volume: 12.824881979694347
# single_leaf_area: 0.01161
# total_leaf_area: 372.24219946062846
# total_tree_branch_area: 12.482396378857036
# total_tree_stem_area: 0
# total_tree_ground_area: 3.614040919029995
# total_tree_canopy_veg_area: 384.7245958394855
# leaf_density: 291.5
# branch_scale: 0
#
# tree_index: 74
# x_coord: -46.83
# y_coord: 18.25
# crown_base: 8.60116
# crown_d1: 2.81518
# crown_d2: 1.13664
# crown_d3: 5.6022
# crown_base_height: 8.58708
# crown_center_height: 11.40226
# tree_height: 14.21744
# crown_volume: 15.234936507593938
# single_leaf_area: 0.01161
# total_leaf_area: 442.19403213291406
# total_tree_branch_area: 14.71194482916001
# total_tree_stem_area: 0
# total_tree_ground_area: 4.058782166929097
# total_tree_canopy_veg_area: 456.9059769620741
# leaf_density: 291.5
# branch_scale: 0
#
# tree_index: 75
# x_coord: -46.42
# y_coord: 42.78
# crown_base: 18.7966
# crown_d1: 5.58249
# crown_d2: 4.28936
# crown_d3: 11.1092
# crown_base_height: 18.768710000000002
# crown_center_height: 24.351200000000002
# tree_height: 29.933690000000002
# crown_volume: 430.2308594428244
# single_leaf_area: 0.01161
# total_leaf_area: 12487.45069532798
# total_tree_branch_area: 356.73814446289947
# total_tree_stem_area: 0
# total_tree_ground_area: 57.80093552914888
# total_tree_canopy_veg_area: 12844.188839790879
# leaf_density: 291.5
# branch_scale: 0
#
# tree_index: 76
# x_coord: -16.96
# y_coord: 29.44
# crown_base: 10.2495
# crown_d1: 3.33683
# crown_d2: 1.51372
# crown_d3: 6.6403
# crown_base_height: 10.23282
# crown_center_height: 13.56965
# tree_height: 16.906480000000002
# crown_volume: 32.02681778232339
# single_leaf_area: 0.01161
# total_leaf_area: 929.5783861319366
# total_tree_branch_area: 28.73867043021763
# total_tree_stem_area: 0
# total_tree_ground_area: 7.198482792573354
# total_tree_canopy_veg_area: 958.3170565621542
# leaf_density: 291.5
# branch_scale: 0
#
# tree_index: 77
# x_coord: -17.32
# y_coord: 23.52
# crown_base: 8.02187
# crown_d1: 2.61222
# crown_d2: 1.10647
# crown_d3: 5.19832
# crown_base_height: 8.008809999999999
# crown_center_height: 10.62103
# tree_height: 13.23325
# crown_volume: 13.396077337095933
# single_leaf_area: 0.01161
# total_leaf_area: 388.8211447092095
# total_tree_branch_area: 12.766159090647433
# total_tree_stem_area: 0
# total_tree_ground_area: 3.84617605057076
# total_tree_canopy_veg_area: 401.5873037998569
# leaf_density: 291.5
# branch_scale: 0
#
# tree_index: 78
# x_coord: -36.07
# y_coord: 10.92
# crown_base: 13.5949
# crown_d1: 4.28941
# crown_d2: 2.20779
# crown_d3: 8.53592
# crown_base_height: 13.573450000000001
# crown_center_height: 17.86286
# tree_height: 22.15227
# crown_volume: 87.57934504982431
# single_leaf_area: 0.01161
# total_leaf_area: 2541.990490071151
# total_tree_branch_area: 77.12306454005666
# total_tree_stem_area: 0
# total_tree_ground_area: 15.313180317891792
# total_tree_canopy_veg_area: 2619.1135546112073
# leaf_density: 291.5
# branch_scale: 0
#
# tree_index: 79
# x_coord: -59.58
# y_coord: -1.807
# crown_base: 14.5357
# crown_d1: 4.95756
# crown_d2: 2.59397
# crown_d3: 9.86555
# crown_base_height: 14.510915
# crown_center_height: 19.468475
# tree_height: 24.426035
# crown_volume: 139.72897924476334
# single_leaf_area: 0.01161
# total_leaf_area: 4055.633622579256
# total_tree_branch_area: 129.02692581426734
# total_tree_stem_area: 0
# total_tree_ground_area: 21.138772790157358
# total_tree_canopy_veg_area: 4184.660548393524
# leaf_density: 291.5
# branch_scale: 0
#
# tree_index: 80
# x_coord: -63.61
# y_coord: -16.1
# crown_base: 9.08398
# crown_d1: 2.73644
# crown_d2: 1.22941
# crown_d3: 5.44552
# crown_base_height: 9.070300000000001
# crown_center_height: 11.806740000000001
# tree_height: 14.54318
# crown_volume: 17.32479171633671
# single_leaf_area: 0.01161
# total_leaf_area: 502.852079566673
# total_tree_branch_area: 15.658354380587962
# total_tree_stem_area: 0
# total_tree_ground_area: 4.7483569116269795
# total_tree_canopy_veg_area: 518.5104339472609
# leaf_density: 291.5
# branch_scale: 0
#
# tree_index: 81
# x_coord: -48.81
# y_coord: -27.18
# crown_base: 11.1522
# crown_d1: 3.63422
# crown_d2: 1.64131
# crown_d3: 7.2321
# crown_base_height: 11.13403
# crown_center_height: 14.76825
# tree_height: 18.40247
# crown_volume: 41.00917707397507
# single_leaf_area: 0.01161
# total_leaf_area: 1190.2913645721264
# total_tree_branch_area: 36.84449879292728
# total_tree_stem_area: 0
# total_tree_ground_area: 8.463131787696206
# total_tree_canopy_veg_area: 1227.1358633650536
# leaf_density: 291.5
# branch_scale: 0
#
# tree_index: 82
# x_coord: -60.24
# y_coord: -27.66
# crown_base: 8.69595
# crown_d1: 2.68473
# crown_d2: 1.21624
# crown_d3: 5.34262
# crown_base_height: 8.68253
# crown_center_height: 11.36726
# tree_height: 14.05199
# crown_volume: 16.63519093857195
# single_leaf_area: 0.01161
# total_leaf_area: 482.83641699205083
# total_tree_branch_area: 15.203186386558365
# total_tree_stem_area: 0
# total_tree_ground_area: 4.6471686925422535
# total_tree_canopy_veg_area: 498.0396033786092
# leaf_density: 291.5
# branch_scale: 0
#
# tree_index: 83
# x_coord: -51.35
# y_coord: -30.22
# crown_base: 12.9158
# crown_d1: 4.23381
# crown_d2: 2.08311
# crown_d3: 8.42528
# crown_base_height: 12.894630000000001
# crown_center_height: 17.12844
# tree_height: 21.362250000000003
# crown_volume: 76.95633582879802
# single_leaf_area: 0.01161
# total_leaf_area: 2233.6576474308627
# total_tree_branch_area: 68.62596153196908
# total_tree_stem_area: 0
# total_tree_ground_area: 13.632461511404271
# total_tree_canopy_veg_area: 2302.2836089628317
# leaf_density: 291.5
# branch_scale: 0
#
# tree_index: 84
# x_coord: -28.11
# y_coord: 5.377
# crown_base: 10.4321
# crown_d1: 3.09619
# crown_d2: 1.4406
# crown_d3: 6.16141
# crown_base_height: 10.416615
# crown_center_height: 13.512805
# tree_height: 16.608995
# crown_volume: 26.91553606030438
# single_leaf_area: 0.01161
# total_leaf_area: 781.2234341503347
# total_tree_branch_area: 24.20319029064058
# total_tree_stem_area: 0
# total_tree_ground_area: 6.519836329562555
# total_tree_canopy_veg_area: 805.4266244409753
# leaf_density: 291.5
# branch_scale: 0
#
# tree_index: 85
# x_coord: -48.36
# y_coord: -5.689
# crown_base: 13.1729
# crown_d1: 4.17184
# crown_d2: 2.06915
# crown_d3: 8.30196
# crown_base_height: 13.15204
# crown_center_height: 17.32388
# tree_height: 21.495720000000002
# crown_volume: 74.81698516847784
# single_leaf_area: 0.01161
# total_leaf_area: 2171.5629945150695
# total_tree_branch_area: 67.72275008282564
# total_tree_stem_area: 0
# total_tree_ground_area: 13.450357366619613
# total_tree_canopy_veg_area: 2239.2857445978952
# leaf_density: 291.5
# branch_scale: 0
#
# tree_index: 86
# x_coord: -8.079
# y_coord: 57.12
# crown_base: 6.92326
# crown_d1: 2.06173
# crown_d2: 0.95304
# crown_d3: 4.10283
# crown_base_height: 6.912945
# crown_center_height: 8.974675
# tree_height: 11.036405
# crown_volume: 7.844091611961285
# single_leaf_area: 0.01161
# total_leaf_area: 227.6747590371763
# total_tree_branch_area: 7.653594377247825
# total_tree_stem_area: 0
# total_tree_ground_area: 2.8534622423745906
# total_tree_canopy_veg_area: 235.32835341442413
# leaf_density: 291.5
# branch_scale: 0
#
# tree_index: 87
# x_coord: -18.47
# y_coord: 59.2
# crown_base: 4.8385
# crown_d1: 1.63789
# crown_d2: 0.781414
# crown_d3: 3.25939
# crown_base_height: 4.830304999999999
# crown_center_height: 6.468195
# tree_height: 8.106085
# crown_volume: 4.18924457990122
# single_leaf_area: 0.01161
# total_leaf_area: 121.59282393163292
# total_tree_branch_area: 4.430892942921684
# total_tree_stem_area: 0
# total_tree_ground_area: 1.91828110247081
# total_tree_canopy_veg_area: 126.02371687455461
# leaf_density: 291.5
# branch_scale: 0
#
# tree_index: 88
# x_coord: -40.49
# y_coord: 57.96
# crown_base: 7.46759
# crown_d1: 2.29989
# crown_d2: 1.03019
# crown_d3: 4.57679
# crown_base_height: 7.456095000000001
# crown_center_height: 9.755985
# tree_height: 12.055875
# crown_volume: 10.224223487517614
# single_leaf_area: 0.01161
# total_leaf_area: 296.7580867251988
# total_tree_branch_area: 9.865001110712459
# total_tree_stem_area: 0
# total_tree_ground_area: 3.334145378969521
# total_tree_canopy_veg_area: 306.62308783591124
# leaf_density: 291.5
# branch_scale: 0
#
# tree_index: 89
# x_coord: -26.73
# y_coord: 60.7
# crown_base: 9.24356
# crown_d1: 2.80473
# crown_d2: 1.26074
# crown_d3: 5.58142
# crown_base_height: 9.22954
# crown_center_height: 12.03427
# tree_height: 14.839000000000002
# crown_volume: 18.67371530228505
# single_leaf_area: 0.01161
# total_leaf_area: 542.0045866488236
# total_tree_branch_area: 16.79932582272734
# total_tree_stem_area: 0
# total_tree_ground_area: 4.993452659155707
# total_tree_canopy_veg_area: 558.803912471551
# leaf_density: 291.5
# branch_scale: 0
#
# tree_index: 90
# x_coord: -31.05
# y_coord: 30.51
# crown_base: 11.7252
# crown_d1: 3.47873
# crown_d2: 1.60428
# crown_d3: 6.92267
# crown_base_height: 11.707804999999999
# crown_center_height: 15.186535
# tree_height: 18.665264999999998
# crown_volume: 37.50331610573168
# single_leaf_area: 0.01161
# total_leaf_area: 1088.533749968862
# total_tree_branch_area: 34.13806869416473
# total_tree_stem_area: 0
# total_tree_ground_area: 8.085561995124301
# total_tree_canopy_veg_area: 1122.6718186630267
# leaf_density: 291.5
# branch_scale: 0
#
# tree_index: 91
# x_coord: -18.4
# y_coord: 17.67
# crown_base: 6.65434
# crown_d1: 1.96672
# crown_d2: 0.932788
# crown_d3: 3.91378
# crown_base_height: 6.64451
# crown_center_height: 8.61123
# tree_height: 10.57795
# crown_volume: 7.167984282192927
# single_leaf_area: 0.01161
# total_leaf_area: 208.05074379064973
# total_tree_branch_area: 7.038330758186307
# total_tree_stem_area: 0
# total_tree_ground_area: 2.7334791997054464
# total_tree_canopy_veg_area: 215.08907454883604
# leaf_density: 291.5
# branch_scale: 0
#
# tree_index: 92
# x_coord: -37.13
# y_coord: 18.87
# crown_base: 7.9244
# crown_d1: 2.3695
# crown_d2: 1.01631
# crown_d3: 4.7153
# crown_base_height: 7.9125499999999995
# crown_center_height: 10.28205
# tree_height: 12.65155
# crown_volume: 10.251743228340779
# single_leaf_area: 0.01161
# total_leaf_area: 297.55684720259114
# total_tree_branch_area: 10.02464625531378
# total_tree_stem_area: 0
# total_tree_ground_area: 3.244907120175389
# total_tree_canopy_veg_area: 307.5814934579049
# leaf_density: 291.5
# branch_scale: 0
#
# tree_index: 93
# x_coord: -31.94
# y_coord: 10.51
# crown_base: 10.1391
# crown_d1: 3.227
# crown_d2: 1.42482
# crown_d3: 6.42173
# crown_base_height: 10.122964999999999
# crown_center_height: 13.349965
# tree_height: 16.576965
# crown_volume: 27.44148312868583
# single_leaf_area: 0.01161
# total_leaf_area: 796.4890478101063
# total_tree_branch_area: 24.624247460442817
# total_tree_stem_area: 0
# total_tree_ground_area: 6.377785046952084
# total_tree_canopy_veg_area: 821.1132952705491
# leaf_density: 291.5
# branch_scale: 0
#
# tree_index: 94
# x_coord: -14.85
# y_coord: -3.246
# crown_base: 10.7352
# crown_d1: 3.48273
# crown_d2: 1.47134
# crown_d3: 6.93064
# crown_base_height: 10.71779
# crown_center_height: 14.200520000000001
# tree_height: 17.68325
# crown_volume: 31.581627007524286
# single_leaf_area: 0.01161
# total_leaf_area: 916.6567238933925
# total_tree_branch_area: 29.04580149906269
# total_tree_stem_area: 0
# total_tree_ground_area: 6.8010498246040365
# total_tree_canopy_veg_area: 945.7025253924552
# leaf_density: 291.5
# branch_scale: 0
#
# tree_index: 95
# x_coord: -44.55
# y_coord: 22.62
# crown_base: 9.95784
# crown_d1: 3.16773
# crown_d2: 1.39002
# crown_d3: 6.30378
# crown_base_height: 9.941999999999998
# crown_center_height: 13.109729999999999
# tree_height: 16.277459999999998
# crown_volume: 25.637688410850952
# single_leaf_area: 0.01161
# total_leaf_area: 744.1339061249489
# total_tree_branch_area: 23.529289268273754
# total_tree_stem_area: 0
# total_tree_ground_area: 6.070045839809016
# total_tree_canopy_veg_area: 767.6631953932226
# leaf_density: 291.5
# branch_scale: 0
#
# tree_index: 96
# x_coord: -29.87
# y_coord: 14.95
# crown_base: 12.6048
# crown_d1: 4.12184
# crown_d2: 1.93887
# crown_d3: 8.20246
# crown_base_height: 12.58419
# crown_center_height: 16.70603
# tree_height: 20.82787
# crown_volume: 64.904845516631
# single_leaf_area: 0.01161
# total_leaf_area: 1883.8631411202148
# total_tree_branch_area: 59.04324581701181
# total_tree_stem_area: 0
# total_tree_ground_area: 11.809928123719807
# total_tree_canopy_veg_area: 1942.9063869372267
# leaf_density: 291.5
# branch_scale: 0
#
# tree_index: 97
# x_coord: -13.14
# y_coord: 14.3
# crown_base: 10.0979
# crown_d1: 3.24646
# crown_d2: 1.36877
# crown_d3: 6.46046
# crown_base_height: 10.081669999999999
# crown_center_height: 13.32813
# tree_height: 16.574589999999997
# crown_volume: 25.47766492164145
# single_leaf_area: 0.01161
# total_leaf_area: 739.4892243506431
# total_tree_branch_area: 23.845265878320074
# total_tree_stem_area: 0
# total_tree_ground_area: 5.885872208877081
# total_tree_canopy_veg_area: 763.3344902289632
# leaf_density: 291.5
# branch_scale: 0
#
# tree_index: 98
# x_coord: -38.7
# ...
# total_tree_stem_area: 0
# total_tree_ground_area: 1.9275668662541354
# total_tree_canopy_veg_area: 123.19787079049492
# leaf_density: 291.5
# branch_scale: 0
#
# tree_index: 441
# x_coord: 51.51
# y_coord: 36.84
# crown_base: 13.5413
# crown_d1: 4.25147
# crown_d2: 2.29617
# crown_d3: 8.46043
# crown_base_height: 13.520045
# crown_center_height: 17.771515
# tree_height: 22.022985000000002
# crown_volume: 93.89355986673402
# single_leaf_area: 0.01161
# total_leaf_area: 2725.260575131955
# total_tree_branch_area: 79.84231433036761
# total_tree_stem_area: 0
# total_tree_ground_area: 16.563722641827535
# total_tree_canopy_veg_area: 2805.1028894623228
# leaf_density: 291.5
# branch_scale: 0
#
# tree_index: 442
# x_coord: 42.19
# y_coord: -1.157
# crown_base: 6.34989
# crown_d1: 1.88233
# crown_d2: 0.87663
# crown_d3: 3.74583
# crown_base_height: 6.340475000000001
# crown_center_height: 8.222805000000001
# tree_height: 10.105135
# crown_volume: 6.05922432415375
# single_leaf_area: 0.01161
# total_leaf_area: 175.8689860085626
# total_tree_branch_area: 6.12836870968923
# total_tree_stem_area: 0
# total_tree_ground_area: 2.4142516153465716
# total_tree_canopy_veg_area: 181.9973547182518
# leaf_density: 291.5
# branch_scale: 0
#
# tree_index: 443
# x_coord: 47.95
# y_coord: -4.328
# crown_base: 6.56459
# crown_d1: 2.23955
# crown_d2: 0.915288
# crown_d3: 4.4567
# crown_base_height: 6.55339
# crown_center_height: 8.79294
# tree_height: 11.03249
# crown_volume: 7.858956940495119
# single_leaf_area: 0.01161
# total_leaf_area: 228.10622519787086
# total_tree_branch_area: 7.9165078373845486
# total_tree_stem_area: 0
# total_tree_ground_area: 2.6318759149701236
# total_tree_canopy_veg_area: 236.0227330352554
# leaf_density: 291.5
# branch_scale: 0
#
# tree_index: 444
# x_coord: 36.93
# y_coord: -6.103
# crown_base: 15.3124
# crown_d1: 5.14364
# crown_d2: 2.85217
# crown_d3: 10.2358
# crown_base_height: 15.286659999999998
# crown_center_height: 20.4303
# tree_height: 25.57394
# crown_volume: 175.27096966502017
# single_leaf_area: 0.01161
# total_leaf_area: 5087.239894527211
# total_tree_branch_area: 160.55957591242588
# total_tree_stem_area: 0
# total_tree_ground_area: 25.556459481760996
# total_tree_canopy_veg_area: 5247.799470439637
# leaf_density: 291.5
# branch_scale: 0
#
# tree_index: 445
# x_coord: 61.37
# y_coord: -19.56
# crown_base: 10.4124
# crown_d1: 3.41463
# crown_d2: 1.49156
# crown_d3: 6.79511
# crown_base_height: 10.395325
# crown_center_height: 13.809955
# tree_height: 17.224585
# crown_volume: 31.820992202972363
# single_leaf_area: 0.01161
# total_leaf_area: 923.6042986912729
# total_tree_branch_area: 28.62901012381795
# total_tree_stem_area: 0
# total_tree_ground_area: 6.98926213154259
# total_tree_canopy_veg_area: 952.2333088150908
# leaf_density: 291.5
# branch_scale: 0
#
# tree_index: 446
# x_coord: 36.05
# y_coord: -60.69
# crown_base: 8.21754
# crown_d1: 2.6373
# crown_d2: 1.132
# crown_d3: 5.24824
# crown_base_height: 8.20436
# crown_center_height: 10.84166
# tree_height: 13.478959999999999
# crown_volume: 14.156014466350113
# single_leaf_area: 0.01161
# total_leaf_area: 410.87831988581206
# total_tree_branch_area: 13.341739352641692
# total_tree_stem_area: 0
# total_tree_ground_area: 4.025712224533646
# total_tree_canopy_veg_area: 424.22005923845376
# leaf_density: 291.5
# branch_scale: 0
#
# tree_index: 447
# x_coord: 52.68
# y_coord: -21.72
# crown_base: 9.45215
# crown_d1: 2.99081
# crown_d2: 1.27075
# crown_d3: 5.95171
# crown_base_height: 9.437195
# crown_center_height: 12.428004999999999
# tree_height: 15.418814999999999
# crown_volume: 20.230083257470884
# single_leaf_area: 0.01161
# total_leaf_area: 587.1781665480925
# total_tree_branch_area: 19.130394240878356
# total_tree_stem_area: 0
# total_tree_ground_area: 5.073061292125934
# total_tree_canopy_veg_area: 606.3085607889708
# leaf_density: 291.5
# branch_scale: 0
#
# tree_index: 448
# x_coord: 45.4
# y_coord: -51.5
# crown_base: 8.70553
# crown_d1: 2.72531
# crown_d2: 1.14557
# crown_d3: 5.42336
# crown_base_height: 8.691899999999999
# crown_center_height: 11.417209999999999
# tree_height: 14.14252
# crown_volume: 14.981240736712605
# single_leaf_area: 0.01161
# total_leaf_area: 434.8305123830834
# total_tree_branch_area: 14.15837596856527
# total_tree_stem_area: 0
# total_tree_ground_area: 4.1228082502667425
# total_tree_canopy_veg_area: 448.98888835164865
# leaf_density: 291.5
# branch_scale: 0
#
# tree_index: 449
# x_coord: 26.26
# y_coord: -47.53
# crown_base: 15.6271
# crown_d1: 4.76855
# crown_d2: 2.80636
# crown_d3: 9.48942
# crown_base_height: 15.603259999999999
# crown_center_height: 20.37181
# tree_height: 25.14036
# crown_volume: 157.31194953023748
# single_leaf_area: 0.01161
# total_leaf_area: 4565.979335115143
# total_tree_branch_area: 138.32672560232945
# total_tree_stem_area: 0
# total_tree_ground_area: 24.742104444260438
# total_tree_canopy_veg_area: 4704.306060717472
# leaf_density: 291.5
# branch_scale: 0
#
# tree_index: 450
# x_coord: 40.43
# y_coord: -50.45
# crown_base: 10.6003
# crown_d1: 3.57055
# crown_d2: 1.56102
# crown_d3: 7.10539
# crown_base_height: 10.582445
# crown_center_height: 14.152995
# tree_height: 17.723545
# crown_volume: 36.44522729064302
# single_leaf_area: 0.01161
# total_leaf_area: 1057.8227221109137
# total_tree_branch_area: 33.426362700337926
# total_tree_stem_area: 0
# total_tree_ground_area: 7.655380954749902
# total_tree_canopy_veg_area: 1091.2490848112516
# leaf_density: 291.5
# branch_scale: 0
#
# tree_index: 451
# x_coord: 10.18
# y_coord: -61.03
# crown_base: 9.41515
# crown_d1: 3.00237
# crown_d2: 1.27858
# crown_d3: 5.97471
# crown_base_height: 9.400135000000002
# crown_center_height: 12.402505000000001
# tree_height: 15.404875
# crown_volume: 20.559314720627977
# single_leaf_area: 0.01161
# total_leaf_area: 596.7341097662271
# total_tree_branch_area: 19.191735383539758
# total_tree_stem_area: 0
# total_tree_ground_area: 5.135771420734614
# total_tree_canopy_veg_area: 615.9258451497668
# leaf_density: 291.5
# branch_scale: 0
#
# tree_index: 452
# x_coord: 64.71
# y_coord: 20.11
# crown_base: 4.25686
# crown_d1: 1.44283
# crown_d2: 0.751018
# crown_d3: 2.87123
# crown_base_height: 4.249645
# crown_center_height: 5.692475
# tree_height: 7.135305
# crown_volume: 3.408823108013572
# single_leaf_area: 0.01161
# total_leaf_area: 98.94109071009393
# total_tree_branch_area: 3.58265021472005
# total_tree_stem_area: 0
# total_tree_ground_area: 1.7719463353341551
# total_tree_canopy_veg_area: 102.52374092481398
# leaf_density: 291.5
# branch_scale: 0
#
# tree_index: 453
# x_coord: 66.36
# y_coord: -18.7
# crown_base: 20.7199
# crown_d1: 6.91537
# crown_d2: 6.28565
# crown_d3: 13.7616
# crown_base_height: 20.68533
# crown_center_height: 27.6007
# tree_height: 34.51607
# crown_volume: 1144.4700196873418
# single_leaf_area: 0.01161
# total_leaf_area: 33218.2423214251
# total_tree_branch_area: 1014.0277155008472
# total_tree_stem_area: 0
# total_tree_ground_area: 124.12242797789654
# total_tree_canopy_veg_area: 34232.27003692595
# leaf_density: 291.5
# branch_scale: 0
#
# tree_index: 454
# x_coord: 52.49
# y_coord: -3.464
# crown_base: 6.7988
# crown_d1: 2.17518
# crown_d2: 0.961435
# crown_d3: 4.3286
# crown_base_height: 6.787920000000001
# crown_center_height: 8.9631
# tree_height: 11.138280000000002
# crown_volume: 8.422163476087572
# single_leaf_area: 0.01161
# total_leaf_area: 244.4532948934418
# total_tree_branch_area: 8.348072445569084
# total_tree_stem_area: 0
# total_tree_ground_area: 2.9039539748736565
# total_tree_canopy_veg_area: 252.80136733901088
# leaf_density: 291.5
# branch_scale: 0
#
# tree_index: 455
# x_coord: 51.12
# y_coord: -18.54
# crown_base: 12.2584
# crown_d1: 3.75414
# crown_d2: 1.77516
# crown_d3: 7.47073
# crown_base_height: 12.239625
# crown_center_height: 15.993765
# tree_height: 19.747905000000003
# crown_volume: 49.55347099836493
# single_leaf_area: 0.01161
# total_leaf_area: 1438.289495727542
# total_tree_branch_area: 45.442448518430055
# total_tree_stem_area: 0
# total_tree_ground_area: 9.899764859268354
# total_tree_canopy_veg_area: 1483.731944245972
# leaf_density: 291.5
# branch_scale: 0
#
# tree_index: 456
# x_coord: 43.0
# y_coord: 9.076
# crown_base: 7.79754
# crown_d1: 2.64422
# crown_d2: 1.07225
# crown_d3: 5.26199
# crown_base_height: 7.784315
# crown_center_height: 10.428535
# tree_height: 13.072754999999999
# crown_volume: 12.7343946496566
# single_leaf_area: 0.01161
# total_leaf_area: 369.61580470628286
# total_tree_branch_area: 12.218893039413395
# total_tree_stem_area: 0
# total_tree_ground_area: 3.6119521020347976
# total_tree_canopy_veg_area: 381.83469774569625
# leaf_density: 291.5
# branch_scale: 0
#
# tree_index: 457
# x_coord: 36.28
# y_coord: -22.49
# crown_base: 10.0369
# crown_d1: 3.35292
# crown_d2: 1.44899
# crown_d3: 6.6723
# crown_base_height: 10.020129999999998
# crown_center_height: 13.37305
# tree_height: 16.72597
# crown_volume: 29.487813912127976
# single_leaf_area: 0.01161
# total_leaf_area: 855.8837987995146
# total_tree_branch_area: 26.90590478929404
# total_tree_stem_area: 0
# total_tree_ground_area: 6.596000034028842
# total_tree_canopy_veg_area: 882.7897035888086
# leaf_density: 291.5
# branch_scale: 0
#
# tree_index: 458
# x_coord: 64.6
# y_coord: 27.05
# crown_base: 20.4795
# crown_d1: 6.17447
# crown_d2: 5.7121
# crown_d3: 12.2872
# crown_base_height: 20.44863
# crown_center_height: 26.6231
# tree_height: 32.79757
# crown_volume: 843.8784527922996
# single_leaf_area: 0.01161
# total_leaf_area: 24493.572092296497
# total_tree_branch_area: 659.9294122162921
# total_tree_stem_area: 0
# total_tree_ground_area: 102.50415656634897
# total_tree_canopy_veg_area: 25153.50150451279
# leaf_density: 291.5
# branch_scale: 0
#
# tree_index: 459
# x_coord: 55.46
# y_coord: 1.802
# crown_base: 12.7092
# crown_d1: 3.76968
# crown_d2: 1.83643
# crown_d3: 7.50166
# crown_base_height: 12.690349999999999
# crown_center_height: 16.46003
# tree_height: 20.22971
# crown_volume: 53.25272700614401
# single_leaf_area: 0.01161
# total_leaf_area: 1545.6604013533301
# total_tree_branch_area: 47.51881820606988
# total_tree_stem_area: 0
# total_tree_ground_area: 10.594943139632013
# total_tree_canopy_veg_area: 1593.1792195594
# leaf_density: 291.5
# branch_scale: 0
#
# tree_index: 460
# x_coord: 61.88
# y_coord: -24.74
# crown_base: 14.6799
# crown_d1: 4.70679
# crown_d2: 2.62125
# crown_d3: 9.36651
# crown_base_height: 14.656365
# crown_center_height: 19.363155
# tree_height: 24.069945
# crown_volume: 135.46600344959157
# single_leaf_area: 0.01161
# total_leaf_area: 3931.9007501243955
# total_tree_branch_area: 118.2791255795402
# total_tree_stem_area: 0
# total_tree_ground_area: 21.58573095192131
# total_tree_canopy_veg_area: 4050.1798757039355
# leaf_density: 291.5
# branch_scale: 0
#
# tree_index: 461
# x_coord: 64.56
# y_coord: -21.46
# crown_base: 10.0487
# crown_d1: 3.12318
# crown_d2: 1.38016
# crown_d3: 6.21512
# crown_base_height: 10.03308
# crown_center_height: 13.15626
# tree_height: 16.27944
# crown_volume: 24.919796824684603
# single_leaf_area: 0.01161
# total_leaf_area: 723.2971028364707
# total_tree_branch_area: 22.786933490442987
# total_tree_stem_area: 0
# total_tree_ground_area: 5.984236457237
# total_tree_canopy_veg_area: 746.0840363269136
# leaf_density: 291.5
# branch_scale: 0
#
# tree_index: 462
# x_coord: 32.53
# y_coord: -48.72
# crown_base: 9.77606
# crown_d1: 2.96634
# crown_d2: 1.33494
# crown_d3: 5.90302
# crown_base_height: 9.76123
# crown_center_height: 12.72757
# tree_height: 15.693909999999999
# crown_volume: 22.142825127161732
# single_leaf_area: 0.01161
# total_leaf_area: 642.6954993158694
# total_tree_branch_area: 19.938580227172064
# total_tree_stem_area: 0
# total_tree_ground_area: 5.598521695210698
# total_tree_canopy_veg_area: 662.6340795430415
# leaf_density: 291.5
# branch_scale: 0
#
# tree_index: 463
# x_coord: 48.94
# y_coord: -36.19
# crown_base: 11.4737
# crown_d1: 3.54627
# crown_d2: 1.63907
# crown_d3: 7.05707
# crown_base_height: 11.455964999999999
# crown_center_height: 15.002234999999999
# tree_height: 18.548505
# crown_volume: 39.90758159763823
# single_leaf_area: 0.01161
# total_leaf_area: 1158.3175558714497
# total_tree_branch_area: 35.34704722190811
# total_tree_stem_area: 0
# total_tree_ground_area: 8.440047204028085
# total_tree_canopy_veg_area: 1193.6646030933578
# leaf_density: 291.5
# branch_scale: 0
#
# tree_index: 464
# x_coord: 12.54
# y_coord: -50.65
# crown_base: 9.09619
# crown_d1: 2.71866
# crown_d2: 1.24159
# crown_d3: 5.41013
# crown_base_height: 9.082595
# crown_center_height: 11.801255
# tree_height: 14.519915
# crown_volume: 17.55496301377422
# single_leaf_area: 0.01161
# total_leaf_area: 509.53280147479677
# total_tree_branch_area: 15.835800335832065
# total_tree_stem_area: 0
# total_tree_ground_area: 4.842908734571688
# total_tree_canopy_veg_area: 525.3686018106289
# leaf_density: 291.5
# branch_scale: 0
#
# tree_index: 465
# x_coord: 29.08
# y_coord: -55.46
# crown_base: 13.2709
# crown_d1: 4.31264
# crown_d2: 2.20478
# crown_d3: 8.58215
# crown_base_height: 13.249335
# crown_center_height: 17.561975
# tree_height: 21.874615
# crown_volume: 87.81371232392604
# single_leaf_area: 0.01161
# total_leaf_area: 2548.7930002019534
# total_tree_branch_area: 77.31152460036506
# total_tree_stem_area: 0
# total_tree_ground_area: 15.271454200430487
# total_tree_canopy_veg_area: 2626.1045248023183
# leaf_density: 291.5
# branch_scale: 0
#
# tree_index: 466
# x_coord: 54.56
# y_coord: -27.48
# crown_base: 10.4447
# crown_d1: 3.45883
# crown_d2: 1.4453
# crown_d3: 6.88306
# crown_base_height: 10.427399999999999
# crown_center_height: 13.88623
# tree_height: 17.34506
# crown_volume: 30.26452289110051
# single_leaf_area: 0.01161
# total_leaf_area: 878.4277769141923
# total_tree_branch_area: 28.45901834842666
# total_tree_stem_area: 0
# total_tree_ground_area: 6.562448044085828
# total_tree_canopy_veg_area: 906.886795262619
# leaf_density: 291.5
# branch_scale: 0
#
# tree_index: 467
# x_coord: 43.53
# y_coord: -43.85
# crown_base: 13.2876
# crown_d1: 4.27574
# crown_d2: 2.25319
# crown_d3: 8.50872
# crown_base_height: 13.26622
# crown_center_height: 17.54196
# tree_height: 21.817700000000002
# crown_volume: 90.92755812396847
# single_leaf_area: 0.01161
# total_leaf_area: 2639.172374548185
# total_tree_branch_area: 77.48290324935836
# total_tree_stem_area: 0
# total_tree_ground_area: 15.949442340501612
# total_tree_canopy_veg_area: 2716.6552777975435
# leaf_density: 291.5
# branch_scale: 0
#
# tree_index: 468
# x_coord: 31.84
# y_coord: -62.58
# crown_base: 8.96369
# crown_d1: 2.98228
# crown_d2: 1.20131
# crown_d3: 5.93474
# crown_base_height: 8.94878
# crown_center_height: 11.931059999999999
# tree_height: 14.913339999999998
# crown_volume: 18.027985905222252
# single_leaf_area: 0.01161
# total_leaf_area: 523.2622908990759
# total_tree_branch_area: 17.189823856654943
# total_tree_stem_area: 0
# total_tree_ground_area: 4.533775979759342
# total_tree_canopy_veg_area: 540.4521147557308
# leaf_density: 291.5
# branch_scale: 0
#
# tree_index: 469
# x_coord: 44.78
# y_coord: 14.78
# crown_base: 11.7845
# crown_d1: 3.82876
# crown_d2: 1.7721
# crown_d3: 7.61924
# crown_base_height: 11.765360000000001
# crown_center_height: 15.59412
# tree_height: 19.42288
# crown_volume: 50.36434666365436
# single_leaf_area: 0.01161
# total_leaf_area: 1461.8251619125679
# total_tree_branch_area: 45.70589781691838
# total_tree_stem_area: 0
# total_tree_ground_area: 9.865664078641851
# total_tree_canopy_veg_area: 1507.5310597294863
# leaf_density: 291.5
# branch_scale: 0
#
# tree_index: 470
# x_coord: -51.46
# y_coord: 28.41
# crown_base: 13.2614
# crown_d1: 4.4114
# crown_d2: 2.26006
# crown_d3: 8.77869
# crown_base_height: 13.239345
# crown_center_height: 17.650745
# tree_height: 22.062145
# crown_volume: 94.38543593564113
# single_leaf_area: 0.01161
# total_leaf_area: 2739.537278031984
# total_tree_branch_area: 81.85818293453495
# total_tree_stem_area: 0
# total_tree_ground_area: 16.046850648712617
# total_tree_canopy_veg_area: 2821.395460966519
# leaf_density: 291.5
# branch_scale: 0
#
# tree_index: 471
# x_coord: 56.32
# y_coord: -30.48
# crown_base: 6.58872
# crown_d1: 1.98511
# crown_d2: 0.87644
# crown_d3: 3.95037
# crown_base_height: 6.578795
# crown_center_height: 8.563905
# tree_height: 10.549015
# crown_volume: 6.387303708159206
# single_leaf_area: 0.01161
# total_leaf_area: 185.39149012932097
# total_tree_branch_area: 6.444524914283891
# total_tree_stem_area: 0
# total_tree_ground_area: 2.4132052032982583
# total_tree_canopy_veg_area: 191.83601504360487
# leaf_density: 291.5
# branch_scale: 0
#
# tree_index: 472
# x_coord: 66.38
# y_coord: 3.268
# crown_base: 7.21071
# crown_d1: 2.40718
# crown_d2: 0.958591
# crown_d3: 4.79028
# crown_base_height: 7.19867
# crown_center_height: 9.60585
# tree_height: 12.013029999999999
# crown_volume: 9.265393534321028
# single_leaf_area: 0.01161
# total_leaf_area: 268.92804733366785
# total_tree_branch_area: 9.109494765291664
# total_tree_stem_area: 0
# total_tree_ground_area: 2.8867991387186547
# total_tree_canopy_veg_area: 278.03754209895953
# leaf_density: 291.5
# branch_scale: 0

# %%
# Redirecting stdout to a text file
output_file = output_path + 'guiana_gort_data_raw_output_class.txt'

# Use %%capture to capture output
with ipy_io.capture_output() as captured_output:

    print("French Guiana Results:\n")

    tree_sum = 0

    # Calculate and output derived values for each circle in French Guiana
    for circle in guiana_circle_objects:
        get_circle_derived_values(circle, guiana_tree_objects, guiana_leaf_density_ratio)
        output_derived_data(circle)

    tree_sum = 0

    # Output detailed information for each circle in French Guiana
    for circle in guiana_circle_objects:
        circle_name = circle.circle_name
        tree_indices = circle.tree_indices
        crown_percentages = circle.crown_percentages
        tree_percent_total = circle.tree_percent_total
        tree_sum += tree_percent_total

        print(f"Total Trees found in {circle_name}: {tree_percent_total}")
        print(f"Tree indices: {tree_indices}")
        print("Percent of tree crown in circle: " + ", ".join([f"{percentage:.4f}" for percentage in crown_percentages]))
        print()  # Print a blank line for separation

    # Print total number of trees found in all circles in French Guiana
    print(f"Total number of trees found in all circles: {tree_sum} out of {len(guiana_tree_objects)}")

# Write captured output to file for French Guiana
with open(output_file, "w") as file:
    file.write(captured_output.stdout)

# %%
save_objects_to_file(redwood_tree_objects, "redwood_tree_objects.pkl", subfolder="object_data")
save_objects_to_file(guiana_tree_objects, "guiana_tree_objects.pkl", subfolder="object_data")
save_objects_to_file(redwood_circle_objects, "redwood_circle_objects.pkl", subfolder="object_data")
save_objects_to_file(guiana_circle_objects, "guiana_circle_objects.pkl", subfolder="object_data")

# %%
import re

def strip_and_replace(input_string):
    # Define the pattern to match parentheses, spaces, and commas
    pattern = r'[\(\),\s]'
    # Replace the matched characters with underscores
    replaced_string = re.sub(pattern, '_', input_string)
    # Replace consecutive underscores with a single underscore
    replaced_string = re.sub(r'_+', '_', replaced_string)
    return replaced_string

def output_gort_inputs(circle_path_prefix, circle_list):
    # Create the directory if it doesn't exist
    path_with_branch = f"{circle_path_prefix}with_branch/"
    if not os.path.exists(circle_path_prefix):
        os.makedirs(circle_path_prefix)
    if not os.path.exists(path_with_branch):
        os.makedirs(path_with_branch)

    for circle in circle_list:
        gort_input_fn = strip_and_replace(circle.circle_name)  # Assuming circle_name is an attribute of the circle object
        
        # Write main circle input file
        file_path = f"{circle_path_prefix}{gort_input_fn}.in"
        with open(file_path, "w") as file:
            file.write("1\n")
            file.write(f'\t{circle.tree_density}')
            file.write(f'\t{circle.Fa}')
            file.write(f'\t{circle.h1}')
            file.write(f'\t{circle.h2}')
            file.write(f'\t0.1')
            file.write(f'\t{circle.mean_crown_d2}')
            file.write(f'\t{circle.mean_crown_d1}')
            file.write(f'\t0.00')
            file.write(f'\t0.4291')
            file.write(f'\t0.4239')
            file.write(f'\t0.35156')
            file.write(f'\t1')

        # Write branch input file
        file_path_2 = f"{path_with_branch}{gort_input_fn}branch.in"
        with open(file_path_2, "w") as file:
            file.write("1\n")
            file.write(f'\t{circle.tree_density}')
            file.write(f'\t{circle.Fa_b}')
            file.write(f'\t{circle.h1}')
            file.write(f'\t{circle.h2}')
            file.write(f'\t0.1')
            file.write(f'\t{circle.mean_crown_d2}')
            file.write(f'\t{circle.mean_crown_d1}')
            file.write(f'\t0.00')
            file.write(f'\t0.4291')
            file.write(f'\t0.4239')
            file.write(f'\t0.35156')
            file.write(f'\t1')

# %%
path_prefix = gort_output + "redwood/"

output_gort_inputs(path_prefix, redwood_circle_objects)

path_prefix = gort_output + "guiana/"

output_gort_inputs(path_prefix, guiana_circle_objects)

# %%
LAI = [circle.LAI_with_branch for circle in redwood_circle_objects]
LAI_max = np.max(LAI)
print(LAI_max)
print(LAI)

LAI2 = [circle.LAI_with_branch for circle in guiana_circle_objects]
LAI_max2 = np.max(LAI)
print(LAI_max2)
print(LAI2)
# Out:
# 2.2758162111475455
# [2.13960801606531, 0.7669376291180716, 1.2372328475786132, 1.6669724864290527, 0.859324616398858, 0.8975007889996125, 0.9013248607787951, 1.497519679391828, 2.2758162111475455]
# 2.2758162111475455
# [7.288367679520273, 12.67210553613514, 7.62905072804793, 12.727076301959704, 9.677088360031638, 25.79799273007158, 4.073055209173534, 5.21281543561292, 9.778842947125355]
